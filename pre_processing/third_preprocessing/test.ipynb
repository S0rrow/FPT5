# %%
import re, datetime, pytz, subprocess, os, json
from botocore.exceptions import ClientError
from time import gmtime, strftime
import boto3
import redis
import mysql.connector
import pandas as pd
from farmhash import FarmHash32 as fhash
from boto3.dynamodb.conditions import Key, Attr

import logging
# parent_dir = os.path.dirname(os.path.dirname(os.path.abspath(__file__)))
# sys.path.append(parent_dir)
# from logging_utils import logging_to_cloudwatch as ltc
from logging_utils import logging_to_cloudwatch as ltc
    
logger = ltc.log('/aws/preprocessing/second','from_dynamodb_to_rds')



# 접속정보 json파일 로드
with open("./.KEYS/DATA_SRC_INFO.json", "r") as f:
# with open("./DATA_SRC_INFO.json", "r") as f:
    access_info = json.load(f)
# key 정보 json파일 로드
with open("./.KEYS/SECOND_PREPROCESSING_KEY.json", "r") as f:
# with open("./API_KEYS.json", "r") as f:
    key = json.load(f)
# rds 접속 정보 json파일 로드
with open("./.KEYS/RDS.json", "r") as f:
# with open("./DATA_SRC_INFO.json", "r") as f:
    rds_info = json.load(f)

# %%
def get_ids_from_redis():
    """
    Retrieve all ID values stored in Redis.

    This function connects to a Redis database using the connection information
    provided in the `access_info` dictionary. It fetches all keys from the 
    Redis hash named 'compare_id' and decodes them from bytes to UTF-8 strings.

    Returns:
        list: A list of ID values (as strings) retrieved from Redis.
    """
    
    redis_ip = access_info['redis_conn_info']['ip']
    redis_port = access_info['redis_conn_info']['port']
    try:
        redis_client = redis.StrictRedis(host=redis_ip, port=redis_port, db=0)
        # redis에 적재되어있는 id 값 가져오기
        return [x.decode('utf-8') for x in redis_client.hkeys('compare_id')]
    except redis.exceptions.RedisError as e:
        logger.error(f"Redis connection error: {e}")
        return []


def get_data_from_dynamodb(ids):
    """
    Retrieve all data from the DynamoDB table 'precessed-data-table' that matches the provided IDs.

    This function connects to a DynamoDB database using the AWS credentials
    provided in the `key` dictionary. It queries the 'precessed-data-table' table
    to fetch all items that match the IDs provided in the `ids` list.

    The function handles pagination to ensure that all items are retrieved,
    even if they span multiple pages.

    Args:
        ids (list): A list of IDs to query in the DynamoDB table.

    Returns:
        list: A list of data items (as dictionaries) retrieved from the DynamoDB table that match the provided IDs.

    Raises:
        ClientError: If there is an error while accessing DynamoDB.
        Exception: For any unexpected errors that may occur during execution.
    """
    
    dynamodb = boto3.resource(
            'dynamodb',
            aws_access_key_id=key['aws_access_key_id'],
            aws_secret_access_key=key['aws_secret_key'],
            region_name=key['region']
        )    
    table = dynamodb.Table('precessed-data-table')

    # 빈 리스트에 추가적으로 받아오기
    data = []
    for id in ids:
        try:
            response = table.query(KeyConditionExpression=Key('pid').eq(id))
            data.append(response['Items'])  # 데이터 값을 리스트에 추가
        except ClientError as e:
            logger.error(f"[get_data_from_dynamodb()]ClientError: {e.response['Error']['Message']}")
#             print(f"ClientError: {e.response['Error']['Message']}")
            continue  # 다음 ID로 이동
        except Exception as e:
            logger.error(f"[get_data_from_dynamodb()]Unexpected error: (id: {id}){str(e)}")
#             print(f"Unexpected error: (id: {id}){str(e)}")
            continue  # 다음 ID로 이동

    df = pd.DataFrame(data)
    return df


def get_pid_from_rds():
    """
    Retrieve all PID values from the RDS database.

    This function connects to the RDS database using the connection information
    provided in the `rds_info` dictionary. It executes a SQL query to fetch all
    PID values from the 'Job_Info' and returns them as a list.

    Returns:
        list: A list of PID values (as strings) retrieved from the RDS database.

    Raises:
        mysql.connector.Error: If there is an error while connecting to the RDS
        or executing the SQL query.
    """
    # RDS 접속 정보
    rds_host = rds_info['host']
    username = rds_info['username']
    password = rds_info['password']
    database = rds_info['database']

    # RDS에 연결
    connection = mysql.connector.connect(
        host=rds_host,
        user=username,
        password=password,
        database=database
    )

    try:
        cursor = connection.cursor()
        # pid를 추출하는 쿼리
        sql = "SELECT pid FROM Job_Info"
        cursor.execute(sql)
        pids = cursor.fetchall()  # 모든 pid를 가져옴
        return [pid[0] for pid in pids]  # pid 리스트 반환

    except mysql.connector.Error as e:
        logger.error(f"[get_pid_from_rds()]Database error: {str(e)}")  # 에러 로그 출력
        return []  # 빈 리스트 반환

    finally:
        cursor.close()  # 커서 종료
        connection.close()  # 연결 종료


def compare_id(redis_list, rds_list):
    """
    Generate a list of IDs that are present in the DynamoDB list but not in the Redis list.

    This function takes two lists: one containing IDs from Redis and another containing IDs from DynamoDB.
    It removes duplicates from the DynamoDB list and returns a list of IDs that are not found in the Redis list.

    Args:
        r_list (list): A list of IDs retrieved from Redis.
        d_list (list): A list of IDs retrieved from DynamoDB.

    Returns:
        list: A list of unique IDs from the DynamoDB list that are not present in the Redis list.
    """
    rds_id_df = pd.DataFrame({"id":rds_list})
    rds_id_df.drop_duplicates(ignore_index=True, inplace=True)
    mask = rds_id_df.isin(redis_list)
    return list(rds_id_df[~mask].dropna().reset_index(drop=True).id)


def load_to_rds(df: pd.DataFrame):
    
    # RDS 접속 정보
    rds_host = rds_info['host']
    username = rds_info['username']
    password = rds_info['password']
    database = rds_info['database']

    # RDS에 연결
    connection = mysql.connector.connect(
        host=rds_host,
        user=username,
        password=password,
        database=database
    )
    cursor = connection.cursor()
    
    sql_query = """
        INSERT INTO job_information (
            pid, job_title, site_symbol, job_prefer, crawl_url, start_date, end_date, post_status,
            get_date, required_career, resume_required, crawl_domain, company_name, cid, job_requirements
        ) 
        VALUES (%s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s)
        ON DUPLICATE KEY UPDATE
            pid = VALUES(pid),
            job_title = VALUES(job_title),
            site_symbol = VALUES(site_symbol),
            job_prefer = VALUES(job_prefer),
            crawl_url = VALUES(crawl_url),
            start_date = VALUES(start_date),
            end_date = VALUES(end_date),
            post_status = VALUES(post_status),
            get_date = VALUES(get_date),
            required_career = VALUES(required_career),
            resume_required = VALUES(resume_required),
            crawl_domain = VALUES(crawl_domain),
            cid = VALUES(cid),
            company_name = VALUES(company_name),
            job_requirements = VALUES(job_requirements)
    """

    for i, values in df.iterrows():
        data = (
            values['pid'],
            values['job_title'],
            values['site_symbol'],
            f"[{', '.join(f"'{item}'" for item in values['job_prefer'])}]"  if isinstance(values['job_prefer'], list) else values['job_prefer'],
            values['crawl_url'],
            values['start_date'],
            values['end_date'],
            values['post_status'],
            values['get_date'],
            values['required_career'],
            values['resume_required'],
            values['crawl_domain'],
            values['cid'],
            values['company_name'],
            f"[{', '.join(f"'{item}'" for item in values['job_requirements'])}]" if isinstance(values['job_requirements'], list) else values['job_requirements']
        )
        try:
            cursor.execute(sql_query, data)
            connection.commit()
            logger.info(f"Data successfully load to rds")
            
        except mysql.connector.Error as error:
            logger.error(f"Error executing SQL query for PID {values['pid']}: {error}")  # 에러 로깅
        except Exception as e:
            logger.error(f"Unexpected error for PID {values['pid']}: {str(e)}")  # 예기치 않은 에러 로깅
    cursor.close()  # 커서 종료
    connection.close()  # 연결 종료

# %%
def find_final_id_list():
    logger.info(f"start getting ids from redis")
    #user function
    id_list_from_redis = get_ids_from_redis()

    # 추가된 id값 list 생성
    # rds id 값 가져와서 비교
    logger.info(f"start getting ids from rds")
    #user function
    id_list_from_rds = get_pid_from_rds()
    list_to_update = compare_id(id_list_from_redis, id_list_from_rds)
    list_to_update = set(id_list_from_redis) - set(id_list_from_rds)
    dynamodb = boto3.resource(
            'dynamodb',
            aws_access_key_id=key['aws_access_key_id'],
            aws_secret_access_key=key['aws_secret_key'],
            region_name=key['region']
        )    
    table = dynamodb.Table('precessed-data-table')
    tmp = table.scan(Select='ALL_ATTRIBUTES')
    precesed_data= list(map(lambda x: str(x['pid']), tmp['Items']))
    final_id = list(set(precesed_data).intersection(list_to_update))
    return final_id

# %%
final_id = find_final_id_list()

# %% [markdown]
# ## DynamoDB ->

# %%
from decimal import Decimal
def get_processed_data(final_id):
    final_id = list(map(Decimal, final_id))
    dynamodb = boto3.resource(
            'dynamodb',
            aws_access_key_id=key['aws_access_key_id'],
            aws_secret_access_key=key['aws_secret_key'],
            region_name=key['region']
        )    
    table = dynamodb.Table('precessed-data-table')
    data = []
    for id in final_id:
        try:
            response = table.query(KeyConditionExpression=Key('pid').eq(id))
            data.append(response['Items'][0])  # 데이터 값을 리스트에 추가
        except ClientError as e:
            print(f"[get_data_from_dynamodb()]ClientError: {e.response['Error']['Message']}")
    #            print(f"ClientError: {e.response['Error']['Message']}")
            continue  # 다음 ID로 이동
        except Exception as e:
            print(f"[get_data_from_dynamodb()]Unexpected error: (id: {id}){str(e)}")
    #            print(f"Unexpected error: (id: {id}){str(e)}")
            continue  # 다음 ID로 이동
    return data

# %%
result = pd.DataFrame(get_processed_data(final_id))

# %%
result
# Out:
#      site_symbol                                     indurstry_type  \
# 0            PRO                      [Technology, Software, Cloud]
# 1            WAN     [Autonomous Driving, Robotics, AI, Technology]
# 2            WAN                            [IT, Software, HR Tech]
# 3             JK  [logistics, delivery, food delivery, outsourci...
# 4             JK  [web development, web design, marketing, adver...
# ...          ...                                                ...
# 1007          JK                                          [Apparel]
# 1008          JK            [telecommunications, marketing, retail]
# 1009          JK                       [telecommunications, retail]
# 1010          JK  [Staffing, Management Consulting, Business Con...
# 1011          JK                   [Construction, Home Improvement]
#
#                                         job_title  \
# 0                               Cloud 인프라 아키텍쳐 담당
# 1     Computer Vision Engineer Autonomous Driving
# 2                          Cloud 인사시스템 개발 및 운영 담당
# 3       연3,150만/인센/정규전환 쿠팡이츠 가맹점 운영 관리 담당자 대규모 채용
# 4                                    워드프레스 개발자 채용
# ...                                           ...
# 1007       데님프로모션 완사입 (DENIM) 영업관리.생산관리 신입 경력직 채용
# 1008             준텔레콤 창원 유튜브 유튜브/숏폼 영상촬영 및 편집자 채용
# 1009                    KT본사직영 KT 플라자 매장 정규직 채용공고
# 1010                 송파구/복지우수 글로벌 외국계 공구 기업 CS 채용
# 1011              부산 층간소음매트 매트시공 신입 모집 2030 젊은 회사
#
#                                            job_category  \
# 0     [Cloud Architect, Solution Architect, Infrastr...
# 1     [Computer Vision Engineer, Research Scientist,...
# 2     [Software Engineer, Backend Developer, Cloud E...
# 3     [customer service, operations, management, adm...
# 4              [web development, wordpress development]
# ...                                                 ...
# 1007   [Sales, Production Management, Fashion, Textile]
# 1008  [video editing, content creation, digital mark...
# 1009  [sales, retail, customer service, telecommunic...
# 1010  [Customer Service, Technical Support, Call Cen...
# 1011              [Construction, Installation, Service]
#
#                                              job_prefer  \
# 0     [SCM / SRM 등 구매 관련 업무 경험, IT 및 AI 산업 시장 변화 동향에...
# 1     [자율 주행 및 로보틱스 관련 연구 개발 경험, GPS, IMU, 카메라, LIDA...
# 2                         [솔루션 운영 및 유지보수 경험, Vue.js 경험]
# 3                                            [관련 경력 우대]
# 4                                                    []
# ...                                                 ...
# 1007                                        [관련 경력자 우대]
# 1008                                                 []
# 1009                                                 []
# 1010                          [영어 능통자 우대, 관련 분야 경력자 우대]
# 1011                                           [2030세대]
#
#                                               crawl_url    end_date  \
# 0     https://career.programmers.co.kr/api/job_posit...
# 1                    https://www.wanted.co.kr/wd/216430
# 2                    https://www.wanted.co.kr/wd/240348
# 3     https://www.jobkorea.co.kr/Recruit/GI_Read/455...  1728777600
# 4     https://www.jobkorea.co.kr/Recruit/GI_Read/455...        None
# ...                                                 ...         ...
# 1007  https://www.jobkorea.co.kr/Recruit/GI_Read/455...        None
# 1008  https://www.jobkorea.co.kr/Recruit/GI_Read/455...  1728777600
# 1009  https://www.jobkorea.co.kr/Recruit/GI_Read/455...  1728777600
# 1010  https://www.jobkorea.co.kr/Recruit/GI_Read/455...  1728950400
# 1011  https://www.jobkorea.co.kr/Recruit/GI_Read/455...  1728658800
#
#              pid post_status required_career  \
# 0     3171239853        True            True
# 1     2042877461
# 2      906695789
# 3     3007989768        None           False
# 4      707219774        None           False
# ...          ...         ...             ...
# 1007  1955750282        None           False
# 1008  1121659660        None           False
# 1009  4185711601        None           False
# 1010  1904068323        None            True
# 1011  2093375407        None           False
#
#                            crawl_domain company_name resume_required  \
# 0     https://career.programmers.co.kr/           엠로            True
# 1                      www.wanted.co.kr  포티투닷(42dot)
# 2                      www.wanted.co.kr        이수시스템
# 3                                  None     에이스휴먼파워㈜            True
# 4                                  None    넛지커뮤니케이션즈            True
# ...                                 ...          ...             ...
# 1007                               None       ㈜인디고라인            True
# 1008                               None        ㈜준텔레콤            True
# 1009                               None     ㈜케이티엠앤에스            True
# 1010                               None      ㈜맨파워코리아            True
# 1011                               None           돌봄            True
#
#       start_date    get_date  \
# 0     2024-04-29    20240828
# 1                 1725864041
# 2                 1725515580
# 3     1726185600  1726538937
# 4     1726185600  1726234283
# ...          ...         ...
# 1007  1726358400  1726452536
# 1008  1726185600  1726234283
# 1009  1726185600  1726234283
# 1010  1726358400  1726452536
# 1011  1726066800  1726123094
#
#                                               dev_stack         cid  \
# 0                  [AWS EC2, Azure, Clean Architecture]  1850949135
# 1                                       [C/C++, Python]  1846198512
# 2     [Java, JSP, JQuery, Oracle DB, Spring framewor...  4067809027
# 3                                                    []   555094931
# 4                                                    []  1652767634
# ...                                                 ...         ...
# 1007                                                 []   438941241
# 1008                                                 []  4034255832
# 1009                                                 []  2232376917
# 1010                                                 []  3973390486
# 1011                                                 []  1564743802
#
#                                        job_requirements
# 0     [학사 학위 취득, Azure/AWS 등 대형 Vendor Cloud 경험, Clo...
# 1     [유관 경력 5년차 이상, 박사 졸업 예정자 지원 가능, 컴퓨터 비전, 로보틱스, ...
# 2     [관련 분야에서 5년 이상의 경력, 솔루션 기반의 운영 및 유지보수 경험, 팀워크 ...
# 3                [쿠팡이츠 가맹점 운영 관리, 고객 응대, 데이터 관리, 문제 해결]
# 4                                            [워드프레스 개발]
# ...                                                 ...
# 1007           [데님 관련 경험, 영업 및 생산 관리 능력, 패션 트렌드에 대한 이해]
# 1008                                [유튜브, 숏폼 영상 촬영, 편집]
# 1009                                   [KT 플라자 매장, 정규직]
# 1010          [고객 상담 경험, 전화 상담 능력, 문제 해결 능력, 커뮤니케이션 능력]
# 1011                             [층간소음매트 시공, 운전면허, 서비스]
#
# [1012 rows x 18 columns]

# %%
import numpy as np
def get_rds_pid_list():
    # RDS 접속 정보
    rds_host = rds_info['host']
    username = rds_info['username']
    password = rds_info['password']
    database = rds_info['database']
    # RDS에 연결
    connection = mysql.connector.connect(
        host=rds_host,
        user=username,
        password=password,
        database=database
    )
    cursor = connection.cursor()
    cursor.execute("SELECT pid FROM job_information")
    a1 = cursor.fetchall()
    rds_pid_list = list(map(lambda x : int(x[0]), list(np.array(a1))))
    cursor.close()
    connection.close()
    return rds_pid_list

# %%
def get_rds_did_list():
    # RDS 접속 정보
    rds_host = rds_info['host']
    username = rds_info['username']
    password = rds_info['password']
    database = rds_info['database']
    # RDS에 연결
    connection = mysql.connector.connect(
        host=rds_host,
        user=username,
        password=password,
        database=database
    )
    cursor = connection.cursor()
    cursor.execute("SELECT did FROM dev_stack")
    a2 = cursor.fetchall()
    rds_did_list = list(map(lambda x : str(x[0]), list(np.array(a2))))
    cursor.close()
    connection.close()
    return rds_did_list

# %%
get_rds_pid_list()
# Out:
# ['1002166931',
#  '1004194211',
#  '1007487304',
#  '1008770164',
#  '1011538068',
#  '1016517998',
#  '1019982009',
#  '1032975379',
#  '1038371436',
#  '1063838531',
#  '1066487499',
#  '1069235713',
#  '1072360246',
#  '1074245989',
#  '107796729',
#  '1078376823',
#  '1078933166',
#  '1094502403',
#  '11033851',
#  '1125012312',
#  '115335239',
#  '1156940915',
#  '116863901',
#  '1169406102',
#  '1171952029',
#  '1177062975',
#  '117958826',
#  '1181601622',
#  '1185761351',
#  '1186934202',
#  '1187277159',
#  '1192613966',
#  '11926471',
#  '1194200153',
#  '119664908',
#  '1196877658',
#  '1208330643',
#  '1216324633',
#  '1239911436',
#  '1243268763',
#  '1248994446',
#  '1254441829',
#  '1254716025',
#  '1259580082',
#  '1260967132',
#  '1271076498',
#  '1284518176',
#  '1287547261',
#  '1295089143',
#  '1299792269',
#  '130033997',
#  '1301926306',
#  '1304596496',
#  '1307116181',
#  '1330064495',
#  '1343586709',
#  '1349004222',
#  '1350729060',
#  '1371076200',
#  '1372828126',
#  '1373153800',
#  '1378927626',
#  '1380415105',
#  '1381429147',
#  '1401323579',
#  '1405285534',
#  '1408637987',
#  '1411291959',
#  '142783217',
#  '1431533054',
#  '1440538849',
#  '1450025646',
#  '1450040320',
#  '1452164681',
#  '1455948838',
#  '1457478252',
#  '1458842847',
#  '1460004241',
#  '1468425216',
#  '1481117790',
#  '1482351075',
#  '1486426563',
#  '1487127095',
#  '1494445823',
#  '1511359921',
#  '1514503624',
#  '1519024124',
#  '152422450',
#  '1538009187',
#  '1551356193',
#  '1554552251',
#  '1557389289',
#  '1557426226',
#  '158224040',
#  '1584358560',
#  '1593146055',
#  '1597356472',
#  '1604565628',
#  '1614327703',
#  '1618026232',
#  '1627531456',
#  '1628883235',
#  '1634584494',
#  '1645607270',
#  '1645983701',
#  '164882419',
#  '1657530626',
#  '1659222261',
#  '1677377143',
#  '168109974',
#  '1694106648',
#  '1696425281',
#  '1699206139',
#  '1709766724',
#  '1712082273',
#  '1716654124',
#  '1718137914',
#  '1739357009',
#  '1746482346',
#  '1766983879',
#  '1767134102',
#  '1770475384',
#  '1771162848',
#  '1775309475',
#  '1780839060',
#  '1783990949',
#  '179584254',
#  '1799734813',
#  '1802182825',
#  '180260616',
#  '182083569',
#  '798295321',
#  '800206637',
#  '802061513',
#  '809244285',
#  '818032378',
#  '823540461',
#  '826461269',
#  '828419886',
#  '828491399',
#  '838085842',
#  '839668629',
#  '858725423',
#  '86267852',
#  '871986318',
#  '874887692',
#  '876312475',
#  '877917518',
#  '879196304',
#  '886574184',
#  '901007858',
#  '907731821',
#  '910021464',
#  '916852985',
#  '918296124',
#  '921463519',
#  '92599749',
#  '932107555',
#  '933581793',
#  '936301732',
#  '940304784',
#  '945453735',
#  '967536817',
#  '970483569',
#  '972276858',
#  '982035668',
#  '99279481',
#  '993441961',
#  '994402269',
#  '996482599']

# %%
def get_did_jobstack(pid):
    # RDS 접속 정보
    rds_host = rds_info['host']
    username = rds_info['username']
    password = rds_info['password']
    database = rds_info['database']
    # RDS에 연결
    connection = mysql.connector.connect(
        host=rds_host,
        user=username,
        password=password,
        database=database
    )
    cursor = connection.cursor()
    sql_query_tmp = f"""
        SELECT did FROM job_stack
        WHERE pid = {pid}
    """
    cursor.execute(sql_query_tmp)
    a3 = cursor.fetchall()
    rds_pid_did = list(map(lambda x : int(x[0]), list(np.array(a3))))
    
    cursor.close()
    connection.close()
    return rds_pid_did

# %%
def get_pid_jobstack():
    # RDS 접속 정보
    rds_host = rds_info['host']
    username = rds_info['username']
    password = rds_info['password']
    database = rds_info['database']
    # RDS에 연결
    connection = mysql.connector.connect(
        host=rds_host,
        user=username,
        password=password,
        database=database
    )
    cursor = connection.cursor()
    sql_query_tmp2 = """
    SELECT pid FROM job_stack
    """
    cursor.execute(sql_query_tmp2)
    a4 = cursor.fetchall()
    pid_list = list(map(lambda x : int(x[0]), list(np.array(a4))))
    cursor.close()
    connection.close()
    return pid_list

# %%
def insert_data(result):
    # RDS 접속 정보
    rds_host = rds_info['host']
    username = rds_info['username']
    password = rds_info['password']
    database = rds_info['database']
    # RDS에 연결
    connection = mysql.connector.connect(
        host=rds_host,
        user=username,
        password=password,
        database=database
    )
    cursor = connection.cursor()
    rds_pid_list= get_rds_pid_list()
    rds_did_list=get_rds_did_list()
    pid_list = get_pid_jobstack()
    
    sql_query = """
        INSERT INTO job_information (
            pid, job_title, site_symbol, job_prefer, crawl_url, start_date, end_date, post_status,
            get_date, required_career, resume_required, crawl_domain, company_name, cid, job_requirements
        ) 
        VALUES (%s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s)
        ON DUPLICATE KEY UPDATE
            pid = VALUES(pid),
            job_title = VALUES(job_title),
            site_symbol = VALUES(site_symbol),
            job_prefer = VALUES(job_prefer),
            crawl_url = VALUES(crawl_url),
            start_date = VALUES(start_date),
            end_date = VALUES(end_date),
            post_status = VALUES(post_status),
            get_date = VALUES(get_date),
            required_career = VALUES(required_career),
            resume_required = VALUES(resume_required),
            crawl_domain = VALUES(crawl_domain),
            cid = VALUES(cid),
            company_name = VALUES(company_name),
            job_requirements = VALUES(job_requirements)
    """
    sql_query2 = """
    INSERT INTO dev_stack (
        did, dev_stack
    ) 
    VALUES (%s, %s)
    ON DUPLICATE KEY UPDATE
        dev_stack = VALUES(dev_stack)
    """
    
    sql_query3 = """
    INSERT INTO job_stack (
        pid, did
    ) 
    VALUES (%s, %s)
    """
    
    for i, values in result.iterrows():
        data = (
            values['pid'],
            values['job_title'],
            values['site_symbol'],
            f"[{', '.join(f"'{item}'" for item in values['job_prefer'])}]"  if isinstance(values['job_prefer'], list) else values['job_prefer'],
            values['crawl_url'],
            values['start_date'],
            values['end_date'],
            values['post_status'],
            values['get_date'],
            values['required_career'],
            values['resume_required'],
            values['crawl_domain'],
            values['cid'],
            values['company_name'],
            f"[{', '.join(f"'{item}'" for item in values['job_requirements'])}]" if isinstance(values['job_requirements'], list) else values['job_requirements']
        )
        try:
            if values['pid'] not in rds_pid_list:
                cursor.execute(sql_query, data)
                connection.commit()
                print(f"Data successfully load to rds")
            else:
                print(f"overload data to rds")
        except mysql.connector.Error as error:
            print(f"Error executing SQL query for PID {values['pid']}: {error}")  # 에러 로깅
        except Exception as e:
            print(f"Unexpected error for PID {values['pid']}: {str(e)}")  # 예기치 않은 에러 로깅
            
        for stack in values['dev_stack']:
            data2 = (str(fhash(stack)), stack)
            data3 = (values['pid'],int(fhash(stack)))
            try:
                if data2[0] not in rds_did_list:
                    cursor.execute(sql_query2, data2)
                    connection.commit()
                    print(f"Data successfully load to rds")
                else:
                    print("Data overload")
            except mysql.connector.Error as error:
                print(f"Error executing SQL query: for dev_stack {stack}: {error}")  # 에러 로깅
            except Exception as e:
                print(f"Unexpected error for dev_stack {stack}: {str(e)}")  # 예기치 않은 에러 로깅
            try:
                if int(data3[0]) in pid_list and data3[1] in get_did_jobstack(values['pid']):
                    print("Data overload")
                else:
                    cursor.execute(sql_query3, data3)
                    connection.commit()
                    print(f"Data successfully load to rds")
            except mysql.connector.Error as error:
                print(f"Error executing SQL query for PID {values['pid']}: {error}")  # 에러 로깅
            except Exception as e:
                print(f"Unexpected error for PID {values['pid']}: {str(e)}")  # 예기치 않은 에러 로깅
    cursor.close()  # 커서 종료
    connection.close()  # 연결 종료

# %%
insert_data(result)
# Out:
# overload data to rds
# Data overload
# Unexpected error for PID 3171239853: name 'pid_list' is not defined
# Data overload
# Unexpected error for PID 3171239853: name 'pid_list' is not defined
# Data overload
# Unexpected error for PID 3171239853: name 'pid_list' is not defined
# overload data to rds
# Data overload
# Unexpected error for PID 2042877461: name 'pid_list' is not defined
# Data overload
# Unexpected error for PID 2042877461: name 'pid_list' is not defined
# overload data to rds
# Data overload
# Unexpected error for PID 906695789: name 'pid_list' is not defined
# Data overload
# Unexpected error for PID 906695789: name 'pid_list' is not defined
# Data overload
# Unexpected error for PID 906695789: name 'pid_list' is not defined
# Data overload
# Unexpected error for PID 906695789: name 'pid_list' is not defined
# Data overload
# Unexpected error for PID 906695789: name 'pid_list' is not defined
# Data overload
# Unexpected error for PID 906695789: name 'pid_list' is not defined
# Data overload
# Unexpected error for PID 906695789: name 'pid_list' is not defined
# overload data to rds
# overload data to rds
# overload data to rds
# overload data to rds
# overload data to rds
# overload data to rds
# overload data to rds
# Data overload
# Unexpected error for PID 3455204151: name 'pid_list' is not defined
# Data overload
# Unexpected error for PID 3455204151: name 'pid_list' is not defined
# Data overload
# Unexpected error for PID 3455204151: name 'pid_list' is not defined
# Data overload
# Unexpected error for PID 3455204151: name 'pid_list' is not defined
# Data overload
# Unexpected error for PID 3455204151: name 'pid_list' is not defined
# Data overload
# Unexpected error for PID 3455204151: name 'pid_list' is not defined
# Data overload
# Unexpected error for PID 3455204151: name 'pid_list' is not defined
# Data overload
# Unexpected error for PID 3455204151: name 'pid_list' is not defined
# Data overload
# Unexpected error for PID 3455204151: name 'pid_list' is not defined
# overload data to rds
# overload data to rds
# overload data to rds
# overload data to rds
# overload data to rds
# overload data to rds
# overload data to rds
# overload data to rds
# overload data to rds
# Data overload
# Unexpected error for PID 991170038: name 'pid_list' is not defined
# Data overload
# Unexpected error for PID 991170038: name 'pid_list' is not defined
# Data overload
# Unexpected error for PID 991170038: name 'pid_list' is not defined
# Data overload
# Unexpected error for PID 991170038: name 'pid_list' is not defined
# Data overload
# Unexpected error for PID 991170038: name 'pid_list' is not defined
# Data overload
# Unexpected error for PID 991170038: name 'pid_list' is not defined
# Data overload
# Unexpected error for PID 991170038: name 'pid_list' is not defined
# Data overload
# Unexpected error for PID 991170038: name 'pid_list' is not defined
# Data overload
# Unexpected error for PID 991170038: name 'pid_list' is not defined
# Data overload
# Unexpected error for PID 991170038: name 'pid_list' is not defined
# Data overload
# Unexpected error for PID 991170038: name 'pid_list' is not defined
# Data overload
# Unexpected error for PID 991170038: name 'pid_list' is not defined
# Data overload
# Unexpected error for PID 991170038: name 'pid_list' is not defined
# Data overload
# Unexpected error for PID 991170038: name 'pid_list' is not defined
# Data overload
# Unexpected error for PID 991170038: name 'pid_list' is not defined
# overload data to rds
# overload data to rds
# overload data to rds
# Data overload
# Unexpected error for PID 4175906951: name 'pid_list' is not defined
# Data overload
# Unexpected error for PID 4175906951: name 'pid_list' is not defined
# Data overload
# Unexpected error for PID 4175906951: name 'pid_list' is not defined
# overload data to rds
# overload data to rds
# overload data to rds
# overload data to rds
# Data overload
# Unexpected error for PID 964155716: name 'pid_list' is not defined
# Data overload
# Unexpected error for PID 964155716: name 'pid_list' is not defined
# Data overload
# Unexpected error for PID 964155716: name 'pid_list' is not defined
# Data overload
# Unexpected error for PID 964155716: name 'pid_list' is not defined
# Data overload
# Unexpected error for PID 964155716: name 'pid_list' is not defined
# Data overload
# Unexpected error for PID 964155716: name 'pid_list' is not defined
# Data overload
# Unexpected error for PID 964155716: name 'pid_list' is not defined
# Data overload
# Unexpected error for PID 964155716: name 'pid_list' is not defined
# Data overload
# Unexpected error for PID 964155716: name 'pid_list' is not defined
# overload data to rds
# overload data to rds
# overload data to rds
# overload data to rds
# overload data to rds
# overload data to rds
# overload data to rds
# overload data to rds
# overload data to rds
# overload data to rds
# overload data to rds
# Data overload
# Unexpected error for PID 3805403281: name 'pid_list' is not defined
# Data overload
# Unexpected error for PID 3805403281: name 'pid_list' is not defined
# Data overload
# Unexpected error for PID 3805403281: name 'pid_list' is not defined
# Data overload
# Unexpected error for PID 3805403281: name 'pid_list' is not defined
# Data overload
# Unexpected error for PID 3805403281: name 'pid_list' is not defined
# Data overload
# Unexpected error for PID 3805403281: name 'pid_list' is not defined
# Data overload
# Unexpected error for PID 3805403281: name 'pid_list' is not defined
# overload data to rds
# Data overload
# Unexpected error for PID 597084087: name 'pid_list' is not defined
# Data overload
# Unexpected error for PID 597084087: name 'pid_list' is not defined
# Data overload
# Unexpected error for PID 597084087: name 'pid_list' is not defined
# Data overload
# Unexpected error for PID 597084087: name 'pid_list' is not defined
# Data overload
# Unexpected error for PID 597084087: name 'pid_list' is not defined
# overload data to rds
# Data overload
# Unexpected error for PID 329581027: name 'pid_list' is not defined
# Data overload
# Unexpected error for PID 329581027: name 'pid_list' is not defined
# Data overload
# Unexpected error for PID 329581027: name 'pid_list' is not defined
# overload data to rds
# overload data to rds
# overload data to rds
# Data overload
# Unexpected error for PID 2893773838: name 'pid_list' is not defined
# Data overload
# Unexpected error for PID 2893773838: name 'pid_list' is not defined
# Data overload
# Unexpected error for PID 2893773838: name 'pid_list' is not defined
# Data overload
# Unexpected error for PID 2893773838: name 'pid_list' is not defined
# overload data to rds
# Data overload
# Unexpected error for PID 2197229536: name 'pid_list' is not defined
# Data overload
# Unexpected error for PID 2197229536: name 'pid_list' is not defined
# Data overload
# Unexpected error for PID 2197229536: name 'pid_list' is not defined
# Data overload
# Unexpected error for PID 2197229536: name 'pid_list' is not defined
# Data overload
# Unexpected error for PID 2197229536: name 'pid_list' is not defined
# Data overload
# Unexpected error for PID 2197229536: name 'pid_list' is not defined
# overload data to rds
# Data overload
# Unexpected error for PID 357099481: name 'pid_list' is not defined
# Data overload
# Unexpected error for PID 357099481: name 'pid_list' is not defined
# Data overload
# Unexpected error for PID 357099481: name 'pid_list' is not defined
# Data overload
# Unexpected error for PID 357099481: name 'pid_list' is not defined
# Data overload
# Unexpected error for PID 357099481: name 'pid_list' is not defined
# overload data to rds
# overload data to rds
# overload data to rds
# overload data to rds
# Data overload
# Unexpected error for PID 3745347267: name 'pid_list' is not defined
# Data overload
# Unexpected error for PID 3745347267: name 'pid_list' is not defined
# Data overload
# Unexpected error for PID 3745347267: name 'pid_list' is not defined
# Data overload
# Unexpected error for PID 3745347267: name 'pid_list' is not defined
# Data overload
# Unexpected error for PID 3745347267: name 'pid_list' is not defined
# Data overload
# Unexpected error for PID 3745347267: name 'pid_list' is not defined
# Data overload
# Unexpected error for PID 3745347267: name 'pid_list' is not defined
# Data overload
# Unexpected error for PID 3745347267: name 'pid_list' is not defined
# Data overload
# Unexpected error for PID 3745347267: name 'pid_list' is not defined
# Data overload
# Unexpected error for PID 3745347267: name 'pid_list' is not defined
# Data overload
# Unexpected error for PID 3745347267: name 'pid_list' is not defined
# Data overload
# Unexpected error for PID 3745347267: name 'pid_list' is not defined
# overload data to rds
# overload data to rds
# Data overload
# Unexpected error for PID 3604010863: name 'pid_list' is not defined
# Data overload
# Unexpected error for PID 3604010863: name 'pid_list' is not defined
# Data overload
# Unexpected error for PID 3604010863: name 'pid_list' is not defined
# Data overload
# Unexpected error for PID 3604010863: name 'pid_list' is not defined
# Data overload
# Unexpected error for PID 3604010863: name 'pid_list' is not defined
# Data overload
# Unexpected error for PID 3604010863: name 'pid_list' is not defined
# Data overload
# Unexpected error for PID 3604010863: name 'pid_list' is not defined
# overload data to rds
# Data overload
# Unexpected error for PID 2258612626: name 'pid_list' is not defined
# Data overload
# Unexpected error for PID 2258612626: name 'pid_list' is not defined
# Data overload
# Unexpected error for PID 2258612626: name 'pid_list' is not defined
# Data overload
# Unexpected error for PID 2258612626: name 'pid_list' is not defined
# Data overload
# Unexpected error for PID 2258612626: name 'pid_list' is not defined
# Data overload
# Unexpected error for PID 2258612626: name 'pid_list' is not defined
# Data overload
# Unexpected error for PID 2258612626: name 'pid_list' is not defined
# Data overload
# Unexpected error for PID 2258612626: name 'pid_list' is not defined
# Data overload
# Unexpected error for PID 2258612626: name 'pid_list' is not defined
# Data overload
# Unexpected error for PID 2258612626: name 'pid_list' is not defined
# Data overload
# Unexpected error for PID 2258612626: name 'pid_list' is not defined
# overload data to rds
# overload data to rds
# overload data to rds
# overload data to rds
# Data overload
# Unexpected error for PID 3485021815: name 'pid_list' is not defined
# Data overload
# Unexpected error for PID 3485021815: name 'pid_list' is not defined
# Data overload
# Unexpected error for PID 3485021815: name 'pid_list' is not defined
# Data overload
# Unexpected error for PID 3485021815: name 'pid_list' is not defined
# Data overload
# Unexpected error for PID 3485021815: name 'pid_list' is not defined
# Data overload
# Unexpected error for PID 3485021815: name 'pid_list' is not defined
# Data overload
# Unexpected error for PID 3485021815: name 'pid_list' is not defined
# Data overload
# Unexpected error for PID 3485021815: name 'pid_list' is not defined
# Data overload
# Unexpected error for PID 3485021815: name 'pid_list' is not defined
# Data overload
# Unexpected error for PID 3485021815: name 'pid_list' is not defined
# Data overload
# Unexpected error for PID 3485021815: name 'pid_list' is not defined
# Data overload
# Unexpected error for PID 3485021815: name 'pid_list' is not defined
# Data overload
# Unexpected error for PID 3485021815: name 'pid_list' is not defined
# overload data to rds
# overload data to rds
# overload data to rds
# overload data to rds
# Data overload
# Unexpected error for PID 1663466789: name 'pid_list' is not defined
# Data overload
# Unexpected error for PID 1663466789: name 'pid_list' is not defined
# Data overload
# Unexpected error for PID 1663466789: name 'pid_list' is not defined
# overload data to rds
# overload data to rds
# overload data to rds
# Data overload
# Unexpected error for PID 3971088713: name 'pid_list' is not defined
# Data overload
# Unexpected error for PID 3971088713: name 'pid_list' is not defined
# Data overload
# Unexpected error for PID 3971088713: name 'pid_list' is not defined
# Data overload
# Unexpected error for PID 3971088713: name 'pid_list' is not defined
# Data overload
# Unexpected error for PID 3971088713: name 'pid_list' is not defined
# Data overload
# Unexpected error for PID 3971088713: name 'pid_list' is not defined
# overload data to rds
# overload data to rds
# overload data to rds
# overload data to rds
# overload data to rds
# overload data to rds
# overload data to rds
# overload data to rds
# overload data to rds
# overload data to rds
# Data overload
# Unexpected error for PID 2181768952: name 'pid_list' is not defined
# Data overload
# Unexpected error for PID 2181768952: name 'pid_list' is not defined
# Data overload
# Unexpected error for PID 2181768952: name 'pid_list' is not defined
# Data overload
# Unexpected error for PID 2181768952: name 'pid_list' is not defined
# Data overload
# Unexpected error for PID 2181768952: name 'pid_list' is not defined
# Data overload
# Unexpected error for PID 2181768952: name 'pid_list' is not defined
# Data overload
# Unexpected error for PID 2181768952: name 'pid_list' is not defined
# Data overload
# Unexpected error for PID 2181768952: name 'pid_list' is not defined
# Data overload
# Unexpected error for PID 2181768952: name 'pid_list' is not defined
# Data overload
# Unexpected error for PID 2181768952: name 'pid_list' is not defined
# Data overload
# Unexpected error for PID 2181768952: name 'pid_list' is not defined
# overload data to rds
# Data overload
# Unexpected error for PID 4158834418: name 'pid_list' is not defined
# Data overload
# Unexpected error for PID 4158834418: name 'pid_list' is not defined
# Data overload
# Unexpected error for PID 4158834418: name 'pid_list' is not defined
# Data overload
# Unexpected error for PID 4158834418: name 'pid_list' is not defined
# Data overload
# Unexpected error for PID 4158834418: name 'pid_list' is not defined
# Data overload
# Unexpected error for PID 4158834418: name 'pid_list' is not defined
# Data overload
# Unexpected error for PID 4158834418: name 'pid_list' is not defined
# Data overload
# Unexpected error for PID 4158834418: name 'pid_list' is not defined
# Data overload
# Unexpected error for PID 4158834418: name 'pid_list' is not defined
# Data overload
# Unexpected error for PID 4158834418: name 'pid_list' is not defined
# Data overload
# Unexpected error for PID 4158834418: name 'pid_list' is not defined
# Data overload
# Unexpected error for PID 4158834418: name 'pid_list' is not defined
# Data overload
# Unexpected error for PID 4158834418: name 'pid_list' is not defined
# Data overload
# Unexpected error for PID 4158834418: name 'pid_list' is not defined
# overload data to rds
# overload data to rds
# Data overload
# Unexpected error for PID 4079983392: name 'pid_list' is not defined
# Data overload
# Unexpected error for PID 4079983392: name 'pid_list' is not defined
# Data overload
# Unexpected error for PID 4079983392: name 'pid_list' is not defined
# Data overload
# Unexpected error for PID 4079983392: name 'pid_list' is not defined
# Data overload
# Unexpected error for PID 4079983392: name 'pid_list' is not defined
# Data overload
# Unexpected error for PID 4079983392: name 'pid_list' is not defined
# Data overload
# Unexpected error for PID 4079983392: name 'pid_list' is not defined
# Data overload
# Unexpected error for PID 4079983392: name 'pid_list' is not defined
# overload data to rds
# overload data to rds
# overload data to rds
# Data overload
# Unexpected error for PID 1177260406: name 'pid_list' is not defined
# Data overload
# Unexpected error for PID 1177260406: name 'pid_list' is not defined
# overload data to rds
# overload data to rds
# overload data to rds
# overload data to rds
# overload data to rds
# overload data to rds
# overload data to rds
# overload data to rds
# overload data to rds
# overload data to rds
# overload data to rds
# overload data to rds
# overload data to rds
# overload data to rds
# Data overload
# Unexpected error for PID 3887869151: name 'pid_list' is not defined
# Data overload
# Unexpected error for PID 3887869151: name 'pid_list' is not defined
# Data overload
# Unexpected error for PID 3887869151: name 'pid_list' is not defined
# Data overload
# Unexpected error for PID 3887869151: name 'pid_list' is not defined
# Data overload
# Unexpected error for PID 3887869151: name 'pid_list' is not defined
# Data overload
# Unexpected error for PID 3887869151: name 'pid_list' is not defined
# Data overload
# Unexpected error for PID 3887869151: name 'pid_list' is not defined
# Data overload
# Unexpected error for PID 3887869151: name 'pid_list' is not defined
# Data overload
# Unexpected error for PID 3887869151: name 'pid_list' is not defined
# Data overload
# Unexpected error for PID 3887869151: name 'pid_list' is not defined
# overload data to rds
# overload data to rds
# Data overload
# Unexpected error for PID 3670248345: name 'pid_list' is not defined
# Data overload
# Unexpected error for PID 3670248345: name 'pid_list' is not defined
# Data overload
# Unexpected error for PID 3670248345: name 'pid_list' is not defined
# Data overload
# Unexpected error for PID 3670248345: name 'pid_list' is not defined
# Data overload
# Unexpected error for PID 3670248345: name 'pid_list' is not defined
# overload data to rds
# overload data to rds
# overload data to rds
# overload data to rds
# Data overload
# Unexpected error for PID 227379723: name 'pid_list' is not defined
# Data overload
# Unexpected error for PID 227379723: name 'pid_list' is not defined
# Data overload
# Unexpected error for PID 227379723: name 'pid_list' is not defined
# Data overload
# Unexpected error for PID 227379723: name 'pid_list' is not defined
# Data overload
# Unexpected error for PID 227379723: name 'pid_list' is not defined
# Data overload
# Unexpected error for PID 227379723: name 'pid_list' is not defined
# Data overload
# Unexpected error for PID 227379723: name 'pid_list' is not defined
# Data overload
# Unexpected error for PID 227379723: name 'pid_list' is not defined
# Data overload
# Unexpected error for PID 227379723: name 'pid_list' is not defined
# overload data to rds
# overload data to rds
# overload data to rds
# overload data to rds
# overload data to rds
# overload data to rds
# overload data to rds
# Data overload
# Unexpected error for PID 2663840165: name 'pid_list' is not defined
# Data overload
# Unexpected error for PID 2663840165: name 'pid_list' is not defined
# Data overload
# Unexpected error for PID 2663840165: name 'pid_list' is not defined
# Data overload
# Unexpected error for PID 2663840165: name 'pid_list' is not defined
# Data overload
# Unexpected error for PID 2663840165: name 'pid_list' is not defined
# Data overload
# Unexpected error for PID 2663840165: name 'pid_list' is not defined
# overload data to rds
# Data overload
# Unexpected error for PID 1519634658: name 'pid_list' is not defined
# Data overload
# Unexpected error for PID 1519634658: name 'pid_list' is not defined
# Data overload
# Unexpected error for PID 1519634658: name 'pid_list' is not defined
# Data overload
# Unexpected error for PID 1519634658: name 'pid_list' is not defined
# Data overload
# Unexpected error for PID 1519634658: name 'pid_list' is not defined
# Data overload
# Unexpected error for PID 1519634658: name 'pid_list' is not defined
# Data overload
# Unexpected error for PID 1519634658: name 'pid_list' is not defined
# overload data to rds
# Data overload
# Unexpected error for PID 4146781914: name 'pid_list' is not defined
# Data overload
# Unexpected error for PID 4146781914: name 'pid_list' is not defined
# Data overload
# Unexpected error for PID 4146781914: name 'pid_list' is not defined
# Data overload
# Unexpected error for PID 4146781914: name 'pid_list' is not defined
# Data overload
# Unexpected error for PID 4146781914: name 'pid_list' is not defined
# Data overload
# Unexpected error for PID 4146781914: name 'pid_list' is not defined
# Data overload
# Unexpected error for PID 4146781914: name 'pid_list' is not defined
# Data overload
# Unexpected error for PID 4146781914: name 'pid_list' is not defined
# overload data to rds
# Data overload
# Unexpected error for PID 474584302: name 'pid_list' is not defined
# Data overload
# Unexpected error for PID 474584302: name 'pid_list' is not defined
# Data overload
# Unexpected error for PID 474584302: name 'pid_list' is not defined
# Data overload
# Unexpected error for PID 474584302: name 'pid_list' is not defined
# Data overload
# Unexpected error for PID 474584302: name 'pid_list' is not defined
# Data overload
# Unexpected error for PID 474584302: name 'pid_list' is not defined
# Data overload
# Unexpected error for PID 474584302: name 'pid_list' is not defined
# Data overload
# Unexpected error for PID 474584302: name 'pid_list' is not defined
# overload data to rds
# overload data to rds
# overload data to rds
# overload data to rds
# overload data to rds
# Data overload
# Unexpected error for PID 1546707523: name 'pid_list' is not defined
# Data overload
# Unexpected error for PID 1546707523: name 'pid_list' is not defined
# Data overload
# Unexpected error for PID 1546707523: name 'pid_list' is not defined
# Data overload
# Unexpected error for PID 1546707523: name 'pid_list' is not defined
# Data overload
# Unexpected error for PID 1546707523: name 'pid_list' is not defined
# Data overload
# Unexpected error for PID 1546707523: name 'pid_list' is not defined
# Data overload
# Unexpected error for PID 1546707523: name 'pid_list' is not defined
# Data overload
# Unexpected error for PID 1546707523: name 'pid_list' is not defined
# Data overload
# Unexpected error for PID 1546707523: name 'pid_list' is not defined
# Data overload
# Unexpected error for PID 1546707523: name 'pid_list' is not defined
# Data overload
# Unexpected error for PID 1546707523: name 'pid_list' is not defined
# Data overload
# Unexpected error for PID 1546707523: name 'pid_list' is not defined
# Data overload
# Unexpected error for PID 1546707523: name 'pid_list' is not defined
# Data overload
# Unexpected error for PID 1546707523: name 'pid_list' is not defined
# Data overload
# Unexpected error for PID 1546707523: name 'pid_list' is not defined
# Data overload
# Unexpected error for PID 1546707523: name 'pid_list' is not defined
# Data overload
# Unexpected error for PID 1546707523: name 'pid_list' is not defined
# overload data to rds
# overload data to rds
# overload data to rds
# overload data to rds
# overload data to rds
# overload data to rds
# overload data to rds
# overload data to rds
# overload data to rds
# overload data to rds
# overload data to rds
# overload data to rds
# overload data to rds
# overload data to rds
# overload data to rds
# overload data to rds
# overload data to rds
# overload data to rds
# overload data to rds
# overload data to rds
# Data overload
# Unexpected error for PID 3102377904: name 'pid_list' is not defined
# Data overload
# Unexpected error for PID 3102377904: name 'pid_list' is not defined
# Data overload
# Unexpected error for PID 3102377904: name 'pid_list' is not defined
# Data overload
# Unexpected error for PID 3102377904: name 'pid_list' is not defined
# Data overload
# Unexpected error for PID 3102377904: name 'pid_list' is not defined
# Data overload
# Unexpected error for PID 3102377904: name 'pid_list' is not defined
# Data overload
# Unexpected error for PID 3102377904: name 'pid_list' is not defined
# Data overload
# Unexpected error for PID 3102377904: name 'pid_list' is not defined
# Data overload
# Unexpected error for PID 3102377904: name 'pid_list' is not defined
# Data overload
# Unexpected error for PID 3102377904: name 'pid_list' is not defined
# Data overload
# Unexpected error for PID 3102377904: name 'pid_list' is not defined
# Data overload
# Unexpected error for PID 3102377904: name 'pid_list' is not defined
# Data overload
# Unexpected error for PID 3102377904: name 'pid_list' is not defined
# Data overload
# Unexpected error for PID 3102377904: name 'pid_list' is not defined
# Data overload
# Unexpected error for PID 3102377904: name 'pid_list' is not defined
# Data overload
# Unexpected error for PID 3102377904: name 'pid_list' is not defined
# overload data to rds
# overload data to rds
# overload data to rds
# Data overload
# Unexpected error for PID 3546010089: name 'pid_list' is not defined
# Data overload
# Unexpected error for PID 3546010089: name 'pid_list' is not defined
# Data overload
# Unexpected error for PID 3546010089: name 'pid_list' is not defined
# Data overload
# Unexpected error for PID 3546010089: name 'pid_list' is not defined
# Data overload
# Unexpected error for PID 3546010089: name 'pid_list' is not defined
# Data overload
# Unexpected error for PID 3546010089: name 'pid_list' is not defined
# Data overload
# Unexpected error for PID 3546010089: name 'pid_list' is not defined
# Data overload
# Unexpected error for PID 3546010089: name 'pid_list' is not defined
# overload data to rds
# overload data to rds
# overload data to rds
# overload data to rds
# overload data to rds
# overload data to rds
# overload data to rds
# overload data to rds
# overload data to rds
# overload data to rds
# Data overload
# Unexpected error for PID 3570456049: name 'pid_list' is not defined
# Data overload
# Unexpected error for PID 3570456049: name 'pid_list' is not defined
# Data overload
# Unexpected error for PID 3570456049: name 'pid_list' is not defined
# Data overload
# Unexpected error for PID 3570456049: name 'pid_list' is not defined
# Data overload
# Unexpected error for PID 3570456049: name 'pid_list' is not defined
# Data overload
# Unexpected error for PID 3570456049: name 'pid_list' is not defined
# overload data to rds
# overload data to rds
# overload data to rds
# overload data to rds
# overload data to rds
# overload data to rds
# overload data to rds
# overload data to rds
# overload data to rds
# overload data to rds
# overload data to rds
# overload data to rds
# overload data to rds
# overload data to rds
# overload data to rds
# overload data to rds
# overload data to rds
# overload data to rds
# overload data to rds
# Data overload
# Unexpected error for PID 609105248: name 'pid_list' is not defined
# Data overload
# Unexpected error for PID 609105248: name 'pid_list' is not defined
# Data overload
# Unexpected error for PID 609105248: name 'pid_list' is not defined
# Data overload
# Unexpected error for PID 609105248: name 'pid_list' is not defined
# Data overload
# Unexpected error for PID 609105248: name 'pid_list' is not defined
# Data overload
# Unexpected error for PID 609105248: name 'pid_list' is not defined
# Data overload
# Unexpected error for PID 609105248: name 'pid_list' is not defined
# Data overload
# Unexpected error for PID 609105248: name 'pid_list' is not defined
# Data overload
# Unexpected error for PID 609105248: name 'pid_list' is not defined
# Data overload
# Unexpected error for PID 609105248: name 'pid_list' is not defined
# Data overload
# Unexpected error for PID 609105248: name 'pid_list' is not defined
# Data overload
# Unexpected error for PID 609105248: name 'pid_list' is not defined
# Data overload
# Unexpected error for PID 609105248: name 'pid_list' is not defined
# Data overload
# Unexpected error for PID 609105248: name 'pid_list' is not defined
# Data overload
# Unexpected error for PID 609105248: name 'pid_list' is not defined
# overload data to rds
# overload data to rds
# Data overload
# Unexpected error for PID 2028063164: name 'pid_list' is not defined
# Data overload
# Unexpected error for PID 2028063164: name 'pid_list' is not defined
# Data overload
# Unexpected error for PID 2028063164: name 'pid_list' is not defined
# Data overload
# Unexpected error for PID 2028063164: name 'pid_list' is not defined
# Data overload
# Unexpected error for PID 2028063164: name 'pid_list' is not defined
# Data overload
# Unexpected error for PID 2028063164: name 'pid_list' is not defined
# Data overload
# Unexpected error for PID 2028063164: name 'pid_list' is not defined
# Data overload
# Unexpected error for PID 2028063164: name 'pid_list' is not defined
# Data overload
# Unexpected error for PID 2028063164: name 'pid_list' is not defined
# Data overload
# Unexpected error for PID 2028063164: name 'pid_list' is not defined
# Data overload
# Unexpected error for PID 2028063164: name 'pid_list' is not defined
# Data overload
# Unexpected error for PID 2028063164: name 'pid_list' is not defined
# Data overload
# Unexpected error for PID 2028063164: name 'pid_list' is not defined
# Data overload
# Unexpected error for PID 2028063164: name 'pid_list' is not defined
# Data overload
# Unexpected error for PID 2028063164: name 'pid_list' is not defined
# Data overload
# Unexpected error for PID 2028063164: name 'pid_list' is not defined
# Data overload
# Unexpected error for PID 2028063164: name 'pid_list' is not defined
# Data overload
# Unexpected error for PID 2028063164: name 'pid_list' is not defined
# Data overload
# Unexpected error for PID 2028063164: name 'pid_list' is not defined
# Data overload
# Unexpected error for PID 2028063164: name 'pid_list' is not defined
# Data overload
# Unexpected error for PID 2028063164: name 'pid_list' is not defined
# Data overload
# Unexpected error for PID 2028063164: name 'pid_list' is not defined
# Data overload
# Unexpected error for PID 2028063164: name 'pid_list' is not defined
# overload data to rds
# overload data to rds
# Data overload
# Unexpected error for PID 1937733638: name 'pid_list' is not defined
# Data overload
# Unexpected error for PID 1937733638: name 'pid_list' is not defined
# Data overload
# Unexpected error for PID 1937733638: name 'pid_list' is not defined
# Data overload
# Unexpected error for PID 1937733638: name 'pid_list' is not defined
# Data overload
# Unexpected error for PID 1937733638: name 'pid_list' is not defined
# Data overload
# Unexpected error for PID 1937733638: name 'pid_list' is not defined
# Data overload
# Unexpected error for PID 1937733638: name 'pid_list' is not defined
# overload data to rds
# overload data to rds
# overload data to rds
# Data overload
# Unexpected error for PID 1230832045: name 'pid_list' is not defined
# Data overload
# Unexpected error for PID 1230832045: name 'pid_list' is not defined
# Data overload
# Unexpected error for PID 1230832045: name 'pid_list' is not defined
# Data overload
# Unexpected error for PID 1230832045: name 'pid_list' is not defined
# Data overload
# Unexpected error for PID 1230832045: name 'pid_list' is not defined
# Data overload
# Unexpected error for PID 1230832045: name 'pid_list' is not defined
# Data overload
# Unexpected error for PID 1230832045: name 'pid_list' is not defined
# Data overload
# Unexpected error for PID 1230832045: name 'pid_list' is not defined
# overload data to rds
# overload data to rds
# overload data to rds
# Data overload
# Unexpected error for PID 1061892312: name 'pid_list' is not defined
# Data overload
# Unexpected error for PID 1061892312: name 'pid_list' is not defined
# Data overload
# Unexpected error for PID 1061892312: name 'pid_list' is not defined
# Data overload
# Unexpected error for PID 1061892312: name 'pid_list' is not defined
# Data overload
# Unexpected error for PID 1061892312: name 'pid_list' is not defined
# Data overload
# Unexpected error for PID 1061892312: name 'pid_list' is not defined
# overload data to rds
# overload data to rds
# Data overload
# Unexpected error for PID 2993992607: name 'pid_list' is not defined
# Data overload
# Unexpected error for PID 2993992607: name 'pid_list' is not defined
# Data overload
# Unexpected error for PID 2993992607: name 'pid_list' is not defined
# Data overload
# Unexpected error for PID 2993992607: name 'pid_list' is not defined
# Data overload
# Unexpected error for PID 2993992607: name 'pid_list' is not defined
# Data overload
# Unexpected error for PID 2993992607: name 'pid_list' is not defined
# overload data to rds
# overload data to rds
# overload data to rds
# overload data to rds
# overload data to rds
# overload data to rds
# overload data to rds
# Data overload
# Unexpected error for PID 396310286: name 'pid_list' is not defined
# Data overload
# Unexpected error for PID 396310286: name 'pid_list' is not defined
# Data overload
# Unexpected error for PID 396310286: name 'pid_list' is not defined
# Data overload
# Unexpected error for PID 396310286: name 'pid_list' is not defined
# Data overload
# Unexpected error for PID 396310286: name 'pid_list' is not defined
# Data overload
# Unexpected error for PID 396310286: name 'pid_list' is not defined
# Data overload
# Unexpected error for PID 396310286: name 'pid_list' is not defined
# overload data to rds
# overload data to rds
# overload data to rds
# overload data to rds
# Data overload
# Unexpected error for PID 3684088338: name 'pid_list' is not defined
# Data overload
# Unexpected error for PID 3684088338: name 'pid_list' is not defined
# Data overload
# Unexpected error for PID 3684088338: name 'pid_list' is not defined
# Data overload
# Unexpected error for PID 3684088338: name 'pid_list' is not defined
# Data overload
# Unexpected error for PID 3684088338: name 'pid_list' is not defined
# Data overload
# Unexpected error for PID 3684088338: name 'pid_list' is not defined
# Data overload
# Unexpected error for PID 3684088338: name 'pid_list' is not defined
# Data overload
# Unexpected error for PID 3684088338: name 'pid_list' is not defined
# Data overload
# Unexpected error for PID 3684088338: name 'pid_list' is not defined
# Data overload
# Unexpected error for PID 3684088338: name 'pid_list' is not defined
# Data overload
# Unexpected error for PID 3684088338: name 'pid_list' is not defined
# Data overload
# Unexpected error for PID 3684088338: name 'pid_list' is not defined
# overload data to rds
# overload data to rds
# overload data to rds
# overload data to rds
# overload data to rds
# overload data to rds
# overload data to rds
# overload data to rds
# Data overload
# Unexpected error for PID 216761773: name 'pid_list' is not defined
# Data overload
# Unexpected error for PID 216761773: name 'pid_list' is not defined
# Data overload
# Unexpected error for PID 216761773: name 'pid_list' is not defined
# Data overload
# Unexpected error for PID 216761773: name 'pid_list' is not defined
# Data overload
# Unexpected error for PID 216761773: name 'pid_list' is not defined
# Data overload
# Unexpected error for PID 216761773: name 'pid_list' is not defined
# Data overload
# Unexpected error for PID 216761773: name 'pid_list' is not defined
# Data overload
# Unexpected error for PID 216761773: name 'pid_list' is not defined
# Data overload
# Unexpected error for PID 216761773: name 'pid_list' is not defined
# Data overload
# Unexpected error for PID 216761773: name 'pid_list' is not defined
# Data overload
# Unexpected error for PID 216761773: name 'pid_list' is not defined
# Data overload
# Unexpected error for PID 216761773: name 'pid_list' is not defined
# Data overload
# Unexpected error for PID 216761773: name 'pid_list' is not defined
# overload data to rds
# overload data to rds
# overload data to rds
# Data overload
# Unexpected error for PID 3137440715: name 'pid_list' is not defined
# Data overload
# Unexpected error for PID 3137440715: name 'pid_list' is not defined
# overload data to rds
# Data overload
# Unexpected error for PID 2788585638: name 'pid_list' is not defined
# Data overload
# Unexpected error for PID 2788585638: name 'pid_list' is not defined
# Data overload
# Unexpected error for PID 2788585638: name 'pid_list' is not defined
# Data overload
# Unexpected error for PID 2788585638: name 'pid_list' is not defined
# overload data to rds
# overload data to rds
# Data overload
# Unexpected error for PID 3069007171: name 'pid_list' is not defined
# Data overload
# Unexpected error for PID 3069007171: name 'pid_list' is not defined
# Data overload
# Unexpected error for PID 3069007171: name 'pid_list' is not defined
# Data overload
# Unexpected error for PID 3069007171: name 'pid_list' is not defined
# overload data to rds
# Data overload
# Unexpected error for PID 1581157140: name 'pid_list' is not defined
# Data overload
# Unexpected error for PID 1581157140: name 'pid_list' is not defined
# Data overload
# Unexpected error for PID 1581157140: name 'pid_list' is not defined
# Data overload
# Unexpected error for PID 1581157140: name 'pid_list' is not defined
# Data overload
# Unexpected error for PID 1581157140: name 'pid_list' is not defined
# Data overload
# Unexpected error for PID 1581157140: name 'pid_list' is not defined
# Data overload
# Unexpected error for PID 1581157140: name 'pid_list' is not defined
# overload data to rds
# overload data to rds
# Data overload
# Unexpected error for PID 2956743923: name 'pid_list' is not defined
# Data overload
# Unexpected error for PID 2956743923: name 'pid_list' is not defined
# Data overload
# Unexpected error for PID 2956743923: name 'pid_list' is not defined
# Data overload
# Unexpected error for PID 2956743923: name 'pid_list' is not defined
# Data overload
# Unexpected error for PID 2956743923: name 'pid_list' is not defined
# Data overload
# Unexpected error for PID 2956743923: name 'pid_list' is not defined
# overload data to rds
# Data overload
# Unexpected error for PID 2709134365: name 'pid_list' is not defined
# Data overload
# Unexpected error for PID 2709134365: name 'pid_list' is not defined
# Data overload
# Unexpected error for PID 2709134365: name 'pid_list' is not defined
# Data overload
# Unexpected error for PID 2709134365: name 'pid_list' is not defined
# Data overload
# Unexpected error for PID 2709134365: name 'pid_list' is not defined
# Data overload
# Unexpected error for PID 2709134365: name 'pid_list' is not defined
# Data overload
# Unexpected error for PID 2709134365: name 'pid_list' is not defined
# Data overload
# Unexpected error for PID 2709134365: name 'pid_list' is not defined
# Data overload
# Unexpected error for PID 2709134365: name 'pid_list' is not defined
# overload data to rds
# Data overload
# Unexpected error for PID 484376563: name 'pid_list' is not defined
# Data overload
# Unexpected error for PID 484376563: name 'pid_list' is not defined
# Data overload
# Unexpected error for PID 484376563: name 'pid_list' is not defined
# Data overload
# Unexpected error for PID 484376563: name 'pid_list' is not defined
# Data overload
# Unexpected error for PID 484376563: name 'pid_list' is not defined
# Data overload
# Unexpected error for PID 484376563: name 'pid_list' is not defined
# Data overload
# Unexpected error for PID 484376563: name 'pid_list' is not defined
# Data overload
# Unexpected error for PID 484376563: name 'pid_list' is not defined
# Data overload
# Unexpected error for PID 484376563: name 'pid_list' is not defined
# Data overload
# Unexpected error for PID 484376563: name 'pid_list' is not defined
# Data overload
# Unexpected error for PID 484376563: name 'pid_list' is not defined
# overload data to rds
# Data overload
# Unexpected error for PID 2602124045: name 'pid_list' is not defined
# Data overload
# Unexpected error for PID 2602124045: name 'pid_list' is not defined
# Data overload
# Unexpected error for PID 2602124045: name 'pid_list' is not defined
# Data overload
# Unexpected error for PID 2602124045: name 'pid_list' is not defined
# Data overload
# Unexpected error for PID 2602124045: name 'pid_list' is not defined
# Data overload
# Unexpected error for PID 2602124045: name 'pid_list' is not defined
# Data overload
# Unexpected error for PID 2602124045: name 'pid_list' is not defined
# Data overload
# Unexpected error for PID 2602124045: name 'pid_list' is not defined
# Data overload
# Unexpected error for PID 2602124045: name 'pid_list' is not defined
# Data overload
# Unexpected error for PID 2602124045: name 'pid_list' is not defined
# Data overload
# Unexpected error for PID 2602124045: name 'pid_list' is not defined
# Data overload
# Unexpected error for PID 2602124045: name 'pid_list' is not defined
# Data overload
# Unexpected error for PID 2602124045: name 'pid_list' is not defined
# Data overload
# Unexpected error for PID 2602124045: name 'pid_list' is not defined
# Data overload
# Unexpected error for PID 2602124045: name 'pid_list' is not defined
# overload data to rds
# overload data to rds
# overload data to rds
# Data overload
# Unexpected error for PID 3558512924: name 'pid_list' is not defined
# Data overload
# Unexpected error for PID 3558512924: name 'pid_list' is not defined
# Data overload
# Unexpected error for PID 3558512924: name 'pid_list' is not defined
# Data overload
# Unexpected error for PID 3558512924: name 'pid_list' is not defined
# Data overload
# Unexpected error for PID 3558512924: name 'pid_list' is not defined
# Data overload
# Unexpected error for PID 3558512924: name 'pid_list' is not defined
# Data overload
# Unexpected error for PID 3558512924: name 'pid_list' is not defined
# Data overload
# Unexpected error for PID 3558512924: name 'pid_list' is not defined
# overload data to rds
# Data overload
# Unexpected error for PID 3721845878: name 'pid_list' is not defined
# Data overload
# Unexpected error for PID 3721845878: name 'pid_list' is not defined
# Data overload
# Unexpected error for PID 3721845878: name 'pid_list' is not defined
# Data overload
# Unexpected error for PID 3721845878: name 'pid_list' is not defined
# Data overload
# Unexpected error for PID 3721845878: name 'pid_list' is not defined
# Data overload
# Unexpected error for PID 3721845878: name 'pid_list' is not defined
# overload data to rds
# overload data to rds
# Data overload
# Unexpected error for PID 3858805205: name 'pid_list' is not defined
# Data overload
# Unexpected error for PID 3858805205: name 'pid_list' is not defined
# Data overload
# Unexpected error for PID 3858805205: name 'pid_list' is not defined
# Data overload
# Unexpected error for PID 3858805205: name 'pid_list' is not defined
# Data overload
# Unexpected error for PID 3858805205: name 'pid_list' is not defined
# Data overload
# Unexpected error for PID 3858805205: name 'pid_list' is not defined
# Data overload
# Unexpected error for PID 3858805205: name 'pid_list' is not defined
# Data overload
# Unexpected error for PID 3858805205: name 'pid_list' is not defined
# overload data to rds
# overload data to rds
# Data overload
# Unexpected error for PID 3837504727: name 'pid_list' is not defined
# Data overload
# Unexpected error for PID 3837504727: name 'pid_list' is not defined
# Data overload
# Unexpected error for PID 3837504727: name 'pid_list' is not defined
# Data overload
# Unexpected error for PID 3837504727: name 'pid_list' is not defined
# Data overload
# Unexpected error for PID 3837504727: name 'pid_list' is not defined
# overload data to rds
# overload data to rds
# Data overload
# Unexpected error for PID 1172140792: name 'pid_list' is not defined
# Data overload
# Unexpected error for PID 1172140792: name 'pid_list' is not defined
# Data overload
# Unexpected error for PID 1172140792: name 'pid_list' is not defined
# Data overload
# Unexpected error for PID 1172140792: name 'pid_list' is not defined
# Data overload
# Unexpected error for PID 1172140792: name 'pid_list' is not defined
# Data overload
# Unexpected error for PID 1172140792: name 'pid_list' is not defined
# Data overload
# Unexpected error for PID 1172140792: name 'pid_list' is not defined
# Data overload
# Unexpected error for PID 1172140792: name 'pid_list' is not defined
# Data overload
# Unexpected error for PID 1172140792: name 'pid_list' is not defined
# overload data to rds
# overload data to rds
# Data overload
# Unexpected error for PID 2328464202: name 'pid_list' is not defined
# Data overload
# Unexpected error for PID 2328464202: name 'pid_list' is not defined
# Data overload
# Unexpected error for PID 2328464202: name 'pid_list' is not defined
# Data overload
# Unexpected error for PID 2328464202: name 'pid_list' is not defined
# Data overload
# Unexpected error for PID 2328464202: name 'pid_list' is not defined
# Data overload
# Unexpected error for PID 2328464202: name 'pid_list' is not defined
# Data overload
# Unexpected error for PID 2328464202: name 'pid_list' is not defined
# Data overload
# Unexpected error for PID 2328464202: name 'pid_list' is not defined
# overload data to rds
# overload data to rds
# overload data to rds
# Data overload
# Unexpected error for PID 307548724: name 'pid_list' is not defined
# Data overload
# Unexpected error for PID 307548724: name 'pid_list' is not defined
# Data overload
# Unexpected error for PID 307548724: name 'pid_list' is not defined
# Data overload
# Unexpected error for PID 307548724: name 'pid_list' is not defined
# overload data to rds
# overload data to rds
# overload data to rds
# Data overload
# Unexpected error for PID 2160317686: name 'pid_list' is not defined
# Data overload
# Unexpected error for PID 2160317686: name 'pid_list' is not defined
# Data overload
# Unexpected error for PID 2160317686: name 'pid_list' is not defined
# Data overload
# Unexpected error for PID 2160317686: name 'pid_list' is not defined
# Data overload
# Unexpected error for PID 2160317686: name 'pid_list' is not defined
# Data overload
# Unexpected error for PID 2160317686: name 'pid_list' is not defined
# Data overload
# Unexpected error for PID 2160317686: name 'pid_list' is not defined
# overload data to rds
# overload data to rds
# Data overload
# Unexpected error for PID 1848740311: name 'pid_list' is not defined
# Data overload
# Unexpected error for PID 1848740311: name 'pid_list' is not defined
# Data overload
# Unexpected error for PID 1848740311: name 'pid_list' is not defined
# overload data to rds
# Data overload
# Unexpected error for PID 1994289178: name 'pid_list' is not defined
# Data overload
# Unexpected error for PID 1994289178: name 'pid_list' is not defined
# Data overload
# Unexpected error for PID 1994289178: name 'pid_list' is not defined
# Data overload
# Unexpected error for PID 1994289178: name 'pid_list' is not defined
# Data overload
# Unexpected error for PID 1994289178: name 'pid_list' is not defined
# Data overload
# Unexpected error for PID 1994289178: name 'pid_list' is not defined
# Data overload
# Unexpected error for PID 1994289178: name 'pid_list' is not defined
# overload data to rds
# overload data to rds
# overload data to rds
# overload data to rds
# Data overload
# Unexpected error for PID 3429436473: name 'pid_list' is not defined
# Data overload
# Unexpected error for PID 3429436473: name 'pid_list' is not defined
# Data overload
# Unexpected error for PID 3429436473: name 'pid_list' is not defined
# Data overload
# Unexpected error for PID 3429436473: name 'pid_list' is not defined
# Data overload
# Unexpected error for PID 3429436473: name 'pid_list' is not defined
# Data overload
# Unexpected error for PID 3429436473: name 'pid_list' is not defined
# Data overload
# Unexpected error for PID 3429436473: name 'pid_list' is not defined
# overload data to rds
# overload data to rds
# overload data to rds
# overload data to rds
# overload data to rds
# overload data to rds
# overload data to rds
# Data overload
# Unexpected error for PID 3959120315: name 'pid_list' is not defined
# Data overload
# Unexpected error for PID 3959120315: name 'pid_list' is not defined
# Data overload
# Unexpected error for PID 3959120315: name 'pid_list' is not defined
# Data overload
# Unexpected error for PID 3959120315: name 'pid_list' is not defined
# Data overload
# Unexpected error for PID 3959120315: name 'pid_list' is not defined
# Data overload
# Unexpected error for PID 3959120315: name 'pid_list' is not defined
# Data overload
# Unexpected error for PID 3959120315: name 'pid_list' is not defined
# Data overload
# Unexpected error for PID 3959120315: name 'pid_list' is not defined
# overload data to rds
# Data overload
# Unexpected error for PID 136281827: name 'pid_list' is not defined
# Data overload
# Unexpected error for PID 136281827: name 'pid_list' is not defined
# Data overload
# Unexpected error for PID 136281827: name 'pid_list' is not defined
# overload data to rds
# overload data to rds
# overload data to rds
# overload data to rds
# overload data to rds
# Data overload
# Unexpected error for PID 3486557072: name 'pid_list' is not defined
# Data overload
# Unexpected error for PID 3486557072: name 'pid_list' is not defined
# Data overload
# Unexpected error for PID 3486557072: name 'pid_list' is not defined
# Data overload
# Unexpected error for PID 3486557072: name 'pid_list' is not defined
# Data overload
# Unexpected error for PID 3486557072: name 'pid_list' is not defined
# Data overload
# Unexpected error for PID 3486557072: name 'pid_list' is not defined
# overload data to rds
# overload data to rds
# Data overload
# Unexpected error for PID 434466414: name 'pid_list' is not defined
# overload data to rds
# overload data to rds
# Data overload
# Unexpected error for PID 685604555: name 'pid_list' is not defined
# Data overload
# Unexpected error for PID 685604555: name 'pid_list' is not defined
# overload data to rds
# overload data to rds
# overload data to rds
# Data overload
# Unexpected error for PID 4113770928: name 'pid_list' is not defined
# Data overload
# Unexpected error for PID 4113770928: name 'pid_list' is not defined
# Data overload
# Unexpected error for PID 4113770928: name 'pid_list' is not defined
# Data overload
# Unexpected error for PID 4113770928: name 'pid_list' is not defined
# Data overload
# Unexpected error for PID 4113770928: name 'pid_list' is not defined
# Data overload
# Unexpected error for PID 4113770928: name 'pid_list' is not defined
# Data overload
# Unexpected error for PID 4113770928: name 'pid_list' is not defined
# Data overload
# Unexpected error for PID 4113770928: name 'pid_list' is not defined
# Data overload
# Unexpected error for PID 4113770928: name 'pid_list' is not defined
# overload data to rds
# Data overload
# ...
# Data overload
# Unexpected error for PID 303223673: name 'pid_list' is not defined
# Data overload
# Unexpected error for PID 303223673: name 'pid_list' is not defined
# Data overload
# Unexpected error for PID 303223673: name 'pid_list' is not defined
# overload data to rds
# overload data to rds
# overload data to rds
# overload data to rds
# overload data to rds
# Data overload
# Unexpected error for PID 1411982058: name 'pid_list' is not defined
# Data overload
# Unexpected error for PID 1411982058: name 'pid_list' is not defined
# Data overload
# Unexpected error for PID 1411982058: name 'pid_list' is not defined
# Data overload
# Unexpected error for PID 1411982058: name 'pid_list' is not defined
# Data overload
# Unexpected error for PID 1411982058: name 'pid_list' is not defined
# Data overload
# Unexpected error for PID 1411982058: name 'pid_list' is not defined
# Data overload
# Unexpected error for PID 1411982058: name 'pid_list' is not defined
# Data overload
# Unexpected error for PID 1411982058: name 'pid_list' is not defined
# Data overload
# Unexpected error for PID 1411982058: name 'pid_list' is not defined
# Data overload
# Unexpected error for PID 1411982058: name 'pid_list' is not defined
# overload data to rds
# overload data to rds
# Data overload
# Unexpected error for PID 3269342040: name 'pid_list' is not defined
# Data overload
# Unexpected error for PID 3269342040: name 'pid_list' is not defined
# Data overload
# Unexpected error for PID 3269342040: name 'pid_list' is not defined
# Data overload
# Unexpected error for PID 3269342040: name 'pid_list' is not defined
# Data overload
# Unexpected error for PID 3269342040: name 'pid_list' is not defined
# overload data to rds
# overload data to rds
# Data overload
# Unexpected error for PID 1773157417: name 'pid_list' is not defined
# Data overload
# Unexpected error for PID 1773157417: name 'pid_list' is not defined
# Data overload
# Unexpected error for PID 1773157417: name 'pid_list' is not defined
# Data overload
# Unexpected error for PID 1773157417: name 'pid_list' is not defined
# Data overload
# Unexpected error for PID 1773157417: name 'pid_list' is not defined
# Data overload
# Unexpected error for PID 1773157417: name 'pid_list' is not defined
# Data overload
# Unexpected error for PID 1773157417: name 'pid_list' is not defined
# Data overload
# Unexpected error for PID 1773157417: name 'pid_list' is not defined
# Data overload
# Unexpected error for PID 1773157417: name 'pid_list' is not defined
# Data overload
# Unexpected error for PID 1773157417: name 'pid_list' is not defined
# Data overload
# Unexpected error for PID 1773157417: name 'pid_list' is not defined
# overload data to rds
# overload data to rds
# overload data to rds
# overload data to rds
# overload data to rds
# overload data to rds
# Data overload
# Unexpected error for PID 250722614: name 'pid_list' is not defined
# Data overload
# Unexpected error for PID 250722614: name 'pid_list' is not defined
# Data overload
# Unexpected error for PID 250722614: name 'pid_list' is not defined
# Data overload
# Unexpected error for PID 250722614: name 'pid_list' is not defined
# Data overload
# Unexpected error for PID 250722614: name 'pid_list' is not defined
# Data overload
# Unexpected error for PID 250722614: name 'pid_list' is not defined
# overload data to rds
# overload data to rds
# overload data to rds
# overload data to rds
# overload data to rds
# overload data to rds
# overload data to rds
# overload data to rds
# Data overload
# Unexpected error for PID 134021083: name 'pid_list' is not defined
# Data overload
# Unexpected error for PID 134021083: name 'pid_list' is not defined
# Data overload
# Unexpected error for PID 134021083: name 'pid_list' is not defined
# Data overload
# Unexpected error for PID 134021083: name 'pid_list' is not defined
# Data overload
# Unexpected error for PID 134021083: name 'pid_list' is not defined
# overload data to rds
# overload data to rds
# Data overload
# Unexpected error for PID 2545093166: name 'pid_list' is not defined
# Data overload
# Unexpected error for PID 2545093166: name 'pid_list' is not defined
# Data overload
# Unexpected error for PID 2545093166: name 'pid_list' is not defined
# Data overload
# Unexpected error for PID 2545093166: name 'pid_list' is not defined
# Data overload
# Unexpected error for PID 2545093166: name 'pid_list' is not defined
# Data overload
# Unexpected error for PID 2545093166: name 'pid_list' is not defined
# Data overload
# Unexpected error for PID 2545093166: name 'pid_list' is not defined
# overload data to rds
# overload data to rds
# overload data to rds
# overload data to rds
# overload data to rds
# overload data to rds
# overload data to rds
# Data overload
# Unexpected error for PID 3204532735: name 'pid_list' is not defined
# Data overload
# Unexpected error for PID 3204532735: name 'pid_list' is not defined
# Data overload
# Unexpected error for PID 3204532735: name 'pid_list' is not defined
# Data overload
# Unexpected error for PID 3204532735: name 'pid_list' is not defined
# Data overload
# Unexpected error for PID 3204532735: name 'pid_list' is not defined
# Data overload
# Unexpected error for PID 3204532735: name 'pid_list' is not defined
# Data overload
# Unexpected error for PID 3204532735: name 'pid_list' is not defined
# overload data to rds
# overload data to rds
# overload data to rds
# Data overload
# Unexpected error for PID 3889550260: name 'pid_list' is not defined
# Data overload
# Unexpected error for PID 3889550260: name 'pid_list' is not defined
# Data overload
# Unexpected error for PID 3889550260: name 'pid_list' is not defined
# Data overload
# Unexpected error for PID 3889550260: name 'pid_list' is not defined
# Data overload
# Unexpected error for PID 3889550260: name 'pid_list' is not defined
# Data overload
# Unexpected error for PID 3889550260: name 'pid_list' is not defined
# Data overload
# Unexpected error for PID 3889550260: name 'pid_list' is not defined
# Data overload
# Unexpected error for PID 3889550260: name 'pid_list' is not defined
# Data overload
# Unexpected error for PID 3889550260: name 'pid_list' is not defined
# Data overload
# Unexpected error for PID 3889550260: name 'pid_list' is not defined
# Data overload
# Unexpected error for PID 3889550260: name 'pid_list' is not defined
# Data overload
# Unexpected error for PID 3889550260: name 'pid_list' is not defined
# overload data to rds
# Data overload
# Unexpected error for PID 3703412341: name 'pid_list' is not defined
# Data overload
# Unexpected error for PID 3703412341: name 'pid_list' is not defined
# Data overload
# Unexpected error for PID 3703412341: name 'pid_list' is not defined
# Data overload
# Unexpected error for PID 3703412341: name 'pid_list' is not defined
# overload data to rds
# overload data to rds
# overload data to rds
# overload data to rds
# overload data to rds
# Data overload
# Unexpected error for PID 588203989: name 'pid_list' is not defined
# Data overload
# Unexpected error for PID 588203989: name 'pid_list' is not defined
# Data overload
# Unexpected error for PID 588203989: name 'pid_list' is not defined
# Data overload
# Unexpected error for PID 588203989: name 'pid_list' is not defined
# Data overload
# Unexpected error for PID 588203989: name 'pid_list' is not defined
# Data overload
# Unexpected error for PID 588203989: name 'pid_list' is not defined
# Data overload
# Unexpected error for PID 588203989: name 'pid_list' is not defined
# Data overload
# Unexpected error for PID 588203989: name 'pid_list' is not defined
# Data overload
# Unexpected error for PID 588203989: name 'pid_list' is not defined
# Data overload
# Unexpected error for PID 588203989: name 'pid_list' is not defined
# Data overload
# Unexpected error for PID 588203989: name 'pid_list' is not defined
# Data overload
# Unexpected error for PID 588203989: name 'pid_list' is not defined
# Data overload
# Unexpected error for PID 588203989: name 'pid_list' is not defined
# Data overload
# Unexpected error for PID 588203989: name 'pid_list' is not defined
# Data overload
# Unexpected error for PID 588203989: name 'pid_list' is not defined
# Data overload
# Unexpected error for PID 588203989: name 'pid_list' is not defined
# Data overload
# Unexpected error for PID 588203989: name 'pid_list' is not defined
# Data overload
# Unexpected error for PID 588203989: name 'pid_list' is not defined
# Data overload
# Unexpected error for PID 588203989: name 'pid_list' is not defined
# overload data to rds
# overload data to rds
# Data overload
# Unexpected error for PID 3424629829: name 'pid_list' is not defined
# Data overload
# Unexpected error for PID 3424629829: name 'pid_list' is not defined
# Data overload
# Unexpected error for PID 3424629829: name 'pid_list' is not defined
# overload data to rds
# overload data to rds
# overload data to rds
# overload data to rds
# Data overload
# Unexpected error for PID 2668204823: name 'pid_list' is not defined
# Data overload
# Unexpected error for PID 2668204823: name 'pid_list' is not defined
# Data overload
# Unexpected error for PID 2668204823: name 'pid_list' is not defined
# Data overload
# Unexpected error for PID 2668204823: name 'pid_list' is not defined
# Data overload
# Unexpected error for PID 2668204823: name 'pid_list' is not defined
# Data overload
# Unexpected error for PID 2668204823: name 'pid_list' is not defined
# overload data to rds
# overload data to rds
# Data overload
# Unexpected error for PID 2067851004: name 'pid_list' is not defined
# Data overload
# Unexpected error for PID 2067851004: name 'pid_list' is not defined
# Data overload
# Unexpected error for PID 2067851004: name 'pid_list' is not defined
# Data overload
# Unexpected error for PID 2067851004: name 'pid_list' is not defined
# overload data to rds
# Data overload
# Unexpected error for PID 123757741: name 'pid_list' is not defined
# Data overload
# Unexpected error for PID 123757741: name 'pid_list' is not defined
# Data overload
# Unexpected error for PID 123757741: name 'pid_list' is not defined
# Data overload
# Unexpected error for PID 123757741: name 'pid_list' is not defined
# Data overload
# Unexpected error for PID 123757741: name 'pid_list' is not defined
# Data overload
# Unexpected error for PID 123757741: name 'pid_list' is not defined
# Data overload
# Unexpected error for PID 123757741: name 'pid_list' is not defined
# overload data to rds
# overload data to rds
# Data overload
# Unexpected error for PID 593132328: name 'pid_list' is not defined
# Data overload
# Unexpected error for PID 593132328: name 'pid_list' is not defined
# Data overload
# Unexpected error for PID 593132328: name 'pid_list' is not defined
# Data overload
# Unexpected error for PID 593132328: name 'pid_list' is not defined
# overload data to rds
# Data overload
# Unexpected error for PID 3354895159: name 'pid_list' is not defined
# Data overload
# Unexpected error for PID 3354895159: name 'pid_list' is not defined
# Data overload
# Unexpected error for PID 3354895159: name 'pid_list' is not defined
# overload data to rds
# overload data to rds
# Data overload
# Unexpected error for PID 2976864632: name 'pid_list' is not defined
# Data overload
# Unexpected error for PID 2976864632: name 'pid_list' is not defined
# Data overload
# Unexpected error for PID 2976864632: name 'pid_list' is not defined
# Data overload
# Unexpected error for PID 2976864632: name 'pid_list' is not defined
# Data overload
# Unexpected error for PID 2976864632: name 'pid_list' is not defined
# Data overload
# Unexpected error for PID 2976864632: name 'pid_list' is not defined
# Data overload
# Unexpected error for PID 2976864632: name 'pid_list' is not defined
# Data overload
# Unexpected error for PID 2976864632: name 'pid_list' is not defined
# Data overload
# Unexpected error for PID 2976864632: name 'pid_list' is not defined
# Data overload
# Unexpected error for PID 2976864632: name 'pid_list' is not defined
# Data overload
# Unexpected error for PID 2976864632: name 'pid_list' is not defined
# Data overload
# Unexpected error for PID 2976864632: name 'pid_list' is not defined
# Data overload
# Unexpected error for PID 2976864632: name 'pid_list' is not defined
# Data overload
# Unexpected error for PID 2976864632: name 'pid_list' is not defined
# Data overload
# Unexpected error for PID 2976864632: name 'pid_list' is not defined
# Data overload
# Unexpected error for PID 2976864632: name 'pid_list' is not defined
# Data overload
# Unexpected error for PID 2976864632: name 'pid_list' is not defined
# Data overload
# Unexpected error for PID 2976864632: name 'pid_list' is not defined
# Data overload
# Unexpected error for PID 2976864632: name 'pid_list' is not defined
# Data overload
# Unexpected error for PID 2976864632: name 'pid_list' is not defined
# overload data to rds
# overload data to rds
# Data overload
# Unexpected error for PID 2602459384: name 'pid_list' is not defined
# Data overload
# Unexpected error for PID 2602459384: name 'pid_list' is not defined
# Data overload
# Unexpected error for PID 2602459384: name 'pid_list' is not defined
# Data overload
# Unexpected error for PID 2602459384: name 'pid_list' is not defined
# Data overload
# Unexpected error for PID 2602459384: name 'pid_list' is not defined
# Data overload
# Unexpected error for PID 2602459384: name 'pid_list' is not defined
# Data overload
# Unexpected error for PID 2602459384: name 'pid_list' is not defined
# Data overload
# Unexpected error for PID 2602459384: name 'pid_list' is not defined
# Data overload
# Unexpected error for PID 2602459384: name 'pid_list' is not defined
# Data overload
# Unexpected error for PID 2602459384: name 'pid_list' is not defined
# Data overload
# Unexpected error for PID 2602459384: name 'pid_list' is not defined
# overload data to rds
# overload data to rds
# overload data to rds
# Data overload
# Unexpected error for PID 2893146655: name 'pid_list' is not defined
# Data overload
# Unexpected error for PID 2893146655: name 'pid_list' is not defined
# Data overload
# Unexpected error for PID 2893146655: name 'pid_list' is not defined
# Data overload
# Unexpected error for PID 2893146655: name 'pid_list' is not defined
# Data overload
# Unexpected error for PID 2893146655: name 'pid_list' is not defined
# overload data to rds
# overload data to rds
# overload data to rds
# Data overload
# Unexpected error for PID 3340417175: name 'pid_list' is not defined
# Data overload
# Unexpected error for PID 3340417175: name 'pid_list' is not defined
# Data overload
# Unexpected error for PID 3340417175: name 'pid_list' is not defined
# Data overload
# Unexpected error for PID 3340417175: name 'pid_list' is not defined
# Data overload
# Unexpected error for PID 3340417175: name 'pid_list' is not defined
# Data overload
# Unexpected error for PID 3340417175: name 'pid_list' is not defined
# Data overload
# Unexpected error for PID 3340417175: name 'pid_list' is not defined
# overload data to rds
# Data overload
# Unexpected error for PID 1024574374: name 'pid_list' is not defined
# Data overload
# Unexpected error for PID 1024574374: name 'pid_list' is not defined
# Data overload
# Unexpected error for PID 1024574374: name 'pid_list' is not defined
# Data overload
# Unexpected error for PID 1024574374: name 'pid_list' is not defined
# Data overload
# Unexpected error for PID 1024574374: name 'pid_list' is not defined
# overload data to rds
# Data overload
# Unexpected error for PID 1919149588: name 'pid_list' is not defined
# overload data to rds
# overload data to rds
# overload data to rds
# overload data to rds
# Data overload
# Unexpected error for PID 1788180811: name 'pid_list' is not defined
# Data overload
# Unexpected error for PID 1788180811: name 'pid_list' is not defined
# Data overload
# Unexpected error for PID 1788180811: name 'pid_list' is not defined
# Data overload
# Unexpected error for PID 1788180811: name 'pid_list' is not defined
# Data overload
# Unexpected error for PID 1788180811: name 'pid_list' is not defined
# overload data to rds
# overload data to rds
# overload data to rds
# Data overload
# Unexpected error for PID 624841999: name 'pid_list' is not defined
# Data overload
# Unexpected error for PID 624841999: name 'pid_list' is not defined
# Data overload
# Unexpected error for PID 624841999: name 'pid_list' is not defined
# Data overload
# Unexpected error for PID 624841999: name 'pid_list' is not defined
# Data overload
# Unexpected error for PID 624841999: name 'pid_list' is not defined
# Data overload
# Unexpected error for PID 624841999: name 'pid_list' is not defined
# overload data to rds
# overload data to rds
# overload data to rds
# overload data to rds
# overload data to rds

# %%
pid_list = get_pid_jobstack()

# %%
sql_query3 = """
    INSERT INTO job_stack (
        pid, did
    ) 
    VALUES (%s, %s)
"""
pid_list = get_pid_jobstack()
for i, values in result.iterrows():
    for stack in values['dev_stack']:
        data2 = (values['pid'],int(fhash(stack)))
        try:
            if int(data2[0]) in pid_list and data2[1] in get_crid_jobstack(values['pid']):
                print("Data overload")
            else:
                cursor.execute(sql_query3, data2)
                connection.commit()
                print(f"Data successfully load to rds")
        except mysql.connector.Error as error:
            print(f"Error executing SQL query for PID {values['pid']}: {error}")  # 에러 로깅
        except Exception as e:
            print(f"Unexpected error for PID {values['pid']}: {str(e)}")  # 예기치 않은 에러 로깅
# Out:
# Data overload
# Data overload
# Data overload
# Data overload
# Data overload
# Data overload
# Data overload
# Data overload
# Data overload
# Data overload
# Data overload
# Data overload
# Data overload
# Data overload
# Data overload
# Data overload
# Data overload
# Data overload
# Data overload
# Data overload
# Data overload
# Data overload
# Data overload
# Data overload
# Data overload
# Data overload
# Data overload
# Data overload
# Data overload
# Data overload
# Data overload
# Data overload
# Data overload
# Data overload
# Data overload
# Data overload
# Data overload
# Data overload
# Data overload
# Data overload
# Data overload
# Data overload
# Data overload
# Data overload
# Data overload
# Data overload
# Data overload
# Data overload
# Data overload
# Data overload
# Data overload
# Data overload
# Data overload
# Data overload
# Data overload
# Data overload
# Data overload
# Data overload
# Data overload
# Data overload
# Data overload
# Data overload
# Data overload
# Data overload
# Data overload
# Data overload
# Data overload
# Data overload
# Data overload
# Data overload
# Data overload
# Data overload
# Data overload
# Data overload
# Data overload
# Data overload
# Data overload
# Data overload
# Data overload
# Data overload
# Data overload
# Data overload
# Data overload
# Data overload
# Data overload
# Data overload
# Data overload
# Data overload
# Data overload
# Data overload
# Data overload
# Data overload
# Data overload
# Data overload
# Data overload
# Data overload
# Data overload
# Data overload
# Data overload
# Data overload
# Data overload
# Data overload
# Data overload
# Data overload
# Data overload
# Data overload
# Data overload
# Data overload
# Data overload
# Data overload
# Data overload
# Data overload
# Data overload
# Data overload
# Data overload
# Data overload
# Data overload
# Data overload
# Data overload
# Data overload
# Data overload
# Data overload
# Data overload
# Data overload
# Data overload
# Data overload
# Data overload
# Data overload
# Data overload
# Data overload
# Data overload
# Data overload
# Data overload
# Data overload
# Data overload
# Data overload
# Data overload
# Data overload
# Data overload
# Data overload
# Data overload
# Data overload
# Data overload
# Data overload
# Data overload
# Data overload
# Data overload
# Data overload
# Data overload
# Data overload
# Data overload
# Data overload
# Data overload
# Data overload
# Data overload
# Data overload
# Data overload
# Data overload
# Data overload
# Data overload
# Data overload
# Data overload
# Data overload
# Data overload
# Data overload
# Data overload
# Data overload
# Data overload
# Data overload
# Data overload
# Data overload
# Data overload
# Data overload
# Data overload
# Data overload
# Data overload
# Data overload
# Data overload
# Data overload
# Data overload
# Data overload
# Data overload
# Data overload
# Data overload
# Data overload
# Data overload
# Data overload
# Data overload
# Data overload
# Data overload
# Data overload
# Data overload
# Data overload
# Data overload
# Data overload
# Data overload
# Data overload
# Data overload
# Data overload
# Data overload
# Data overload
# Data overload
# Data overload
# Data overload
# Data overload
# Data overload
# Data overload
# Data overload
# Data overload
# Data overload
# Data overload
# Data overload
# Data overload
# Data overload
# Data overload
# Data overload
# Data overload
# Data overload
# Data overload
# Data overload
# Data overload
# Data overload
# Data overload
# Data overload
# Data overload
# Data overload
# Data overload
# Data overload
# Data overload
# Data overload
# Data overload
# Data overload
# Data overload
# Data overload
# Data overload
# Data overload
# Data overload
# Data overload
# Data overload
# Data overload
# Data overload
# Data overload
# Data overload
# Data overload
# Data overload
# Data overload
# Data overload
# Data overload
# Data overload
# Data overload
# Data overload
# Data overload
# Data overload
# Data overload
# Data overload
# Data overload
# Data overload
# Data overload
# Data overload
# Data overload
# Data overload
# Data overload
# Data overload
# Data overload
# Data overload
# Data overload
# Data overload
# Data overload
# Data overload
# Data overload
# Data overload
# Data overload
# Data overload
# Data overload
# Data overload
# Data overload
# Data overload
# Data overload
# Data overload
# Data overload
# Data overload
# Data overload
# Data overload
# Data overload
# Data overload
# Data overload
# Data overload
# Data overload
# Data overload
# Data overload
# Data overload
# Data overload
# Data overload
# Data overload
# Data overload
# Data overload
# Data overload
# Data overload
# Data overload
# Data overload
# Data overload
# Data overload
# Data overload
# Data overload
# Data overload
# Data overload
# Data overload
# Data overload
# Data overload
# Data overload
# Data overload
# Data overload
# Data overload
# Data overload
# Data overload
# Data overload
# Data overload
# Data overload
# Data overload
# Data overload
# Data overload
# Data overload
# Data overload
# Data overload
# Data overload
# Data overload
# Data overload
# Data overload
# Data overload
# Data overload
# Data overload
# Data overload
# Data overload
# Data overload
# Data overload
# Data overload
# Data overload
# Data overload
# Data overload
# Data overload
# Data overload
# Data overload
# Data overload
# Data overload
# Data overload
# Data overload
# Data overload
# Data overload
# Data overload
# Data overload
# Data overload
# Data overload
# Data overload
# Data overload
# Data overload
# Data overload
# Data overload
# Data overload
# Data overload
# Data overload
# Data overload
# Data overload
# Data overload
# Data overload
# Data overload
# Data overload
# Data overload
# Data overload
# Data overload
# Data overload
# Data overload
# Data overload
# Data overload
# Data overload
# Data overload
# Data overload
# Data overload
# Data overload
# Data overload
# Data overload
# Data overload
# Data overload
# Data overload
# Data overload
# Data overload
# Data overload
# Data overload
# Data overload
# Data overload
# Data overload
# Data overload
# Data overload
# Data overload
# Data overload
# Data overload
# Data overload
# Data overload
# Data overload
# Data overload
# Data overload
# Data overload
# Data overload
# Data overload
# Data overload
# Data overload
# Data overload
# Data overload
# Data overload
# Data overload
# Data overload
# Data overload
# Data overload
# Data overload
# Data overload
# Data overload
# Data overload
# Data overload
# Data overload
# Data overload
# Data overload
# Data overload
# Data overload
# Data overload
# Data overload
# Data overload
# Data overload
# Data overload
# Data overload
# Data overload
# Data overload
# Data overload
# Data overload
# Data overload
# Data overload
# Data overload
# Data overload
# Data overload
# Data overload
# Data overload
# Data overload
# Data overload
# Data overload
# Data overload
# Data overload
# Data overload
# Data overload
# Data overload
# Data overload
# Data overload
# Data overload
# Data overload
# Data overload
# Data overload
# Data overload
# Data overload
# Data overload
# Data overload
# Data overload
# Data overload
# Data overload
# Data overload
# Data overload
# Data overload
# Data overload
# Data overload
# Data overload
# Data overload
# Data overload
# Data overload
# Data overload
# Data overload
# Data overload
# Data overload
# Data overload
# Data overload
# Data overload
# Data overload
# Data overload
# Data overload
# Data overload
# Data overload
# Data overload
# Data overload
# Data overload
# Data overload
# Data overload
# Data overload
# Data overload
# Data overload
# Data overload
# Data overload
# Data overload
# Data overload
# Data overload
# Data overload
# Data overload
# Data overload
# Data overload
# Data overload
# Data overload
# Data overload
# Data overload
# Data overload
# Data overload
# Data overload
# Data overload
# Data overload
# Data overload
# Data overload
# Data overload
# Data overload
# Data overload
# Data overload
# Data overload
# Data overload
# Data overload
# Data overload
# Data overload
# Data overload
# Data overload
# Data overload
# Data overload
# Data overload
# Data overload
# Data overload
# Data overload
# Data overload
# Data overload
# Data overload
# Data overload
# Data overload
# Data overload
# Data overload
# Data overload
# Data overload
# Data overload
# Data overload
# Data overload
# Data overload
# Data overload
# Data overload
# Data overload
# Data overload
# Data overload
# Data overload
# Data overload
# Data overload
# Data overload
# Data overload
# Data overload
# Data overload
# Data overload
# Data overload
# Data overload
# Data overload
# Data overload
# Data overload
# Data overload
# Data overload
# Data overload
# Data overload
# Data overload
# Data overload
# Data overload
# Data overload
# Data overload
# Data overload
# Data overload
# Data overload
# Data overload
# Data overload
# Data overload
# Data overload
# Data overload
# Data overload
# Data overload
# Data overload
# Data overload
# Data overload
# Data overload
# Data overload
# Data overload
# Data overload
# Data overload
# Data overload
# Data overload
# Data overload
# Data overload
# Data overload
# Data overload
# Data overload
# Data overload
# Data overload
# Data overload
# Data overload
# Data overload
# Data overload
# Data overload
# Data overload
# Data overload
# Data overload
# Data overload
# Data overload
# Data overload
# Data overload
# Data overload
# Data overload
# Data overload
# Data overload
# Data overload
# Data overload
# Data overload
# Data overload
# Data overload
# Data overload
# Data overload
# Data overload
# Data overload
# Data overload
# Data overload
# Data overload
# Data overload
# Data overload
# Data overload
# Data overload
# Data overload
# Data overload
# Data overload
# Data overload
# Data overload
# Data overload
# Data overload
# Data overload
# Data overload
# Data overload
# Data overload
# Data overload
# Data overload
# Data overload
# Data overload
# Data overload
# Data overload
# Data overload
# Data overload
# Data overload
# Data overload
# Data overload
# Data overload
# Data overload
# Data overload
# Data overload
# Data overload
# Data overload
# Data overload
# Data overload
# Data overload
# Data overload
# Data overload
# Data overload
# Data overload
# Data overload
# Data overload
# Data overload
# Data overload
# Data overload
# Data overload
# Data overload
# Data overload
# Data overload
# Data overload
# Data overload
# Data overload
# Data overload
# Data overload
# Data overload
# Data overload
# Data overload
# Data overload
# Data overload
# Data overload
# Data overload
# Data overload
# Data overload
# Data overload
# Data overload
# Data overload
# Data overload
# Data overload
# Data overload
# Data overload
# Data overload
# Data overload
# Data overload
# Data overload
# Data overload
# Data overload
# Data overload
# Data overload
# Data overload
# Data overload
# Data overload
# Data overload
# Data overload
# Data overload
# Data overload
# Data overload
# Data overload
# Data overload
# Data overload
# Data overload
# Data overload
# Data overload
# Data overload
# Data overload
# Data overload
# Data overload
# Data overload
# Data overload
# Data overload
# Data overload
# Data overload
# Data overload
# Data overload
# Data overload
# Data overload
# Data overload
# Data overload
# Data overload
# Data overload
# Data overload
# Data overload
# Data overload
# Data overload
# Data overload
# Data overload
# Data overload
# Data overload
# Data overload
# Data overload
# Data overload
# Data overload
# Data overload
# Data overload
# Data overload
# Data overload
# Data overload
# Data overload
# Data overload
# Data overload
# Data overload
# Data overload
# Data overload
# Data overload
# Data overload
# Data overload
# Data overload
# Data overload
# Data overload
# Data overload
# Data overload
# Data overload
# Data overload
# Data overload
# Data overload
# Data overload
# Data overload
# Data overload
# Data overload
# Data overload
# Data overload
# Data overload
# Data overload
# Data overload
# Data overload
# Data overload
# Data overload
# Data overload
# Data overload
# Data overload
# Data overload
# Data overload
# Data overload
# Data overload
# Data overload
# Data overload
# Data overload
# Data overload
# Data overload
# Data overload
# Data overload
# Data overload
# Data overload
# Data overload
# Data overload
# Data overload
# Data overload
# Data overload
# Data overload
# Data overload
# Data overload
# Data overload
# Data overload
# Data overload
# Data overload
# Data overload
# Data overload
# Data overload
# Data overload
# Data overload
# Data overload
# Data overload
# Data overload
# Data overload
# Data overload
# Data overload
# Data overload
# Data overload
# Data overload
# Data overload
# Data overload
# Data overload
# Data overload
# Data overload
# Data overload
# Data overload
# Data overload
# Data overload
# Data overload
# Data overload
# Data overload
# Data overload
# Data overload
# Data overload
# Data overload
# Data overload
# Data overload
# Data overload
# Data overload
# Data overload
# Data overload
# Data overload
# Data overload
# Data overload
# Data overload
# Data overload
# Data overload
# Data overload
# Data overload
# Data overload
# Data overload
# Data overload
# Data overload
# Data overload
# Data overload
# Data overload
# Data overload
# Data overload
# Data overload
# Data overload
# Data overload
# Data overload
# Data overload
# Data overload
# Data overload
# Data overload
# Data overload
# Data overload
# Data overload
# Data overload
# Data overload
# Data overload
# Data overload
# Data overload
# Data overload
# Data overload
# Data overload
# Data overload
# Data overload
# Data overload
# Data overload
# Data overload
# Data overload
# Data overload
# Data overload
# Data overload
# Data overload
# Data overload
# Data overload
# Data overload
# Data overload
# Data overload
# Data overload
# Data overload
# Data overload
# Data overload
# Data overload
# Data overload
# Data overload
# Data overload
# Data overload
# Data overload
# Data overload
# Data overload
# Data overload
# Data overload
# Data overload
# Data overload
# Data overload
# Data overload
# Data overload
# Data overload
# Data overload
# Data overload
# Data overload
# Data overload
# Data overload
# Data overload
# Data overload
# Data overload
# Data overload
# Data overload
# Data overload
# Data overload
# Data overload
# Data overload
# Data overload
# Data overload
# Data overload
# Data overload
# Data overload
# Data overload
# Data overload
# Data overload
# Data overload
# Data overload
# Data overload
# Data overload
# Data overload
# Data overload
# Data overload
# Data overload
# Data overload
# Data overload
# Data overload
# Data overload
# Data overload
# Data overload
# Data overload
# Data overload
# Data overload
# Data overload
# Data overload
# Data overload
# Data overload
# Data overload
# Data overload
# Data overload
# Data overload
# Data overload
# Data overload
# Data overload
# Data overload
# Data overload
# Data overload
# Data overload
# Data overload
# Data overload
# Data overload
# Data overload
# Data overload
# Data overload
# Data overload
# Data overload
# Data overload
# Data overload
# Data overload
# Data overload
# Data overload
# Data overload
# Data overload
# Data overload
# Data overload
# Data overload
# Data overload
# Data overload
# Data overload
# Data overload
# Data overload
# Data overload
# Data overload
# Data overload
# Data overload
# Data overload
# Data overload
# Data overload
# Data overload
# Data overload
# Data overload
# Data overload
# Data overload
# Data overload
# Data overload
# Data overload
# Data overload
# Data overload
# Data overload
# Data overload
# Data overload
# Data overload
# Data overload
# Data overload
# Data overload
# Data overload
# Data overload
# Data overload
# Data overload
# Data overload
# Data overload
# Data overload
# Data overload
# Data overload
# Data overload
# Data overload
# Data overload
# Data overload
# Data overload
# Data overload
# Data overload
# Data overload
# Data overload
# Data overload
# Data overload
# Data overload
# Data overload
# Data overload
# Data overload
# Data overload
# Data overload
# Data overload
# Data overload
# Data overload
# Data overload
# Data overload
# Data overload
# Data overload
# Data overload
# Data overload
# Data overload
# Data overload
# Data overload
# Data overload
# Data overload
# Data overload
# Data overload
# Data overload
# Data overload
# Data overload
# Data overload
# Data overload
# Data overload
# Data overload
# Data overload
# Data overload
# Data overload
# Data overload
# Data overload
# Data overload
# Data overload
# Data overload
# Data overload
# Data overload
# Data overload
# Data overload
# Data overload
# Data overload
# Data overload
# Data overload
# Data overload
# Data overload
# Data overload
# Data overload
# Data overload
# Data overload
# Data overload
# Data overload
# Data overload
# Data overload
# Data overload
# Data overload
# Data overload
# Data overload
# Data overload
# Data overload
# Data overload
# Data overload
# Data overload
# Data overload
# Data overload
# Data overload
# Data overload
# Data overload
# Data overload
# Data overload
# Data overload
# Data overload
# Data overload
# Data overload
# Data overload
# Data overload
# Data overload
# Data overload
# Data overload
# Data overload
# Data overload
# Data overload
# Data overload
# Data overload
# Data overload
# Data overload
# Data overload
# Data overload
# Data overload
# Data overload
# Data overload
# Data overload
# Data overload
# Data overload
# Data overload
# Data overload
# Data overload
# Data overload
# Data overload
# Data overload
# Data overload
# Data overload
# Data overload
# Data overload
# Data overload
# Data overload
# Data overload
# Data overload
# Data overload
# Data overload
# Data overload
# Data overload
# Data overload
# Data overload
# Data overload
# Data overload
# Data overload
# Data overload
# Data overload
# Data overload
# Data overload
# Data overload
# Data overload
# Data overload
# Data overload
# Data overload
# Data overload
# Data overload
# Data overload
# Data overload
# Data overload
# Data overload
# Data overload
# Data overload
# Data overload
# Data overload
# Data overload
# Data overload
# Data overload
# Data overload
# Data overload
# Data overload
# Data overload
# Data overload
# Data overload
# Data overload
# Data overload
# Data overload
# Data overload
# Data overload
# Data overload
# Data overload
# Data overload
# Data overload
# Data overload
# Data overload
# Data overload
# Data overload
# Data overload
# Data overload
# Data overload
# Data overload
# Data overload
# Data overload
# Data overload
# Data overload
# Data overload
# Data overload
# Data overload
# Data overload
# Data overload
# Data overload
# Data overload
# Data overload
# Data overload
# Data overload
# Data overload
# Data overload
# Data overload
# Data overload
# Data overload
# Data overload
# Data overload
# Data overload
# Data overload
# Data overload
# Data overload
# Data overload
# Data overload
# Data overload
# Data overload
# Data overload
# Data overload
# Data overload
# Data overload
# Data overload
# Data overload
# Data overload
# Data overload
# Data overload
# Data overload
# Data overload
# Data overload
# Data overload
# Data overload
# Data overload
# Data overload
# Data overload
# Data overload
# Data overload
# Data overload
# Data overload
# Data overload
# Data overload
# Data overload
# Data overload
# Data overload
# Data overload
# Data overload
# Data overload
# Data overload
# Data overload
# Data overload
# Data overload
# Data overload
# Data overload
# Data overload
# Data overload
# Data overload
# Data overload
# Data overload
# Data overload
# Data overload
# Data overload
# Data overload
# Data overload
# Data overload
# Data overload
# Data overload
# Data overload
# Data overload
# Data overload
# Data overload
# Data overload
# Data overload
# Data overload
# Data overload
# Data overload
# Data overload
# Data overload
# Data overload
# Data overload
# Data overload
# Data overload
# Data overload
# Data overload
# Data overload
# Data overload
# Data overload
# Data overload
# Data overload
# Data overload
# Data overload
# Data overload
# Data overload
# Data overload
# Data overload
# Data overload
# Data overload
# Data overload
# Data overload
# Data overload
# Data overload
# Data overload
# Data overload
# Data overload
# Data overload
# Data overload
# Data overload
# Data overload
# Data overload
# Data overload
# Data overload
# Data overload
# Data overload
# Data overload
# Data overload
# Data overload
# Data overload
# Data overload
# Data overload
# Data overload
# Data overload
# Data overload
# Data overload
# Data overload
# Data overload
# Data overload
# Data overload
# Data overload
# Data overload
# Data overload
# Data overload
# Data overload
# Data overload
# Data overload
# Data overload
# Data overload
# Data overload
# Data overload
# Data overload
# Data overload
# Data overload
# Data overload
# Data overload
# Data overload
# Data overload
# Data overload
# Data overload
# Data overload
# Data overload
# Data overload
# Data overload
# Data overload
# Data overload
# Data overload
# Data overload
# Data overload
# Data overload
# Data overload
# Data overload
# Data overload
# Data overload
# Data overload
# Data overload
# Data overload
# Data overload
# Data overload
# Data overload
# Data overload
# Data overload
# Data overload
# Data overload
# Data overload
# Data overload
# Data overload
# Data overload
# Data overload
# Data overload
# Data overload
# Data overload
# Data overload
# Data overload
# Data overload
# Data overload
# Data overload
# Data overload
# Data overload
# Data overload
# Data overload
# Data overload
# Data overload
# Data overload
# Data overload
# Data overload
# Data overload
# Data overload
# Data overload
# Data overload
# Data overload
# Data overload
# Data overload
# Data overload
# Data overload
# Data overload
# Data overload
# Data overload
# Data overload
# Data overload
# Data overload
# Data overload
# Data overload
# Data overload
# Data overload
# Data overload
# Data overload
# Data overload
# Data overload
# Data overload
# Data overload
# Data overload
# Data overload
# Data overload
# Data overload
# Data overload
# Data overload
# Data overload
# Data overload
# Data overload
# Data overload
# Data overload
# Data overload
# Data overload
# Data overload
# Data overload
# Data overload
# Data overload
# Data overload
# Data overload
# Data overload
# Data overload
# Data overload
# Data overload
# Data overload
# Data overload
# Data overload
# Data overload
# Data overload
# Data overload
# Data overload
# Data overload
# Data overload
# Data overload
# Data overload
# Data overload
# Data overload
# Data overload
# Data overload
# Data overload
# Data overload
# Data overload
# Data overload
# Data overload
# Data overload
# Data overload
# Data overload
# Data overload
# Data overload
# Data overload
# Data overload
# Data overload
# Data overload
# Data overload
# Data overload
# Data overload
# Data overload
# Data overload
# Data overload
# Data overload
# Data overload
# Data overload
# Data overload
# Data overload
# Data overload
# Data overload
# Data overload
# Data overload
# Data overload
# Data overload
# Data overload
# Data overload
# Data overload
# Data overload
# Data overload
# Data overload
# Data overload
# Data overload
# Data overload
# Data overload
# Data overload
# Data overload
# Data overload
# Data overload
# Data overload
# Data overload
# Data overload
# Data overload
# Data overload
# Data overload
# Data overload
# Data overload
# Data overload
# Data overload
# Data overload
# Data overload
# Data overload
# Data overload
# Data overload
# Data overload
# Data overload
# Data overload
# Data overload
# Data overload
# Data overload
# Data overload
# Data overload
# Data overload
# Data overload
# Data overload
# Data overload
# Data overload
# Data overload
# Data overload
# Data overload
# Data overload
# Data overload
# Data overload
# Data overload
# Data overload
# Data overload
# Data overload
# Data overload
# Data overload
# Data overload
# Data overload
# Data overload
# Data overload
# Data overload
# Data overload
# Data overload
# Data overload
# Data overload
# Data overload
# Data overload
# Data overload
# Data overload
# Data overload
# Data overload
# Data overload
# Data overload
# Data overload
# Data overload
# Data overload
# Data overload
# Data overload
# Data overload
# Data overload
# Data overload
# Data overload
# Data overload
# Data overload
# Data overload
# Data overload
# Data overload
# Data overload
# Data overload
# Data overload
# Data overload
# Data overload
# Data overload
# Data overload
# Data overload
# Data overload
# Data overload
# Data overload
# Data overload
# Data overload
# Data overload
# Data overload
# Data overload
# Data overload
# Data overload
# Data overload
# Data overload
# Data overload
# Data overload
# Data overload
# Data overload
# Data overload
# Data overload
# Data overload
# Data overload
# Data overload
# Data overload
# Data overload
# Data overload
# Data overload
# Data overload
# Data overload
# Data overload
# Data overload
# Data overload
# Data overload
# Data overload
# Data overload
# Data overload
# Data overload
# Data overload
# Data overload
# Data overload
# Data overload
# Data overload
# Data overload
# Data overload
# Data overload
# Data overload
# Data overload
# Data overload
# Data overload
# Data overload
# Data overload
# Data overload
# Data overload
# Data overload
# Data overload
# Data overload
# Data overload
# Data overload
# Data overload
# Data overload
# Data overload
# Data overload
# Data overload
# Data overload
# Data overload
# Data overload
# Data overload
# Data overload
# Data overload
# Data overload
# Data overload
# Data overload
# Data overload
# Data overload
# Data overload
# Data overload
# Data overload
# Data overload
# Data overload
# Data overload
# Data overload
# Data overload
# Data overload
# Data overload
# Data overload
# Data overload
# Data overload
# Data overload
# Data overload
# Data overload
# Data overload
# Data overload
# Data overload
# Data overload
# Data overload
# Data overload
# Data overload
# Data overload
# Data overload
# Data overload
# Data overload
# Data overload
# Data overload
# Data overload
# Data overload
# Data overload
# Data overload
# Data overload
# Data overload
# Data overload
# Data overload
# Data overload
# Data overload
# Data overload
# Data overload
# Data overload
# Data overload
# Data overload
# Data overload
# Data overload
# Data overload
# Data overload
# Data overload
# Data overload
# Data overload
# Data overload
# Data overload
# Data overload
# Data overload
# Data overload
# Data overload
# Data overload
# Data overload
# Data overload
# Data overload
# Data overload
# Data overload
# Data overload
# Data overload
# Data overload
# Data overload
# Data overload
# Data overload
# Data overload
# Data overload
# Data overload
# Data overload
# Data overload
# Data overload
# Data overload
# Data overload
# Data overload
# Data overload
# Data overload
# Data overload
# Data overload
# Data overload
# Data overload
# Data overload
# Data overload
# Data overload
# Data overload
# Data overload
# Data overload
# Data overload
# Data overload
# Data overload
# Data overload
# Data overload
# Data overload
# Data overload
# Data overload
# Data overload
# Data overload
# Data overload
# Data overload
# Data overload
# Data overload
# Data overload
# Data overload
# Data overload
# Data overload
# Data overload
# Data overload
# Data overload
# Data overload
# Data overload
# Data overload
# Data overload
# Data overload
# Data overload
# Data overload
# Data overload
# Data overload
# Data overload
# Data overload
# Data overload
# Data overload
# Data overload
# Data overload
# Data overload
# Data overload
# Data overload
# Data overload
# Data overload
# Data overload
# Data overload
# Data overload
# Data overload
# Data overload
# Data overload
# Data overload
# Data overload
# Data overload
# Data overload
# Data overload
# Data overload
# Data overload
# Data overload
# Data overload
# Data overload
# Data overload
# Data overload
# Data overload
# Data overload
# Data overload
# Data overload
# Data overload
# Data overload
# Data overload
# Data overload
# Data overload
# Data overload
# Data overload
# Data overload
# Data overload
# Data overload
# Data overload
# Data overload
# Data overload
# Data overload
# Data overload
# Data overload
# Data overload
# Data overload
# Data overload
# Data overload
# Data overload
# Data overload
# Data overload
# Data overload
# Data overload
# Data overload
# Data overload
# Data overload
# Data overload
# Data overload
# Data overload
# Data overload
# Data overload
# Data overload
# Data overload
# Data overload
# Data overload
# Data overload
# Data overload
# Data overload
# Data overload
# Data overload
# Data overload
# Data overload
# Data overload
# Data overload
# Data overload
# Data overload
# Data overload
# Data overload
# Data overload
# Data overload
# Data overload
# Data overload
# Data overload
# Data overload
# Data overload
# Data overload
# Data overload
# Data overload
# Data overload
# Data overload
# Data overload
# Data overload
# Data overload
# Data overload
# Data overload
# Data overload
# Data overload
# Data overload
# Data overload
# Data overload
# Data overload
# Data overload
# Data overload
# Data overload
# Data overload
# Data overload
# Data overload
# Data overload
# Data overload
# Data overload
# Data overload
# Data overload
# Data overload
# Data overload
# Data overload
# Data overload
# Data overload
# Data overload
# Data overload
# Data overload
# Data overload
# Data overload
# Data overload
# Data overload
# Data overload
# Data overload
# Data overload
# Data overload
# Data overload
# Data overload
# Data overload
# Data overload
# Data overload
# Data overload
# Data overload
# Data overload
# Data overload
# Data overload
# Data overload
# Data overload
# Data overload
# Data overload
# Data overload
# Data overload
# Data overload
# Data overload
# Data overload
# Data overload
# Data overload
# Data overload
# Data overload
# Data overload
# Data overload
# Data overload
# Data overload
# Data overload
# Data overload
# Data overload
# Data overload
# Data overload
# Data overload
# Data overload
# Data overload
# Data overload
# Data overload
# Data overload
# Data overload
# Data overload
# Data overload
# Data overload
# Data overload
# Data overload
# Data overload
# Data overload
# Data overload
# Data overload
# Data overload
# Data overload
# Data overload
# Data overload
# Data overload
# Data overload
# Data overload
# Data overload
# Data overload
# Data overload
# Data overload
# Data overload
# Data overload
# Data overload
# Data overload
# Data overload
# Data overload
# Data overload
# Data overload
# Data overload
# Data overload
# Data overload
# Data overload
# Data overload
# Data overload
# Data overload
# Data overload
# Data overload
# Data overload
# Data overload
# Data overload
# Data overload
# Data overload
# Data overload
# Data overload
# Data overload
# Data overload
# Data overload
# Data overload
# Data overload
# Data overload
# Data overload
# Data overload
# Data overload
# Data overload
# Data overload
# Data overload
# Data overload
# Data overload
# Data overload
# Data overload
# Data overload
# Data overload
# Data overload
# Data overload
# Data overload
# Data overload
# Data overload
# Data overload
# Data overload
# Data overload
# Data overload
# Data overload
# Data overload
# Data overload
# Data overload
# Data overload
# Data overload
# Data overload
# Data overload
# Data overload
# Data overload
# Data overload
# Data overload
# Data overload
# Data overload
# Data overload
# Data overload
# Data overload
# Data overload
# Data overload
# Data overload
# Data overload
# Data overload
# Data overload
# Data overload
# Data overload
# Data overload
# Data overload
# Data overload
# Data overload
# Data overload
# Data overload
# Data overload
# Data overload
# Data overload
# Data overload
# Data overload
# Data overload
# Data overload
# Data overload
# Data overload
# Data overload
# Data overload
# Data overload
# Data overload
# Data overload
# Data overload
# Data overload
# Data overload
# Data overload
# Data overload
# Data overload
# Data overload
# Data overload
# Data overload
# Data overload
# Data overload
# Data overload
# Data overload
# Data overload
# Data overload
# Data overload
# Data overload
# Data overload
# Data overload
# Data overload
# Data overload
# Data overload
# Data overload
# Data overload
# Data overload
# Data overload
# Data overload
# Data overload
# Data overload
# Data overload
# Data overload
# Data overload
# Data overload
# Data overload
# Data overload
# Data overload
# Data overload
# Data overload
# Data overload
# Data overload
# Data overload
# Data overload
# Data overload
# Data overload
# Data overload
# Data overload
# Data overload
# Data overload
# Data overload
# Data overload
# Data overload
# Data overload
# Data overload
# Data overload
# Data overload
# Data overload
# Data overload
# Data overload
# Data overload
# Data overload
# Data overload
# Data overload
# Data overload
# Data overload
# Data overload
# Data overload
# Data overload
# Data overload
# Data overload
# Data overload
# Data overload
# Data overload
# Data overload
# Data overload
# Data overload
# Data overload
# Data overload
# Data overload
# Data overload
# Data overload
# Data overload
# Data overload
# Data overload
# Data overload
# Data overload
# Data overload
# Data overload
# Data overload
# Data overload
# Data overload
# Data overload
# Data overload
# Data overload
# Data overload
# Data overload
# Data overload
# Data overload
# Data overload
# Data overload
# Data overload
# Data overload
# Data overload
# Data overload
# Data overload
# Data overload
# Data overload
# Data overload
# Data overload
# Data overload
# Data overload
# Data overload
# Data overload
# Data overload
# Data overload
# Data overload
# Data overload
# Data overload
# Data overload
# Data overload
# Data overload
# Data overload
# Data overload
# Data overload
# Data overload
# Data overload
# Data overload
# Data overload
# Data overload
# Data overload
# Data overload
# Data overload
# Data overload
# Data overload
# Data overload
# Data overload
# Data overload
# Data overload
# Data overload
# Data overload
# Data overload
# Data overload
# Data overload
# Data overload
# Data overload
# Data overload
# Data overload
# Data overload
# Data overload
# Data overload
# Data overload
# Data overload
# Data overload
# Data overload
# Data overload
# Data overload
# Data overload
# Data overload
# Data overload
# Data overload
# Data overload
# Data overload
# Data overload
# Data overload
# Data overload
# Data overload
# Data overload
# Data overload
# Data overload
# Data overload
# Data overload
# Data overload
# Data overload
# Data overload
# Data overload
# Data overload
# Data overload
# Data overload
# Data overload
# Data overload
# Data overload
# Data overload
# Data overload
# Data overload
# Data overload
# Data overload
# Data overload
# Data overload
# Data overload
# Data overload
# Data overload
# Data overload
# Data overload
# Data overload
# Data overload
# Data overload
# Data overload
# Data overload
# Data overload
# Data overload
# Data overload
# Data overload
# Data overload
# Data overload
# Data overload
# Data overload
# Data overload
# Data overload
# Data overload
# Data overload
# Data overload
# Data overload
# Data overload
# Data overload
# Data overload
# Data overload
# Data overload
# Data overload
# Data overload
# Data overload
# Data overload
# Data overload
# Data overload
# Data overload
# Data overload
# Data overload
# Data overload
# Data overload
# Data overload
# Data overload
# Data overload
# Data overload
# Data overload
# Data overload
# Data overload
# Data overload
# Data overload
# Data overload
# Data overload
# Data overload
# Data overload
# Data overload
# Data overload
# Data overload
# Data overload
# Data overload
# Data successfully load to rds
# Data successfully load to rds
# Data successfully load to rds
# Data successfully load to rds
# Data successfully load to rds
# Data overload
# Data overload
# Data overload
# Data overload
# Data overload
# Data overload
# Data overload
# Data overload
# Data overload
# Data overload
# Data overload
# Data overload
# Data overload
# Data overload
# Data overload
# Data overload
# Data overload
# Data overload
# Data overload
# Data overload
# Data overload
# Data overload
# Data overload
# Data overload
# Data overload
# Data overload
# Data overload
# Data overload
# Data overload
# Data overload
# Data overload
# Data overload
# Data overload
# Data overload
# Data overload
# Data overload
# Data overload
# Data overload
# Data overload
# Data overload
# Data overload
# Data overload
# Data overload
# Data overload
# Data overload
# Data overload
# Data overload
# Data overload
# Data overload
# Data overload
# Data overload
# Data overload
# Data overload
# Data overload
# Data overload
# Data overload
# Data overload

# %%
# RDS 접속 정보
rds_host = rds_info['host']
username = rds_info['username']
password = rds_info['password']
database = rds_info['database']
# RDS에 연결
connection = mysql.connector.connect(
    host=rds_host,
    user=username,
    password=password,
    database=database
)
cursor = connection.cursor()

sql_query_tmp = f"""
    SELECT crid FROM include_cartegory
"""
cursor.execute(sql_query_tmp)
a4 = cursor.fetchall()
rds_pid_did = list(map(lambda x : int(x[0]), list(np.array(a4))))

# %%
# RDS 접속 정보
rds_host = rds_info['host']
username = rds_info['username']
password = rds_info['password']
database = rds_info['database']
# RDS에 연결
connection = mysql.connector.connect(
    host=rds_host,
    user=username,
    password=password,
    database=database
)
cursor = connection.cursor()

sql_query_tmp = f"""
    SELECT crid FROM include_cartegory
    WHERE pid = {1173140312}
"""
cursor.execute(sql_query_tmp)
a = cursor.fetchall()

# %%
# RDS 접속 정보
rds_host = rds_info['host']
username = rds_info['username']
password = rds_info['password']
database = rds_info['database']
# RDS에 연결
connection = mysql.connector.connect(
    host=rds_host,
    user=username,
    password=password,
    database=database
)
cursor = connection.cursor()

sql_query4 = """
    INSERT INTO cartegory (
        crid, job_cartegory
    ) 
    VALUES (%s, %s)
    ON DUPLICATE KEY UPDATE
        job_cartegory = VALUES(job_cartegory)
"""
for i, values in result.iterrows():
    for cart in values['job_category']:
        data4 = (str(fhash(cart)), cart)
        try:
            cursor.execute(sql_query4, data4)
            connection.commit()
            print(f"Data successfully load to rds")
        except mysql.connector.Error as error:
            print(f"Error executing SQL query for PID {values['pid']}: {error}")  # 에러 로깅
        except Exception as e:
            print(f"Unexpected error for PID {values['pid']}: {str(e)}")  # 예기치 않은 에러 로깅
cursor.close()  # 커서 종료
connection.close()  # 연결 종료
# Out:
# Data successfully load to rds
# Data successfully load to rds
# Data successfully load to rds
# Data successfully load to rds
# Data successfully load to rds
# Data successfully load to rds
# Data successfully load to rds
# Data successfully load to rds
# Data successfully load to rds
# Data successfully load to rds
# Data successfully load to rds
# Data successfully load to rds
# Data successfully load to rds
# Data successfully load to rds
# Data successfully load to rds
# Data successfully load to rds
# Data successfully load to rds
# Data successfully load to rds
# Data successfully load to rds
# Data successfully load to rds
# Data successfully load to rds
# Data successfully load to rds
# Data successfully load to rds
# Data successfully load to rds
# Data successfully load to rds
# Data successfully load to rds
# Data successfully load to rds
# Data successfully load to rds
# Data successfully load to rds
# Data successfully load to rds
# Data successfully load to rds
# Data successfully load to rds
# Data successfully load to rds
# Data successfully load to rds
# Data successfully load to rds
# Data successfully load to rds
# Data successfully load to rds
# Data successfully load to rds
# Data successfully load to rds
# Data successfully load to rds
# Data successfully load to rds
# Data successfully load to rds
# Data successfully load to rds
# Data successfully load to rds
# Data successfully load to rds
# Data successfully load to rds
# Data successfully load to rds
# Data successfully load to rds
# Data successfully load to rds
# Data successfully load to rds
# Data successfully load to rds
# Data successfully load to rds
# Data successfully load to rds
# Data successfully load to rds
# Data successfully load to rds
# Data successfully load to rds
# Data successfully load to rds
# Data successfully load to rds
# Data successfully load to rds
# Data successfully load to rds
# Data successfully load to rds
# Data successfully load to rds
# Data successfully load to rds
# Data successfully load to rds
# Data successfully load to rds
# Data successfully load to rds
# Data successfully load to rds
# Data successfully load to rds
# Data successfully load to rds
# Data successfully load to rds
# Data successfully load to rds
# Data successfully load to rds
# Data successfully load to rds
# Data successfully load to rds
# Data successfully load to rds
# Data successfully load to rds
# Data successfully load to rds
# Data successfully load to rds
# Data successfully load to rds
# Data successfully load to rds
# Data successfully load to rds
# Data successfully load to rds
# Data successfully load to rds
# Data successfully load to rds
# Data successfully load to rds
# Data successfully load to rds
# Data successfully load to rds
# Data successfully load to rds
# Data successfully load to rds
# Data successfully load to rds
# Data successfully load to rds
# Data successfully load to rds
# Data successfully load to rds
# Data successfully load to rds
# Data successfully load to rds
# Data successfully load to rds
# Data successfully load to rds
# Data successfully load to rds
# Data successfully load to rds
# Data successfully load to rds
# Data successfully load to rds
# Data successfully load to rds
# Data successfully load to rds
# Data successfully load to rds
# Data successfully load to rds
# Data successfully load to rds
# Data successfully load to rds
# Data successfully load to rds
# Data successfully load to rds
# Data successfully load to rds
# Data successfully load to rds
# Data successfully load to rds
# Data successfully load to rds
# Data successfully load to rds
# Data successfully load to rds
# Data successfully load to rds
# Data successfully load to rds
# Data successfully load to rds
# Data successfully load to rds
# Data successfully load to rds
# Data successfully load to rds
# Data successfully load to rds
# Data successfully load to rds
# Data successfully load to rds
# Data successfully load to rds
# Data successfully load to rds
# Data successfully load to rds
# Data successfully load to rds
# Data successfully load to rds
# Data successfully load to rds
# Data successfully load to rds
# Data successfully load to rds
# Data successfully load to rds
# Data successfully load to rds
# Data successfully load to rds
# Data successfully load to rds
# Data successfully load to rds
# Data successfully load to rds
# Data successfully load to rds
# Data successfully load to rds
# Data successfully load to rds
# Data successfully load to rds
# Data successfully load to rds
# Data successfully load to rds
# Data successfully load to rds
# Data successfully load to rds
# Data successfully load to rds
# Data successfully load to rds
# Data successfully load to rds
# Data successfully load to rds
# Data successfully load to rds
# Data successfully load to rds
# Data successfully load to rds
# Data successfully load to rds
# Data successfully load to rds
# Data successfully load to rds
# Data successfully load to rds
# Data successfully load to rds
# Data successfully load to rds
# Data successfully load to rds
# Data successfully load to rds
# Data successfully load to rds
# Data successfully load to rds
# Data successfully load to rds
# Data successfully load to rds
# Data successfully load to rds
# Data successfully load to rds
# Data successfully load to rds
# Data successfully load to rds
# Data successfully load to rds
# Data successfully load to rds
# Data successfully load to rds
# Data successfully load to rds
# Data successfully load to rds
# Data successfully load to rds
# Data successfully load to rds
# Data successfully load to rds
# Data successfully load to rds
# Data successfully load to rds
# Data successfully load to rds
# Data successfully load to rds
# Data successfully load to rds
# Data successfully load to rds
# Data successfully load to rds
# Data successfully load to rds
# Data successfully load to rds
# Data successfully load to rds
# Data successfully load to rds
# Data successfully load to rds
# Data successfully load to rds
# Data successfully load to rds
# Data successfully load to rds
# Data successfully load to rds
# Data successfully load to rds
# Data successfully load to rds
# Data successfully load to rds
# Data successfully load to rds
# Data successfully load to rds
# Data successfully load to rds
# Data successfully load to rds
# Data successfully load to rds
# Data successfully load to rds
# Data successfully load to rds
# Data successfully load to rds
# Data successfully load to rds
# Data successfully load to rds
# Data successfully load to rds
# Data successfully load to rds
# Data successfully load to rds
# Data successfully load to rds
# Data successfully load to rds
# Data successfully load to rds
# Data successfully load to rds
# Data successfully load to rds
# Data successfully load to rds
# Data successfully load to rds
# Data successfully load to rds
# Data successfully load to rds
# Data successfully load to rds
# Data successfully load to rds
# Data successfully load to rds
# Data successfully load to rds
# Data successfully load to rds
# Data successfully load to rds
# Data successfully load to rds
# Data successfully load to rds
# Data successfully load to rds
# Data successfully load to rds
# Data successfully load to rds
# Data successfully load to rds
# Data successfully load to rds
# Data successfully load to rds
# Data successfully load to rds
# Data successfully load to rds
# Data successfully load to rds
# Data successfully load to rds
# Data successfully load to rds
# Data successfully load to rds
# Data successfully load to rds
# Data successfully load to rds
# Data successfully load to rds
# Data successfully load to rds
# Data successfully load to rds
# Data successfully load to rds
# Data successfully load to rds
# Data successfully load to rds
# Data successfully load to rds
# Data successfully load to rds
# Data successfully load to rds
# Data successfully load to rds
# Data successfully load to rds
# Data successfully load to rds
# Data successfully load to rds
# Data successfully load to rds
# Data successfully load to rds
# Data successfully load to rds
# Data successfully load to rds
# Data successfully load to rds
# Data successfully load to rds
# Data successfully load to rds
# Data successfully load to rds
# Data successfully load to rds
# Data successfully load to rds
# Data successfully load to rds
# Data successfully load to rds
# Data successfully load to rds
# Data successfully load to rds
# Data successfully load to rds
# Data successfully load to rds
# Data successfully load to rds
# Data successfully load to rds
# Data successfully load to rds
# Data successfully load to rds
# Data successfully load to rds
# Data successfully load to rds
# Data successfully load to rds
# Data successfully load to rds
# Data successfully load to rds
# Data successfully load to rds
# Data successfully load to rds
# Data successfully load to rds
# Data successfully load to rds
# Data successfully load to rds
# Data successfully load to rds
# Data successfully load to rds
# Data successfully load to rds
# Data successfully load to rds
# Data successfully load to rds
# Data successfully load to rds
# Data successfully load to rds
# Data successfully load to rds
# Data successfully load to rds
# Data successfully load to rds
# Data successfully load to rds
# Data successfully load to rds
# Data successfully load to rds
# Data successfully load to rds
# Data successfully load to rds
# Data successfully load to rds
# Data successfully load to rds
# Data successfully load to rds
# Data successfully load to rds
# Data successfully load to rds
# Data successfully load to rds
# Data successfully load to rds
# Data successfully load to rds
# Data successfully load to rds
# Data successfully load to rds
# Data successfully load to rds
# Data successfully load to rds
# Data successfully load to rds
# Data successfully load to rds
# Data successfully load to rds
# Data successfully load to rds
# Data successfully load to rds
# Data successfully load to rds
# Data successfully load to rds
# Data successfully load to rds
# Data successfully load to rds
# Data successfully load to rds
# Data successfully load to rds
# Data successfully load to rds
# Data successfully load to rds
# Data successfully load to rds
# Data successfully load to rds
# Data successfully load to rds
# Data successfully load to rds
# Data successfully load to rds
# Data successfully load to rds
# Data successfully load to rds
# Data successfully load to rds
# Data successfully load to rds
# Data successfully load to rds
# Data successfully load to rds
# Data successfully load to rds
# Data successfully load to rds
# Data successfully load to rds
# Data successfully load to rds
# Data successfully load to rds
# Data successfully load to rds
# Data successfully load to rds
# Data successfully load to rds
# Data successfully load to rds
# Data successfully load to rds
# Data successfully load to rds
# Data successfully load to rds
# Data successfully load to rds
# Data successfully load to rds
# Data successfully load to rds
# Data successfully load to rds
# Data successfully load to rds
# Data successfully load to rds
# Data successfully load to rds
# Data successfully load to rds
# Data successfully load to rds
# Data successfully load to rds
# Data successfully load to rds
# Data successfully load to rds
# Data successfully load to rds
# Data successfully load to rds
# Data successfully load to rds
# Data successfully load to rds
# Data successfully load to rds
# Data successfully load to rds
# Data successfully load to rds
# Data successfully load to rds
# Data successfully load to rds
# Data successfully load to rds
# Data successfully load to rds
# Data successfully load to rds
# Data successfully load to rds
# Data successfully load to rds
# Data successfully load to rds
# Data successfully load to rds
# Data successfully load to rds
# Data successfully load to rds
# Data successfully load to rds
# Data successfully load to rds
# Data successfully load to rds
# Data successfully load to rds
# Data successfully load to rds
# Data successfully load to rds
# Data successfully load to rds
# Data successfully load to rds
# Data successfully load to rds
# Data successfully load to rds
# Data successfully load to rds
# Data successfully load to rds
# Data successfully load to rds
# Data successfully load to rds
# Data successfully load to rds
# Data successfully load to rds
# Data successfully load to rds
# Data successfully load to rds
# Data successfully load to rds
# Data successfully load to rds
# Data successfully load to rds
# Data successfully load to rds
# Data successfully load to rds
# Data successfully load to rds
# Data successfully load to rds
# Data successfully load to rds
# Data successfully load to rds
# Data successfully load to rds
# Data successfully load to rds
# Data successfully load to rds
# Data successfully load to rds
# Data successfully load to rds
# Data successfully load to rds
# Data successfully load to rds
# Data successfully load to rds
# Data successfully load to rds
# Data successfully load to rds
# Data successfully load to rds
# Data successfully load to rds
# Data successfully load to rds
# Data successfully load to rds
# Data successfully load to rds
# Data successfully load to rds
# Data successfully load to rds
# Data successfully load to rds
# Data successfully load to rds
# Data successfully load to rds
# Data successfully load to rds
# Data successfully load to rds
# Data successfully load to rds
# Data successfully load to rds
# Data successfully load to rds
# Data successfully load to rds
# Data successfully load to rds
# Data successfully load to rds
# Data successfully load to rds
# Data successfully load to rds
# Data successfully load to rds
# Data successfully load to rds
# Data successfully load to rds
# Data successfully load to rds
# Data successfully load to rds
# Data successfully load to rds
# Data successfully load to rds
# Data successfully load to rds
# Data successfully load to rds
# Data successfully load to rds
# Data successfully load to rds
# Data successfully load to rds
# Data successfully load to rds
# Data successfully load to rds
# Data successfully load to rds
# Data successfully load to rds
# Data successfully load to rds
# Data successfully load to rds
# Data successfully load to rds
# Data successfully load to rds
# Data successfully load to rds
# Data successfully load to rds
# Data successfully load to rds
# Data successfully load to rds
# Data successfully load to rds
# Data successfully load to rds
# Data successfully load to rds
# Data successfully load to rds
# Data successfully load to rds
# Data successfully load to rds
# Data successfully load to rds
# Data successfully load to rds
# Data successfully load to rds
# Data successfully load to rds
# Data successfully load to rds
# Data successfully load to rds
# Data successfully load to rds
# Data successfully load to rds
# Data successfully load to rds
# Data successfully load to rds
# Data successfully load to rds
# Data successfully load to rds
# Data successfully load to rds
# Data successfully load to rds
# Data successfully load to rds
# Data successfully load to rds
# Data successfully load to rds
# Data successfully load to rds
# Data successfully load to rds
# Data successfully load to rds
# Data successfully load to rds
# Data successfully load to rds
# Data successfully load to rds
# Data successfully load to rds
# Data successfully load to rds
# Data successfully load to rds
# Data successfully load to rds
# Data successfully load to rds
# Data successfully load to rds
# Data successfully load to rds
# Data successfully load to rds
# Data successfully load to rds
# Data successfully load to rds
# Data successfully load to rds
# Data successfully load to rds
# Data successfully load to rds
# Data successfully load to rds
# Data successfully load to rds
# Data successfully load to rds
# Data successfully load to rds
# Data successfully load to rds
# Data successfully load to rds
# Data successfully load to rds
# Data successfully load to rds
# Data successfully load to rds
# Data successfully load to rds
# Data successfully load to rds
# Data successfully load to rds
# Data successfully load to rds
# Data successfully load to rds
# Data successfully load to rds
# Data successfully load to rds
# Data successfully load to rds
# Data successfully load to rds
# Data successfully load to rds
# Data successfully load to rds
# Data successfully load to rds
# Data successfully load to rds
# Data successfully load to rds
# Data successfully load to rds
# Data successfully load to rds
# Data successfully load to rds
# Data successfully load to rds
# Data successfully load to rds
# Data successfully load to rds
# Data successfully load to rds
# Data successfully load to rds
# Data successfully load to rds
# Data successfully load to rds
# Data successfully load to rds
# Data successfully load to rds
# Data successfully load to rds
# Data successfully load to rds
# Data successfully load to rds
# Data successfully load to rds
# Data successfully load to rds
# Data successfully load to rds
# Data successfully load to rds
# Data successfully load to rds
# Data successfully load to rds
# Data successfully load to rds
# Data successfully load to rds
# Data successfully load to rds
# Data successfully load to rds
# Data successfully load to rds
# Data successfully load to rds
# Data successfully load to rds
# Data successfully load to rds
# Data successfully load to rds
# Data successfully load to rds
# Data successfully load to rds
# Data successfully load to rds
# Data successfully load to rds
# Data successfully load to rds
# Data successfully load to rds
# Data successfully load to rds
# Data successfully load to rds
# Data successfully load to rds
# Data successfully load to rds
# Data successfully load to rds
# Data successfully load to rds
# Data successfully load to rds
# Data successfully load to rds
# Data successfully load to rds
# Data successfully load to rds
# Data successfully load to rds
# Data successfully load to rds
# Data successfully load to rds
# Data successfully load to rds
# Data successfully load to rds
# Data successfully load to rds
# Data successfully load to rds
# Data successfully load to rds
# Data successfully load to rds
# Data successfully load to rds
# Data successfully load to rds
# Data successfully load to rds
# Data successfully load to rds
# Data successfully load to rds
# Data successfully load to rds
# Data successfully load to rds
# Data successfully load to rds
# Data successfully load to rds
# Data successfully load to rds
# Data successfully load to rds
# Data successfully load to rds
# Data successfully load to rds
# Data successfully load to rds
# Data successfully load to rds
# Data successfully load to rds
# Data successfully load to rds
# Data successfully load to rds
# Data successfully load to rds
# Data successfully load to rds
# Data successfully load to rds
# Data successfully load to rds
# Data successfully load to rds
# Data successfully load to rds
# Data successfully load to rds
# Data successfully load to rds
# Data successfully load to rds
# Data successfully load to rds
# Data successfully load to rds
# Data successfully load to rds
# Data successfully load to rds
# Data successfully load to rds
# Data successfully load to rds
# Data successfully load to rds
# Data successfully load to rds
# Data successfully load to rds
# Data successfully load to rds
# Data successfully load to rds
# Data successfully load to rds
# Data successfully load to rds
# Data successfully load to rds
# Data successfully load to rds
# Data successfully load to rds
# Data successfully load to rds
# Data successfully load to rds
# Data successfully load to rds
# Data successfully load to rds
# Data successfully load to rds
# Data successfully load to rds
# Data successfully load to rds
# Data successfully load to rds
# Data successfully load to rds
# Data successfully load to rds
# Data successfully load to rds
# Data successfully load to rds
# Data successfully load to rds
# Data successfully load to rds
# Data successfully load to rds
# Data successfully load to rds
# Data successfully load to rds
# Data successfully load to rds
# Data successfully load to rds
# Data successfully load to rds
# Data successfully load to rds
# Data successfully load to rds
# Data successfully load to rds
# Data successfully load to rds
# Data successfully load to rds
# Data successfully load to rds
# Data successfully load to rds
# Data successfully load to rds
# Data successfully load to rds
# Data successfully load to rds
# Data successfully load to rds
# Data successfully load to rds
# Data successfully load to rds
# Data successfully load to rds
# Data successfully load to rds
# Data successfully load to rds
# Data successfully load to rds
# Data successfully load to rds
# Data successfully load to rds
# Data successfully load to rds
# Data successfully load to rds
# Data successfully load to rds
# Data successfully load to rds
# Data successfully load to rds
# Data successfully load to rds
# Data successfully load to rds
# Data successfully load to rds
# Data successfully load to rds
# Data successfully load to rds
# Data successfully load to rds
# Data successfully load to rds
# Data successfully load to rds
# Data successfully load to rds
# Data successfully load to rds
# Data successfully load to rds
# Data successfully load to rds
# Data successfully load to rds
# Data successfully load to rds
# Data successfully load to rds
# Data successfully load to rds
# Data successfully load to rds
# Data successfully load to rds
# Data successfully load to rds
# Data successfully load to rds
# Data successfully load to rds
# Data successfully load to rds
# Data successfully load to rds
# Data successfully load to rds
# Data successfully load to rds
# Data successfully load to rds
# Data successfully load to rds
# Data successfully load to rds
# Data successfully load to rds
# Data successfully load to rds
# Data successfully load to rds
# Data successfully load to rds
# Data successfully load to rds
# Data successfully load to rds
# Data successfully load to rds
# Data successfully load to rds
# Data successfully load to rds
# Data successfully load to rds
# Data successfully load to rds
# Data successfully load to rds
# Data successfully load to rds
# Data successfully load to rds
# Data successfully load to rds
# Data successfully load to rds
# Data successfully load to rds
# Data successfully load to rds
# Data successfully load to rds
# Data successfully load to rds
# Data successfully load to rds
# Data successfully load to rds
# Data successfully load to rds
# Data successfully load to rds
# Data successfully load to rds
# Data successfully load to rds
# Data successfully load to rds
# Data successfully load to rds
# Data successfully load to rds
# Data successfully load to rds
# Data successfully load to rds
# Data successfully load to rds
# Data successfully load to rds
# Data successfully load to rds
# Data successfully load to rds
# Data successfully load to rds
# Data successfully load to rds
# Data successfully load to rds
# Data successfully load to rds
# Data successfully load to rds
# Data successfully load to rds
# Data successfully load to rds
# Data successfully load to rds
# Data successfully load to rds
# Data successfully load to rds
# Data successfully load to rds
# Data successfully load to rds
# Data successfully load to rds
# Data successfully load to rds
# Data successfully load to rds
# Data successfully load to rds
# Data successfully load to rds
# Data successfully load to rds
# Data successfully load to rds
# Data successfully load to rds
# Data successfully load to rds
# Data successfully load to rds
# Data successfully load to rds
# Data successfully load to rds
# Data successfully load to rds
# Data successfully load to rds
# Data successfully load to rds
# Data successfully load to rds
# Data successfully load to rds
# Data successfully load to rds
# Data successfully load to rds
# Data successfully load to rds
# Data successfully load to rds
# Data successfully load to rds
# Data successfully load to rds
# Data successfully load to rds
# Data successfully load to rds
# Data successfully load to rds
# Data successfully load to rds
# Data successfully load to rds
# Data successfully load to rds
# Data successfully load to rds
# Data successfully load to rds
# Data successfully load to rds
# Data successfully load to rds
# Data successfully load to rds
# Data successfully load to rds
# Data successfully load to rds
# Data successfully load to rds
# Data successfully load to rds
# Data successfully load to rds
# Data successfully load to rds
# Data successfully load to rds
# Data successfully load to rds
# Data successfully load to rds
# Data successfully load to rds
# Data successfully load to rds
# Data successfully load to rds
# Data successfully load to rds
# Data successfully load to rds
# Data successfully load to rds
# Data successfully load to rds
# Data successfully load to rds
# Data successfully load to rds
# Data successfully load to rds
# Data successfully load to rds
# Data successfully load to rds
# Data successfully load to rds
# Data successfully load to rds
# Data successfully load to rds
# Data successfully load to rds
# Data successfully load to rds
# Data successfully load to rds
# Data successfully load to rds
# Data successfully load to rds
# Data successfully load to rds
# Data successfully load to rds
# Data successfully load to rds
# Data successfully load to rds
# Data successfully load to rds
# Data successfully load to rds
# Data successfully load to rds
# Data successfully load to rds
# Data successfully load to rds
# Data successfully load to rds
# Data successfully load to rds
# Data successfully load to rds
# Data successfully load to rds
# Data successfully load to rds
# Data successfully load to rds
# Data successfully load to rds
# Data successfully load to rds
# Data successfully load to rds
# Data successfully load to rds
# Data successfully load to rds
# Data successfully load to rds
# Data successfully load to rds
# Data successfully load to rds
# Data successfully load to rds
# Data successfully load to rds
# Data successfully load to rds
# Data successfully load to rds
# Data successfully load to rds
# Data successfully load to rds
# Data successfully load to rds
# Data successfully load to rds
# Data successfully load to rds
# Data successfully load to rds
# Data successfully load to rds
# Data successfully load to rds
# Data successfully load to rds
# Data successfully load to rds
# Data successfully load to rds
# Data successfully load to rds
# Data successfully load to rds
# Data successfully load to rds
# Data successfully load to rds
# Data successfully load to rds
# Data successfully load to rds
# Data successfully load to rds
# Data successfully load to rds
# Data successfully load to rds
# Data successfully load to rds
# Data successfully load to rds
# Data successfully load to rds
# Data successfully load to rds
# Data successfully load to rds
# Data successfully load to rds
# Data successfully load to rds
# Data successfully load to rds
# Data successfully load to rds
# Data successfully load to rds
# Data successfully load to rds
# Data successfully load to rds
# Data successfully load to rds
# Data successfully load to rds
# Data successfully load to rds
# Data successfully load to rds
# Data successfully load to rds
# Data successfully load to rds
# Data successfully load to rds
# Data successfully load to rds
# Data successfully load to rds
# Data successfully load to rds
# Data successfully load to rds
# Data successfully load to rds
# Data successfully load to rds
# Data successfully load to rds
# Data successfully load to rds
# Data successfully load to rds
# Data successfully load to rds
# Data successfully load to rds
# Data successfully load to rds
# Data successfully load to rds
# Data successfully load to rds
# Data successfully load to rds
# Data successfully load to rds
# Data successfully load to rds
# Data successfully load to rds
# Data successfully load to rds
# Data successfully load to rds
# Data successfully load to rds
# Data successfully load to rds
# Data successfully load to rds
# Data successfully load to rds
# Data successfully load to rds
# Data successfully load to rds
# Data successfully load to rds
# Data successfully load to rds
# Data successfully load to rds
# Data successfully load to rds
# Data successfully load to rds
# Data successfully load to rds
# Data successfully load to rds
# Data successfully load to rds
# Data successfully load to rds
# Data successfully load to rds
# Data successfully load to rds
# Data successfully load to rds
# Data successfully load to rds
# Data successfully load to rds
# Data successfully load to rds
# Data successfully load to rds
# Data successfully load to rds
# Data successfully load to rds
# Data successfully load to rds
# Data successfully load to rds
# Data successfully load to rds
# Data successfully load to rds
# Data successfully load to rds
# Data successfully load to rds
# Data successfully load to rds
# Data successfully load to rds
# Data successfully load to rds
# Data successfully load to rds
# Data successfully load to rds
# Data successfully load to rds
# Data successfully load to rds
# Data successfully load to rds
# Data successfully load to rds
# Data successfully load to rds
# Data successfully load to rds
# Data successfully load to rds
# Data successfully load to rds
# Data successfully load to rds
# Data successfully load to rds
# Data successfully load to rds
# Data successfully load to rds
# Data successfully load to rds
# Data successfully load to rds
# Data successfully load to rds
# Data successfully load to rds
# Data successfully load to rds
# Data successfully load to rds
# Data successfully load to rds
# Data successfully load to rds
# Data successfully load to rds
# Data successfully load to rds
# Data successfully load to rds
# Data successfully load to rds
# Data successfully load to rds
# Data successfully load to rds
# Data successfully load to rds
# Data successfully load to rds
# Data successfully load to rds
# Data successfully load to rds
# Data successfully load to rds
# Data successfully load to rds
# Data successfully load to rds
# Data successfully load to rds
# Data successfully load to rds
# Data successfully load to rds
# Data successfully load to rds
# Data successfully load to rds
# Data successfully load to rds
# Data successfully load to rds
# Data successfully load to rds
# Data successfully load to rds
# Data successfully load to rds
# Data successfully load to rds
# Data successfully load to rds
# Data successfully load to rds
# Data successfully load to rds
# Data successfully load to rds
# Data successfully load to rds
# Data successfully load to rds
# Data successfully load to rds
# Data successfully load to rds
# Data successfully load to rds
# Data successfully load to rds
# Data successfully load to rds
# Data successfully load to rds
# Data successfully load to rds
# Data successfully load to rds
# Data successfully load to rds
# Data successfully load to rds
# Data successfully load to rds
# Data successfully load to rds
# Data successfully load to rds
# Data successfully load to rds
# Data successfully load to rds
# Data successfully load to rds
# Data successfully load to rds
# Data successfully load to rds
# Data successfully load to rds
# Data successfully load to rds
# Data successfully load to rds
# Data successfully load to rds
# Data successfully load to rds
# Data successfully load to rds
# Data successfully load to rds
# Data successfully load to rds
# Data successfully load to rds
# Data successfully load to rds
# Data successfully load to rds
# Data successfully load to rds
# Data successfully load to rds
# Data successfully load to rds
# Data successfully load to rds
# Data successfully load to rds
# Data successfully load to rds
# Data successfully load to rds
# Data successfully load to rds
# Data successfully load to rds
# Data successfully load to rds
# Data successfully load to rds
# Data successfully load to rds
# Data successfully load to rds
# Data successfully load to rds
# Data successfully load to rds
# Data successfully load to rds
# Data successfully load to rds
# Data successfully load to rds
# Data successfully load to rds
# Data successfully load to rds
# Data successfully load to rds
# Data successfully load to rds
# Data successfully load to rds
# Data successfully load to rds
# Data successfully load to rds
# Data successfully load to rds
# Data successfully load to rds
# Data successfully load to rds
# Data successfully load to rds
# Data successfully load to rds
# Data successfully load to rds
# Data successfully load to rds
# Data successfully load to rds
# Data successfully load to rds
# Data successfully load to rds
# Data successfully load to rds
# Data successfully load to rds
# Data successfully load to rds
# Data successfully load to rds
# Data successfully load to rds
# Data successfully load to rds
# Data successfully load to rds
# Data successfully load to rds
# Data successfully load to rds
# Data successfully load to rds
# Data successfully load to rds
# Data successfully load to rds
# Data successfully load to rds
# Data successfully load to rds
# Data successfully load to rds
# Data successfully load to rds
# Data successfully load to rds
# Data successfully load to rds
# Data successfully load to rds
# Data successfully load to rds
# Data successfully load to rds
# Data successfully load to rds
# Data successfully load to rds
# Data successfully load to rds
# Data successfully load to rds
# Data successfully load to rds
# Data successfully load to rds
# Data successfully load to rds
# Data successfully load to rds
# Data successfully load to rds
# Data successfully load to rds
# Data successfully load to rds
# Data successfully load to rds
# Data successfully load to rds
# Data successfully load to rds
# Data successfully load to rds
# Data successfully load to rds
# Data successfully load to rds
# Data successfully load to rds
# Data successfully load to rds
# Data successfully load to rds
# Data successfully load to rds
# Data successfully load to rds
# Data successfully load to rds
# Data successfully load to rds
# Data successfully load to rds
# Data successfully load to rds
# Data successfully load to rds
# Data successfully load to rds
# Data successfully load to rds
# Data successfully load to rds
# Data successfully load to rds
# Data successfully load to rds
# Data successfully load to rds
# Data successfully load to rds
# Data successfully load to rds
# Data successfully load to rds
# Data successfully load to rds
# Data successfully load to rds
# Data successfully load to rds
# Data successfully load to rds
# Data successfully load to rds
# Data successfully load to rds
# Data successfully load to rds
# Data successfully load to rds
# Data successfully load to rds
# Data successfully load to rds
# Data successfully load to rds
# Data successfully load to rds
# Data successfully load to rds
# Data successfully load to rds
# Data successfully load to rds
# Data successfully load to rds
# Data successfully load to rds
# Data successfully load to rds
# Data successfully load to rds
# Data successfully load to rds
# Data successfully load to rds
# Data successfully load to rds
# Data successfully load to rds
# Data successfully load to rds
# Data successfully load to rds
# Data successfully load to rds
# Data successfully load to rds
# Data successfully load to rds
# Data successfully load to rds
# Data successfully load to rds
# Data successfully load to rds
# Data successfully load to rds
# Data successfully load to rds
# Data successfully load to rds
# Data successfully load to rds
# Data successfully load to rds
# Data successfully load to rds
# Data successfully load to rds
# Data successfully load to rds
# Data successfully load to rds
# Data successfully load to rds
# Data successfully load to rds
# Data successfully load to rds
# Data successfully load to rds
# Data successfully load to rds
# Data successfully load to rds
# Data successfully load to rds
# Data successfully load to rds
# Data successfully load to rds
# Data successfully load to rds
# Data successfully load to rds
# Data successfully load to rds
# Data successfully load to rds
# Data successfully load to rds
# Data successfully load to rds
# Data successfully load to rds
# Data successfully load to rds
# Data successfully load to rds
# Data successfully load to rds
# Data successfully load to rds
# Data successfully load to rds
# Data successfully load to rds
# Data successfully load to rds
# Data successfully load to rds
# Data successfully load to rds
# Data successfully load to rds
# Data successfully load to rds
# Data successfully load to rds
# Data successfully load to rds
# Data successfully load to rds
# Data successfully load to rds
# Data successfully load to rds
# Data successfully load to rds
# Data successfully load to rds
# Data successfully load to rds
# Data successfully load to rds
# Data successfully load to rds
# Data successfully load to rds
# Data successfully load to rds
# Data successfully load to rds
# Data successfully load to rds
# Data successfully load to rds
# Data successfully load to rds
# Data successfully load to rds
# Data successfully load to rds
# Data successfully load to rds
# Data successfully load to rds
# Data successfully load to rds
# Data successfully load to rds
# Data successfully load to rds
# Data successfully load to rds
# Data successfully load to rds
# Data successfully load to rds
# Data successfully load to rds
# Data successfully load to rds
# Data successfully load to rds
# Data successfully load to rds
# Data successfully load to rds
# Data successfully load to rds
# Data successfully load to rds
# Data successfully load to rds
# Data successfully load to rds
# Data successfully load to rds
# Data successfully load to rds
# Data successfully load to rds
# Data successfully load to rds
# Data successfully load to rds
# Data successfully load to rds
# Data successfully load to rds
# Data successfully load to rds
# Data successfully load to rds
# Data successfully load to rds
# Data successfully load to rds
# Data successfully load to rds
# Data successfully load to rds
# Data successfully load to rds
# Data successfully load to rds
# Data successfully load to rds
# Data successfully load to rds
# Data successfully load to rds
# Data successfully load to rds
# Data successfully load to rds
# Data successfully load to rds
# Data successfully load to rds
# Data successfully load to rds
# Data successfully load to rds
# Data successfully load to rds
# Data successfully load to rds
# Data successfully load to rds
# Data successfully load to rds
# Data successfully load to rds
# Data successfully load to rds
# Data successfully load to rds
# Data successfully load to rds
# Data successfully load to rds
# Data successfully load to rds
# Data successfully load to rds
# Data successfully load to rds
# Data successfully load to rds
# Data successfully load to rds
# Data successfully load to rds
# Data successfully load to rds
# Data successfully load to rds
# Data successfully load to rds
# Data successfully load to rds
# Data successfully load to rds
# Data successfully load to rds
# Data successfully load to rds
# Data successfully load to rds
# Data successfully load to rds
# Data successfully load to rds
# Data successfully load to rds
# Data successfully load to rds
# Data successfully load to rds
# Data successfully load to rds
# Data successfully load to rds
# Data successfully load to rds
# Data successfully load to rds
# Data successfully load to rds
# Data successfully load to rds
# Data successfully load to rds
# Data successfully load to rds
# Data successfully load to rds
# Data successfully load to rds
# Data successfully load to rds
# Data successfully load to rds
# Data successfully load to rds
# Data successfully load to rds
# Data successfully load to rds
# Data successfully load to rds
# Data successfully load to rds
# Data successfully load to rds
# Data successfully load to rds
# Data successfully load to rds
# Data successfully load to rds
# Data successfully load to rds
# Data successfully load to rds
# Data successfully load to rds
# Data successfully load to rds
# Data successfully load to rds
# Data successfully load to rds
# Data successfully load to rds
# Data successfully load to rds
# Data successfully load to rds
# Data successfully load to rds
# Data successfully load to rds
# Data successfully load to rds
# Data successfully load to rds
# Data successfully load to rds
# Data successfully load to rds
# Data successfully load to rds
# Data successfully load to rds
# Data successfully load to rds
# Data successfully load to rds
# Data successfully load to rds
# Data successfully load to rds
# Data successfully load to rds
# Data successfully load to rds
# Data successfully load to rds
# Data successfully load to rds
# Data successfully load to rds
# Data successfully load to rds
# Data successfully load to rds
# Data successfully load to rds
# Data successfully load to rds
# Data successfully load to rds
# Data successfully load to rds
# Data successfully load to rds
# Data successfully load to rds
# Data successfully load to rds
# Data successfully load to rds
# Data successfully load to rds
# Data successfully load to rds
# Data successfully load to rds
# Data successfully load to rds
# Data successfully load to rds
# Data successfully load to rds
# Data successfully load to rds
# Data successfully load to rds
# Data successfully load to rds
# Data successfully load to rds
# Data successfully load to rds
# Data successfully load to rds
# Data successfully load to rds
# Data successfully load to rds
# Data successfully load to rds
# Data successfully load to rds
# Data successfully load to rds
# Data successfully load to rds
# Data successfully load to rds
# Data successfully load to rds
# Data successfully load to rds
# Data successfully load to rds
# Data successfully load to rds
# Data successfully load to rds
# Data successfully load to rds
# Data successfully load to rds
# Data successfully load to rds
# Data successfully load to rds
# Data successfully load to rds
# Data successfully load to rds
# Data successfully load to rds
# Data successfully load to rds
# Data successfully load to rds
# Data successfully load to rds
# Data successfully load to rds
# Data successfully load to rds
# Data successfully load to rds
# Data successfully load to rds
# Data successfully load to rds
# Data successfully load to rds
# Data successfully load to rds
# Data successfully load to rds
# Data successfully load to rds
# Data successfully load to rds
# Data successfully load to rds
# Data successfully load to rds
# Data successfully load to rds
# Data successfully load to rds
# Data successfully load to rds
# Data successfully load to rds
# Data successfully load to rds
# Data successfully load to rds
# Data successfully load to rds
# Data successfully load to rds
# Data successfully load to rds
# Data successfully load to rds
# Data successfully load to rds
# Data successfully load to rds
# Data successfully load to rds
# Data successfully load to rds
# Data successfully load to rds
# Data successfully load to rds
# Data successfully load to rds
# Data successfully load to rds
# Data successfully load to rds
# Data successfully load to rds
# Data successfully load to rds
# Data successfully load to rds
# Data successfully load to rds
# Data successfully load to rds
# Data successfully load to rds
# Data successfully load to rds
# Data successfully load to rds
# Data successfully load to rds
# Data successfully load to rds
# Data successfully load to rds
# Data successfully load to rds
# Data successfully load to rds
# Data successfully load to rds
# Data successfully load to rds
# Data successfully load to rds
# Data successfully load to rds
# Data successfully load to rds
# Data successfully load to rds
# Data successfully load to rds
# Data successfully load to rds
# Data successfully load to rds
# Data successfully load to rds
# Data successfully load to rds
# Data successfully load to rds
# Data successfully load to rds
# Data successfully load to rds
# Data successfully load to rds
# Data successfully load to rds
# Data successfully load to rds
# Data successfully load to rds
# Data successfully load to rds
# Data successfully load to rds
# Data successfully load to rds
# Data successfully load to rds
# Data successfully load to rds
# Data successfully load to rds
# Data successfully load to rds
# Data successfully load to rds
# Data successfully load to rds
# Data successfully load to rds
# Data successfully load to rds
# Data successfully load to rds
# Data successfully load to rds
# Data successfully load to rds
# Data successfully load to rds
# Data successfully load to rds
# Data successfully load to rds
# Data successfully load to rds
# Data successfully load to rds
# Data successfully load to rds
# Data successfully load to rds
# Data successfully load to rds
# Data successfully load to rds
# Data successfully load to rds
# Data successfully load to rds
# Data successfully load to rds
# Data successfully load to rds
# Data successfully load to rds
# Data successfully load to rds
# Data successfully load to rds
# Data successfully load to rds
# Data successfully load to rds
# Data successfully load to rds
# Data successfully load to rds
# Data successfully load to rds
# Data successfully load to rds
# Data successfully load to rds
# Data successfully load to rds
# Data successfully load to rds
# Data successfully load to rds
# Data successfully load to rds
# Data successfully load to rds
# Data successfully load to rds
# Data successfully load to rds
# Data successfully load to rds
# Data successfully load to rds
# Data successfully load to rds
# Data successfully load to rds
# Data successfully load to rds
# Data successfully load to rds
# Data successfully load to rds
# Data successfully load to rds
# Data successfully load to rds
# Data successfully load to rds
# Data successfully load to rds
# Data successfully load to rds
# Data successfully load to rds
# Data successfully load to rds
# Data successfully load to rds
# Data successfully load to rds
# Data successfully load to rds
# Data successfully load to rds
# Data successfully load to rds
# Data successfully load to rds
# Data successfully load to rds
# Data successfully load to rds
# Data successfully load to rds
# Data successfully load to rds
# Data successfully load to rds
# Data successfully load to rds
# Data successfully load to rds
# Data successfully load to rds
# Data successfully load to rds
# Data successfully load to rds
# Data successfully load to rds
# Data successfully load to rds
# Data successfully load to rds
# Data successfully load to rds
# Data successfully load to rds
# Data successfully load to rds
# Data successfully load to rds
# Data successfully load to rds
# Data successfully load to rds
# Data successfully load to rds
# Data successfully load to rds
# Data successfully load to rds
# Data successfully load to rds
# Data successfully load to rds
# Data successfully load to rds
# Data successfully load to rds
# Data successfully load to rds
# Data successfully load to rds
# Data successfully load to rds
# Data successfully load to rds
# Data successfully load to rds
# Data successfully load to rds
# Data successfully load to rds
# Data successfully load to rds
# Data successfully load to rds
# Data successfully load to rds
# Data successfully load to rds
# Data successfully load to rds
# Data successfully load to rds
# Data successfully load to rds
# Data successfully load to rds
# Data successfully load to rds
# Data successfully load to rds
# Data successfully load to rds
# Data successfully load to rds
# Data successfully load to rds
# Data successfully load to rds
# Data successfully load to rds
# Data successfully load to rds
# Data successfully load to rds
# Data successfully load to rds
# Data successfully load to rds
# Data successfully load to rds
# Data successfully load to rds
# Data successfully load to rds
# Data successfully load to rds
# Data successfully load to rds
# Data successfully load to rds
# Data successfully load to rds
# Data successfully load to rds
# Data successfully load to rds
# Data successfully load to rds
# Data successfully load to rds
# Data successfully load to rds
# Data successfully load to rds
# Data successfully load to rds
# Data successfully load to rds
# Data successfully load to rds
# Data successfully load to rds
# Data successfully load to rds
# Data successfully load to rds
# Data successfully load to rds
# Data successfully load to rds
# Data successfully load to rds
# Data successfully load to rds
# Data successfully load to rds
# Data successfully load to rds
# Data successfully load to rds
# Data successfully load to rds
# Data successfully load to rds
# Data successfully load to rds
# Data successfully load to rds
# Data successfully load to rds
# Data successfully load to rds
# Data successfully load to rds
# Data successfully load to rds
# Data successfully load to rds
# Data successfully load to rds
# Data successfully load to rds
# Data successfully load to rds
# Data successfully load to rds
# Data successfully load to rds
# Data successfully load to rds
# Data successfully load to rds
# Data successfully load to rds
# Data successfully load to rds
# Data successfully load to rds
# Data successfully load to rds
# Data successfully load to rds
# Data successfully load to rds
# Data successfully load to rds
# Data successfully load to rds
# Data successfully load to rds
# Data successfully load to rds
# Data successfully load to rds
# Data successfully load to rds
# Data successfully load to rds
# Data successfully load to rds
# Data successfully load to rds
# Data successfully load to rds
# Data successfully load to rds
# Data successfully load to rds
# Data successfully load to rds
# Data successfully load to rds
# Data successfully load to rds
# Data successfully load to rds
# Data successfully load to rds
# Data successfully load to rds
# Data successfully load to rds
# Data successfully load to rds
# Data successfully load to rds
# Data successfully load to rds
# Data successfully load to rds
# Data successfully load to rds
# Data successfully load to rds
# Data successfully load to rds
# Data successfully load to rds
# Data successfully load to rds
# Data successfully load to rds
# Data successfully load to rds
# Data successfully load to rds
# Data successfully load to rds
# Data successfully load to rds
# Data successfully load to rds
# Data successfully load to rds
# ...
# Data successfully load to rds
# Data successfully load to rds
# Data successfully load to rds
# Data successfully load to rds
# Data successfully load to rds
# Data successfully load to rds
# Data successfully load to rds
# Data successfully load to rds
# Data successfully load to rds
# Data successfully load to rds
# Data successfully load to rds
# Data successfully load to rds
# Data successfully load to rds
# Data successfully load to rds
# Data successfully load to rds
# Data successfully load to rds
# Data successfully load to rds
# Data successfully load to rds
# Data successfully load to rds
# Data successfully load to rds
# Data successfully load to rds
# Data successfully load to rds
# Data successfully load to rds
# Data successfully load to rds
# Data successfully load to rds
# Data successfully load to rds
# Data successfully load to rds
# Data successfully load to rds
# Data successfully load to rds
# Data successfully load to rds
# Data successfully load to rds
# Data successfully load to rds
# Data successfully load to rds
# Data successfully load to rds
# Data successfully load to rds
# Data successfully load to rds
# Data successfully load to rds
# Data successfully load to rds
# Data successfully load to rds
# Data successfully load to rds
# Data successfully load to rds
# Data successfully load to rds
# Data successfully load to rds
# Data successfully load to rds
# Data successfully load to rds
# Data successfully load to rds
# Data successfully load to rds
# Data successfully load to rds
# Data successfully load to rds
# Data successfully load to rds
# Data successfully load to rds
# Data successfully load to rds
# Data successfully load to rds
# Data successfully load to rds
# Data successfully load to rds
# Data successfully load to rds
# Data successfully load to rds
# Data successfully load to rds
# Data successfully load to rds
# Data successfully load to rds
# Data successfully load to rds
# Data successfully load to rds
# Data successfully load to rds
# Data successfully load to rds
# Data successfully load to rds
# Data successfully load to rds
# Data successfully load to rds
# Data successfully load to rds
# Data successfully load to rds
# Data successfully load to rds
# Data successfully load to rds
# Data successfully load to rds
# Data successfully load to rds
# Data successfully load to rds
# Data successfully load to rds
# Data successfully load to rds
# Data successfully load to rds
# Data successfully load to rds
# Data successfully load to rds
# Data successfully load to rds
# Data successfully load to rds
# Data successfully load to rds
# Data successfully load to rds
# Data successfully load to rds
# Data successfully load to rds
# Data successfully load to rds
# Data successfully load to rds
# Data successfully load to rds
# Data successfully load to rds
# Data successfully load to rds
# Data successfully load to rds
# Data successfully load to rds
# Data successfully load to rds
# Data successfully load to rds
# Data successfully load to rds
# Data successfully load to rds
# Data successfully load to rds
# Data successfully load to rds
# Data successfully load to rds
# Data successfully load to rds
# Data successfully load to rds
# Data successfully load to rds
# Data successfully load to rds
# Data successfully load to rds
# Data successfully load to rds
# Data successfully load to rds
# Data successfully load to rds
# Data successfully load to rds
# Data successfully load to rds
# Data successfully load to rds
# Data successfully load to rds
# Data successfully load to rds
# Data successfully load to rds
# Data successfully load to rds
# Data successfully load to rds
# Data successfully load to rds
# Data successfully load to rds
# Data successfully load to rds
# Data successfully load to rds
# Data successfully load to rds
# Data successfully load to rds
# Data successfully load to rds
# Data successfully load to rds
# Data successfully load to rds
# Data successfully load to rds
# Data successfully load to rds
# Data successfully load to rds
# Data successfully load to rds
# Data successfully load to rds
# Data successfully load to rds
# Data successfully load to rds
# Data successfully load to rds
# Data successfully load to rds
# Data successfully load to rds
# Data successfully load to rds
# Data successfully load to rds
# Data successfully load to rds
# Data successfully load to rds
# Data successfully load to rds
# Data successfully load to rds
# Data successfully load to rds
# Data successfully load to rds
# Data successfully load to rds
# Data successfully load to rds
# Data successfully load to rds
# Data successfully load to rds
# Data successfully load to rds
# Data successfully load to rds
# Data successfully load to rds
# Data successfully load to rds
# Data successfully load to rds
# Data successfully load to rds
# Data successfully load to rds
# Data successfully load to rds
# Data successfully load to rds
# Data successfully load to rds
# Data successfully load to rds
# Data successfully load to rds
# Data successfully load to rds
# Data successfully load to rds
# Data successfully load to rds
# Data successfully load to rds
# Data successfully load to rds
# Data successfully load to rds
# Data successfully load to rds
# Data successfully load to rds
# Data successfully load to rds
# Data successfully load to rds
# Data successfully load to rds
# Data successfully load to rds
# Data successfully load to rds
# Data successfully load to rds
# Data successfully load to rds
# Data successfully load to rds
# Data successfully load to rds
# Data successfully load to rds
# Data successfully load to rds
# Data successfully load to rds
# Data successfully load to rds
# Data successfully load to rds
# Data successfully load to rds
# Data successfully load to rds
# Data successfully load to rds
# Data successfully load to rds
# Data successfully load to rds
# Data successfully load to rds
# Data successfully load to rds
# Data successfully load to rds
# Data successfully load to rds
# Data successfully load to rds
# Data successfully load to rds
# Data successfully load to rds
# Data successfully load to rds
# Data successfully load to rds
# Data successfully load to rds
# Data successfully load to rds
# Data successfully load to rds
# Data successfully load to rds
# Data successfully load to rds
# Data successfully load to rds
# Data successfully load to rds
# Data successfully load to rds
# Data successfully load to rds
# Data successfully load to rds
# Data successfully load to rds
# Data successfully load to rds
# Data successfully load to rds
# Data successfully load to rds
# Data successfully load to rds
# Data successfully load to rds
# Data successfully load to rds
# Data successfully load to rds
# Data successfully load to rds
# Data successfully load to rds
# Data successfully load to rds
# Data successfully load to rds
# Data successfully load to rds
# Data successfully load to rds
# Data successfully load to rds
# Data successfully load to rds
# Data successfully load to rds
# Data successfully load to rds
# Data successfully load to rds
# Data successfully load to rds
# Data successfully load to rds
# Data successfully load to rds
# Data successfully load to rds
# Data successfully load to rds
# Data successfully load to rds
# Data successfully load to rds
# Data successfully load to rds
# Data successfully load to rds
# Data successfully load to rds
# Data successfully load to rds
# Data successfully load to rds
# Data successfully load to rds
# Data successfully load to rds
# Data successfully load to rds
# Data successfully load to rds
# Data successfully load to rds
# Data successfully load to rds
# Data successfully load to rds
# Data successfully load to rds
# Data successfully load to rds
# Data successfully load to rds
# Data successfully load to rds
# Data successfully load to rds
# Data successfully load to rds
# Data successfully load to rds
# Data successfully load to rds
# Data successfully load to rds
# Data successfully load to rds
# Data successfully load to rds
# Data successfully load to rds
# Data successfully load to rds
# Data successfully load to rds
# Data successfully load to rds
# Data successfully load to rds
# Data successfully load to rds
# Data successfully load to rds
# Data successfully load to rds
# Data successfully load to rds
# Data successfully load to rds
# Data successfully load to rds
# Data successfully load to rds
# Data successfully load to rds
# Data successfully load to rds
# Data successfully load to rds
# Data successfully load to rds
# Data successfully load to rds
# Data successfully load to rds
# Data successfully load to rds
# Data successfully load to rds
# Data successfully load to rds
# Data successfully load to rds
# Data successfully load to rds
# Data successfully load to rds
# Data successfully load to rds
# Data successfully load to rds
# Data successfully load to rds
# Data successfully load to rds
# Data successfully load to rds
# Data successfully load to rds
# Data successfully load to rds
# Data successfully load to rds
# Data successfully load to rds
# Data successfully load to rds
# Data successfully load to rds
# Data successfully load to rds
# Data successfully load to rds
# Data successfully load to rds
# Data successfully load to rds
# Data successfully load to rds
# Data successfully load to rds
# Data successfully load to rds
# Data successfully load to rds
# Data successfully load to rds
# Data successfully load to rds
# Data successfully load to rds
# Data successfully load to rds
# Data successfully load to rds
# Data successfully load to rds
# Data successfully load to rds
# Data successfully load to rds
# Data successfully load to rds
# Data successfully load to rds
# Data successfully load to rds
# Data successfully load to rds
# Data successfully load to rds
# Data successfully load to rds
# Data successfully load to rds
# Data successfully load to rds
# Data successfully load to rds
# Data successfully load to rds
# Data successfully load to rds
# Data successfully load to rds
# Data successfully load to rds
# Data successfully load to rds
# Data successfully load to rds
# Data successfully load to rds
# Data successfully load to rds
# Data successfully load to rds
# Data successfully load to rds
# Data successfully load to rds
# Data successfully load to rds
# Data successfully load to rds
# Data successfully load to rds
# Data successfully load to rds
# Data successfully load to rds
# Data successfully load to rds
# Data successfully load to rds
# Data successfully load to rds
# Data successfully load to rds
# Data successfully load to rds
# Data successfully load to rds
# Data successfully load to rds
# Data successfully load to rds
# Data successfully load to rds
# Data successfully load to rds
# Data successfully load to rds
# Data successfully load to rds
# Data successfully load to rds
# Data successfully load to rds
# Data successfully load to rds
# Data successfully load to rds
# Data successfully load to rds
# Data successfully load to rds
# Data successfully load to rds
# Data successfully load to rds
# Data successfully load to rds
# Data successfully load to rds
# Data successfully load to rds
# Data successfully load to rds
# Data successfully load to rds
# Data successfully load to rds
# Data successfully load to rds
# Data successfully load to rds
# Data successfully load to rds
# Data successfully load to rds
# Data successfully load to rds
# Data successfully load to rds
# Data successfully load to rds
# Data successfully load to rds
# Data successfully load to rds
# Data successfully load to rds
# Data successfully load to rds
# Data successfully load to rds
# Data successfully load to rds
# Data successfully load to rds
# Data successfully load to rds
# Data successfully load to rds
# Data successfully load to rds
# Data successfully load to rds
# Data successfully load to rds
# Data successfully load to rds
# Data successfully load to rds
# Data successfully load to rds
# Data successfully load to rds
# Data successfully load to rds
# Data successfully load to rds
# Data successfully load to rds
# Data successfully load to rds
# Data successfully load to rds
# Data successfully load to rds
# Data successfully load to rds
# Data successfully load to rds
# Data successfully load to rds
# Data successfully load to rds
# Data successfully load to rds
# Data successfully load to rds
# Data successfully load to rds
# Data successfully load to rds
# Data successfully load to rds
# Data successfully load to rds
# Data successfully load to rds
# Data successfully load to rds
# Data successfully load to rds
# Data successfully load to rds
# Data successfully load to rds
# Data successfully load to rds
# Data successfully load to rds
# Data successfully load to rds
# Data successfully load to rds
# Data successfully load to rds
# Data successfully load to rds
# Data successfully load to rds
# Data successfully load to rds
# Data successfully load to rds
# Data successfully load to rds
# Data successfully load to rds
# Data successfully load to rds
# Data successfully load to rds
# Data successfully load to rds
# Data successfully load to rds
# Data successfully load to rds
# Data successfully load to rds
# Data successfully load to rds
# Data successfully load to rds
# Data successfully load to rds
# Data successfully load to rds
# Data successfully load to rds
# Data successfully load to rds
# Data successfully load to rds
# Data successfully load to rds
# Data successfully load to rds
# Data successfully load to rds
# Data successfully load to rds
# Data successfully load to rds
# Data successfully load to rds
# Data successfully load to rds
# Data successfully load to rds
# Data successfully load to rds
# Data successfully load to rds
# Data successfully load to rds
# Data successfully load to rds
# Data successfully load to rds
# Data successfully load to rds
# Data successfully load to rds
# Data successfully load to rds
# Data successfully load to rds
# Data successfully load to rds
# Data successfully load to rds
# Data successfully load to rds
# Data successfully load to rds
# Data successfully load to rds
# Data successfully load to rds
# Data successfully load to rds
# Data successfully load to rds
# Data successfully load to rds
# Data successfully load to rds
# Data successfully load to rds
# Data successfully load to rds
# Data successfully load to rds
# Data successfully load to rds
# Data successfully load to rds
# Data successfully load to rds
# Data successfully load to rds
# Data successfully load to rds
# Data successfully load to rds
# Data successfully load to rds
# Data successfully load to rds
# Data successfully load to rds
# Data successfully load to rds
# Data successfully load to rds
# Data successfully load to rds
# Data successfully load to rds
# Data successfully load to rds
# Data successfully load to rds
# Data successfully load to rds
# Data successfully load to rds
# Data successfully load to rds
# Data successfully load to rds
# Data successfully load to rds
# Data successfully load to rds
# Data successfully load to rds
# Data successfully load to rds
# Data successfully load to rds
# Data successfully load to rds
# Data successfully load to rds
# Data successfully load to rds
# Data successfully load to rds
# Data successfully load to rds
# Data successfully load to rds
# Data successfully load to rds
# Data successfully load to rds
# Data successfully load to rds
# Data successfully load to rds
# Data successfully load to rds
# Data successfully load to rds
# Data successfully load to rds
# Data successfully load to rds
# Data successfully load to rds
# Data successfully load to rds
# Data successfully load to rds
# Data successfully load to rds
# Data successfully load to rds
# Data successfully load to rds
# Data successfully load to rds
# Data successfully load to rds
# Data successfully load to rds
# Data successfully load to rds
# Data successfully load to rds
# Data successfully load to rds
# Data successfully load to rds
# Data successfully load to rds
# Data successfully load to rds
# Data successfully load to rds
# Data successfully load to rds
# Data successfully load to rds
# Data successfully load to rds
# Data successfully load to rds
# Data successfully load to rds
# Data successfully load to rds
# Data successfully load to rds
# Data successfully load to rds
# Data successfully load to rds
# Data successfully load to rds
# Data successfully load to rds
# Data successfully load to rds
# Data successfully load to rds
# Data successfully load to rds
# Data successfully load to rds
# Data successfully load to rds
# Data successfully load to rds
# Data successfully load to rds
# Data successfully load to rds
# Data successfully load to rds
# Data successfully load to rds
# Data successfully load to rds
# Data successfully load to rds
# Data successfully load to rds
# Data successfully load to rds
# Data successfully load to rds

# %%
# RDS 접속 정보
rds_host = rds_info['host']
username = rds_info['username']
password = rds_info['password']
database = rds_info['database']
# RDS에 연결
connection = mysql.connector.connect(
    host=rds_host,
    user=username,
    password=password,
    database=database
)
cursor = connection.cursor()

sql_query4 = """
    INSERT INTO cartegory (
        crid, job_cartegory
    ) 
    VALUES (%s, %s)
    ON DUPLICATE KEY UPDATE
        job_cartegory = VALUES(job_cartegory)
"""
sql_query5 = """
    INSERT INTO include_cartegory (
        crid, pid
    ) 
    VALUES (%s, %s)
"""
for i, values in result.iterrows():
    for cart in values['job_category']:
        data4 = (str(fhash(cart)), cart)
        data5 = (str(fhash(cart)),values['pid'])
        try:
            cursor.execute(sql_query4, data4)
            connection.commit()
            print(f"Data successfully load to rds")
            cursor.execute(sql_query5, data5)
            connection.commit()
            print(f"Data successfully load to rds")
        except mysql.connector.Error as error:
            print(f"Error executing SQL query for PID {values['pid']}: {error}")  # 에러 로깅
        except Exception as e:
            print(f"Unexpected error for PID {values['pid']}: {str(e)}")  # 예기치 않은 에러 로깅
cursor.close()  # 커서 종료
connection.close()  # 연결 종료

# %%
result
# Out:
#     site_symbol                                     indurstry_type  \
# 0           WAN                         [IT, Software, Technology]
# 1            JK                         [Apparel, Fashion, Export]
# 2           WAN        [IT, Software, AI, Manufacturing, Security]
# 3           PRO                                    [Software, IoT]
# 4           PRO                    [AI, Robotics, Marine, Fintech]
# ..          ...                                                ...
# 367         WAN                  [IT, Software, AI, Deep Learning]
# 368         PRO                 [Healthcare, Technology, Software]
# 369         PRO  [E-commerce, Supply Chain Management, Technology]
# 370         PRO           [Software, Technology, Operating System]
# 371          JK                [Education, Publishing, E-commerce]
#
#                                              job_title  \
# 0                                             Java 개발자
# 1                                    의류 해외영업 관련 정규직 채용
# 2                                   울산 영상처리 Python 개발자
# 3                           c#.NET 기반 IoT 플랫폼 미들웨어 개발자
# 4                   Back-end Developer (Data Platform)
# ..                                                 ...
# 367                                  Deep Learning 개발자
# 368                                           백 엔드 개발자
# 369                     Senior, Backend engineer (SCM)
# 370           [TmaxOS] 동영상 플랫폼 개발, 개방형OS 및 SuperApp 개발
# 371  영업 NO 회원관리시스템-진도설정 ,, 상담 학습진도/습관 ,, 회원코칭위주 온라인...
#
#                                           job_category  \
# 0                  [Java Developer, Software Engineer]
# 1    [International Sales, Export, Sales, Business ...
# 2                [Python Developer, Backend Developer]
# 3    [Software Engineer, Middleware Developer, IoT ...
# 4                   [Backend Developer, Data Engineer]
# ..                                                 ...
# 367            [Deep Learning Developer, AI Developer]
# 368             [Backend Developer, Software Engineer]
# 369  [Backend Developer, Software Engineer, Senior ...
# 370  [Software Engineer, Web Developer, System Soft...
# 371  [Sales, Customer Service, Education, Online Ed...
#
#                                             job_prefer  \
# 0       [관련 경력 1년 이상, SI, ERP, MES, POP 등 프로젝트 개발 유경험]
# 1                                               [null]
# 2    [최신 백엔드 기술 이해 및 습득 능력, REST API 디자인 직관, 유저 문제 ...
# 3    [닷넷 기반 C 언어 미들웨어 개발 경험, 데이터베이스 지식 보유, 데이터 수집 장...
# 4    [Gunicorn/nginx/celery/AWS 사용 경험, Python 기반 RO...
# ..                                                 ...
# 367  [LLM AI Agent 개발 경험, Mobile Application 및 Web ...
# 368  [제품, 서비스 공급 기업에서 서비스 런칭, 운영, 고도화 업무 수행 경험, 의료,...
# 369  [컴퓨터 과학 분야 석사학위 소지 혹은 5년 이상 직접적인 소프트웨어 개발 경험, ...
# 370  [Linux System, Server Architecture 이해, Web Ser...
# 371                                             [null]
#
#                                              crawl_url    end_date  \
# 0                   https://www.wanted.co.kr/wd/240609
# 1    https://www.jobkorea.co.kr/Recruit/GI_Read/455...  1727708400
# 2                   https://www.wanted.co.kr/wd/241663  1727308800
# 3    https://career.programmers.co.kr/api/job_posit...        None
# 4    https://career.programmers.co.kr/api/job_posit...
# ..                                                 ...         ...
# 367                 https://www.wanted.co.kr/wd/241695  1727654400
# 368  https://career.programmers.co.kr/api/job_posit...
# 369  https://career.programmers.co.kr/api/job_posit...
# 370  https://career.programmers.co.kr/api/job_posit...
# 371  https://www.jobkorea.co.kr/Recruit/GI_Read/455...  1726671600
#
#             pid post_status required_career  \
# 0    1919149588
# 1    1416842085        None            True
# 2    3486557072        None            None
# 3    3837504727        True            True
# 4     808590014        True            True
# ..          ...         ...             ...
# 367  2659269050        None            None
# 368  1950952480        True            True
# 369  3721845878        True            True
# 370   100900925        True           False
# 371  2585218474        None           False
#
#                           crawl_domain company_name resume_required  \
# 0                     www.wanted.co.kr         엠아이티
# 1                                 None    ㈜기수케이트레이딩            True
# 2                     www.wanted.co.kr         인터엑스            None
# 3    https://career.programmers.co.kr/        에스위너스            True
# 4    https://career.programmers.co.kr/        씨드로닉스            True
# ..                                 ...          ...             ...
# 367                   www.wanted.co.kr         비주얼신            None
# 368  https://career.programmers.co.kr/        헬스피디아            True
# 369  https://career.programmers.co.kr/      Coupang            True
# 370  https://career.programmers.co.kr/       티맥스티베로            True
# 371                               None         교원구몬            True
#
#      start_date    get_date  \
# 0                1725556052
# 1    1726066800  1726123094
# 2          None  1726160852
# 3    2024-09-12  1726125518
# 4    2024-02-23    20240828
# ..          ...         ...
# 367        None  1726160852
# 368  2024-01-03    20240828
# 369  2024-06-26    20240828
# 370  2023-07-04    20240828
# 371  1726066800  1726123094
#
#                                              dev_stack         cid  \
# 0                                               [Java]  3752537004
# 1                                                   []  3659021357
# 2    [Python, REST API, Fast API, Linux, Nginx, Apa...  1967293289
# 3                          [C#, .NET, TCP, UDP, RS232]  3294195024
# 4    [Python, Django, PostgreSQL, ROS, REST API, Gu...  3648260093
# ..                                                 ...         ...
# 367  [Python, Tensorflow, Keras, Pytorch, GPU, Deep...   777346143
# 368  [Python, Django, Java, AWS EC2, MySQL, Postgre...  2662912872
# 369      [Java, Spring, Kotlin, SQL, Spring Boot, AWS]  3572271363
# 370  [Linux, Web Service, REST API, Spring, NodeJS,...  4065120436
# 371                                                 []  4119371735
#
#                                       job_requirements
# 0                [Java 개발에 대한 깊은 이해, 팀 협업 및 커뮤니케이션 능력]
# 1              [해외 영업, 의류 수출, 바이어 발굴, 수출 계약, 영문 서류 작성]
# 2    [파이썬 백엔드 개발 경력 2년 이상, Nginx, Apache 웹서버 구축 및 최...
# 3    [3년 이상 경력, C#, .NET, 미들웨어 개발, 데이터베이스 지식, 데이터 수...
# 4    [Django (Python) 기반 실무 개발 경력 2년 이상, Django RES...
# ..                                                 ...
# 367  [새로운 연구/기술 Follow-up, 고속 병렬 처리 GPU 관련 개발 및 빅데이...
# 368  [웹에 대한 전반적인 지식, 웹 통신의 흐름, 인프라에 대한 이해, 제품, 서비스 ...
# 369  [컴퓨터 과학 전공 우대 혹은 그에 준하는 학사학위 소지, 최소 5년 이상 직접적인...
# 370  [4년제 정규 대학 졸업자 및 졸업예정자 (학사 학위 이상), 해외여행 결격 사유 ...
# 371                  [회원 관리, 상담, 학습 진도 관리, 온라인 교육, 코칭]
#
# [372 rows x 18 columns]
