# %%
import requests
from bs4 import BeautifulSoup as BS
import pandas as pd
#from tqdm import tqdm
import json
import time
import re
import datetime

# %%
# rocketpunch crawler
def rocketpunch_crawler(url, headers):
    session = requests.Session()
    res = session.get(url.format(1), headers=headers)
    res = json.loads(res.text)
    soup = BS(res['data']['template'], 'html.parser')

    page_size = soup.find('div', {'class': 'tablet computer large screen widescreen only'}).find_all('a', {'class': 'item'})[-1].text.strip()

    data_list = parse_page(soup)

    for i in range(2, int(page_size) + 1):
        res = session.get(url.format(i), headers=headers)
        res = json.loads(res.text)
        soup = BS(res['data']['template'], 'html.parser')
        data_list.extend(parse_page(soup))
        time.sleep(2) # for sake of politeness

    return data_list

# API 호출
# company_id, company_name, job_id, description, job_title, job_career
def parse_page(soup):
    data_list = []
    for company in soup.find_all('div', {'class': 'company item'}):
        company_data = {}
        company_data['company_id'] = company['data-company_id']
        for content in company.find_all('div', {'class': 'content'}):
            company_data['company_name'] = content.find('a', {'class': 'company-name nowrap header name'}).text.strip()
            company_data['description'] = content.find('div', {'class': 'description'}).text.strip()
            
            for job_detail in content.find_all('div', {'class': 'job-detail'}):
                job_data = company_data.copy()
                job_data['job_id'] = job_detail.find('a', {'class': 'nowrap job-title'})['href'].split('/')[2]
                job_data['job_title'] = job_detail.find('a', {'class': 'nowrap job-title'}).text.strip()
                job_data['job_career'] = job_detail.find('div', {'class': 'job-stat-info'}).text.strip().split(' / ')
                job_data['timestamp'] = datetime.datetime.now().strftime('%Y-%m-%d_%H:%M:%S')
                job_data['crawl_domain'] = 'www.rocketpunch.com'
                data_list.append(job_data)
                
    return data_list

# %%
# 공고 크롤링
# job_task, job_detail, job_industry, job_specialties, date_start, date_end, timestamp
def parse_job_page(data, headers):
    job_url = 'https://www.rocketpunch.com/jobs/{}'
    session = requests.Session()
    pattern = re.compile('[ㄱ-ㅎ가-힣]+')

    for job in data:
        res = session.get(job_url.format(job['job_id']), headers=headers)
        soup = BS(res.text, 'html.parser')
        
        # 주요 업무(업무 내용) : job_task
        job_task_div = soup.find('div', class_='duty break')
        
        task_span_hidden = job_task_div.find('span', class_='hide full-text')
        task_span_short = job_task_div.find('span', class_='short-text') if not task_span_hidden else None
        task_span = task_span_hidden.text if task_span_hidden else (task_span_short.text if task_span_short else "")
        job['job_task'] = task_span.strip() if task_span else ""
        
        # 업무 기술/활동분야 : job_specialties
        specialties_raw = soup.find('div', class_='job-specialties')
        specialties = [a.text for a in specialties_raw.find_all('a')]
        job['job_specialties'] = ', '.join(specialties)
        
        # 채용 상세 : job_detail
        detail_div = soup.find('div', class_='content break')
        detail_span_hidden = detail_div.find('span', class_='hide full-text')
        detail_span_short = detail_div.find('span', class_='short-text') if not detail_span_hidden else None
        detail_span = detail_span_hidden.text if detail_span_hidden else detail_span_short.text
        job['job_detail'] = detail_span.strip() if detail_span else ""
        
        # 산업 분야 : job_industry
        industry_div = soup.find('div', class_='job-company-areas')
        industry_text = [a.text for a in industry_div.find_all('a')]
        job['job_industry'] = ', '.join(industry_text)
        
        # 채용 시작일/만료일 : date_start, date_end
        job_date = soup.find('div', class_='job-dates')
        date_span = job_date.find_all('span')
        
        #수시채용, 상시채용 예외처리
        if any(pattern.search(span.text) for span in date_span):
            job['date_start'] = datetime.datetime.now().strftime('%Y-%m-%d')
            job['date_end'] = None
            
        else:
            if len(date_span) > 1:
                job['date_start'] = datetime.datetime.strptime(date_span[0].text.strip(), '%Y.%m.%d').date()
                job['date_end'] = datetime.datetime.strptime(date_span[1].text.strip(), '%Y.%m.%d').date()
            elif len(date_span) == 1:
                job['date_start'] = datetime.datetime.strptime(date_span[0].text.strip(), '%Y.%m.%d').date()

    return data

# %%
if __name__ == "__main__" :
    headers = {
        'User-Agent': 'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/70.0.3538.77 Safari/537.36'
    }
    url = 'https://www.rocketpunch.com/api/jobs/template?page={}'
    #data_list = rocketpunch_crawler(url, headers)
    detailed_data = parse_job_page(data_list, headers)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[36], line 7
#       5 url = 'https://www.rocketpunch.com/api/jobs/template?page={}'
#       6 #data_list = rocketpunch_crawler(url, headers)
# ----> 7 detailed_data = parse_job_page(data_list, headers)
#
# Cell In[35], line 16, in parse_job_page(data, headers)
#      13 job_task_div = soup.find('div', class_='duty break')
#      15 task_span_hidden = job_task_div.find('span', class_='hide full-text')
# ---> 16 task_span = task_span_hidden.text if task_span_hidden else (task_span_short.text if task_span_short else "")
#      17 job['job_task'] = task_span.strip() if task_span else ""
#      19 # 업무 기술/활동분야 : job_specialties
#
# NameError: name 'task_span_short' is not defined

# %% [markdown]
# # 수정 코드

# %%
def parse_job_page(data, headers):
    job_url = 'https://www.rocketpunch.com/jobs/{}'
    session = requests.Session()
    pattern = re.compile('[ㄱ-ㅎ가-힣]+')

    for job in data:
        res = session.get(job_url.format(job['job_id']), headers=headers)
        soup = BS(res.text, 'html.parser')
        
        # 주요 업무(업무 내용) : job_task
        job_task_div = soup.find('div', class_='duty break')
        task_span_hidden = job_task_div.find('span', class_='hide full-text') if job_task_div else None
        task_span_short = job_task_div.find('span', class_='short-text') if job_task_div and not task_span_hidden else None
        task_span = task_span_hidden.text if task_span_hidden else (task_span_short.text if task_span_short else "")
        job['job_task'] = task_span.strip() if task_span else ""
        
        # 업무 기술/활동분야 : job_specialties
        specialties_raw = soup.find('div', class_='job-specialties')
        specialties = [a.text for a in specialties_raw.find_all('a')] if specialties_raw else []
        job['job_specialties'] = ', '.join(specialties)
        
        # 채용 상세 : job_detail
        detail_div = soup.find('div', class_='content break')
        detail_span_hidden = detail_div.find('span', class_='hide full-text') if detail_div else None
        detail_span_short = detail_div.find('span', class_='short-text') if detail_div and not detail_span_hidden else None
        detail_span = detail_span_hidden.text if detail_span_hidden else (detail_span_short.text if detail_span_short else "")
        job['job_detail'] = detail_span.strip() if detail_span else ""
        
        # 산업 분야 : job_industry
        industry_div = soup.find('div', class_='job-company-areas')
        industry_text = [a.text for a in industry_div.find_all('a')] if industry_div else []
        job['job_industry'] = ', '.join(industry_text)
        
        # 채용 시작일/만료일 : date_start, date_end
        job_date = soup.find('div', class_='job-dates')
        date_span = job_date.find_all('span') if job_date else []
        
        # 수시채용, 상시채용 예외처리
        if any(pattern.search(span.text) for span in date_span):
            job['date_start'] = datetime.datetime.now().strftime('%Y-%m-%d')
            job['date_end'] = None
        else:
            if len(date_span) > 1:
                job['date_start'] = datetime.datetime.strptime(date_span[0].text.strip(), '%Y.%m.%d').date()
                job['date_end'] = datetime.datetime.strptime(date_span[1].text.strip(), '%Y.%m.%d').date()
            elif len(date_span) == 1:
                job['date_start'] = datetime.datetime.strptime(date_span[0].text.strip(), '%Y.%m.%d').date()

    return data

# %%
if __name__ == "__main__" :
    headers = {
        'User-Agent': 'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/70.0.3538.77 Safari/537.36'
    }
    url = 'https://www.rocketpunch.com/api/jobs/template?page={}'
    data_list = rocketpunch_crawler(url, headers)
    detailed_data = parse_job_page(data_list, headers)
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# /tmp/ipykernel_2263914/2313346837.py in <module>
#       4     }
#       5     url = 'https://www.rocketpunch.com/api/jobs/template?page={}'
# ----> 6     data_list = rocketpunch_crawler(url, headers)
#       7     detailed_data = parse_job_page(data_list, headers)
#
# /tmp/ipykernel_2263914/1191265853.py in rocketpunch_crawler(url, headers)
#      15         soup = BS(res['data']['template'], 'html.parser')
#      16         data_list.extend(parse_page(soup))
# ---> 17         time.sleep(2) # for sake of politeness
#      18
#      19     return data_list
#
# KeyboardInterrupt:

# %% [markdown]
# ### 수정사항
# parse_job_page(data, headers) 함수안의 변수마다 예외처리 코드 추가

# %%
detailed_data
# Out:
# [{'company_id': '21640',
#   'company_name': '씨드앤',
#   'description': '실내 적정 온도를 통해 지속가능한 사회와 환경을 만들어갑니다.',
#   'job_id': '149219',
#   'job_title': '필드 커뮤니케이션 매니저 (1년 이상)',
#   'job_career': ['경력'],
#   'timestamp': '2024-08-07_02:43:02',
#   'crawl_domain': 'www.rocketpunch.com',
#   'job_task': "[서비스운영기획부 팀 소개]‘저희 팀은 이런 장점이 있어요'👨🏻\u200d💻\xa0쭌님 / 팀장 / ENFJ: 씨드앤의 최전방에 위치하는 팀으로 제품 설치부터 CS 처리, 매장 관리까지 고객과 직접 소통하고 있습니다. 팀원들과 공동으로 업무를 수행하며 다져진 팀워크는 저희 팀의 큰 장점이며, PoC(검증 기간) 기간이 끝난 후 만족해 하는 고객의 모습을 보며 큰 보람을 느낄 수 있습니다.👨🏻\u200d💻\xa0이나님 / 부팀장 / INFP: 씨드앤의 모든 서비스의 시작을 담당하며 도전할 수 있는 기회가 많습니다. 화목하고 서로 의지하는 분위기의 팀에서 함께 새로운 업무를 배우고 성장할 수 있습니다.‘이런 팀원과 함께 하고 싶어요’👨🏻\u200d💻\xa0쭌님 / 팀장 / ENFJ: 다양한 고객들을 자주 마주하다보니, 사람들과 소통하는 것을 좋아하며 팀과 융화될 수 있는 협동심을 갖추신 분과 함께 하고 싶습니다. 또한 각기 다른 상황에 맞춰 임기응변이 뛰어나신 이성적이고 도전적인 분이셨으면 좋겠습니다.👨🏻\u200d💻\xa0이나님 / 부팀장 / INFP: 힘들어도 함께 웃으면서 일할 수 있는 긍정적인 분과 함께 하고 싶어요! 맡은 업무에 책임을 다 하는 진정성있는 분이셨으면 좋겠습니다. :)[주요 업무]- 기획 : 고객 커뮤니케이션을 통한 서비스(앱 또는 웹, CS 등) 개선점 기획하는 업무- 설치 : 건물 내 리프(Leaf) 시스템 설치 및 서비스 유지 관리하는 업무 수행 (에어컨에 부착하는 컨트롤러 설치는 사다리를 이용해요)- 데이터 분석 : 리프 도입 전후 비교를 위한 전력 사용량, 온습도 데이터 등을 활용한 데이터 분석 업무 (MS Power BI, Excel 등을 활용해요)- PoC 업무 : PM 또는 필드 담당을 맡아 고객사와의 일정 및 비용 등에 대해 소통하며 전반적인 PoC 운영을 리딩하는 업무*PoC : 자사 서비스를 시범적으로 도입하여 사용성 및 효과를 검증하는 프로젝트성 업무[자격 요건]- CS/CX 및 유관 업무 경력이 1년 이상이신 분- IoT 및 AI 서비스에 대한 전반적인 이해와 관심이 높으신 분- 고객의 입장에서 생각하고 서비스하실 수 있으신 분- 높은 책임감으로 성실히 업무 수행이 가능한 분- 새로운 시장을 함께 적극적으로 개척해나가실 분[우대 조건]- 고객과의 커뮤니케이션에 적극적이신 분- 꼼꼼하고 상황에 따라 유연한 대처가 가능하신 분- 전기기능사, 산업안전기사 등 관련 자격증을 보유하신 분",
#   'job_specialties': '서비스 운영, 고객 커뮤니케이션, 고객 관리, CX , CX Manager, CS/CX, CS, 고객응대, 고객지원, 운영, 고객대응, Customer Experience, 데이터 분석, 고객상담, 고객분석',
#   'job_detail': '[Better for Us, Better for Earth]AIoT 기반 온도관리 서비스 Leaf 를 제공하는 SeedN 입니다. 세상을 위한 적정 온도로 냉난방 에너지 낭비와 기후위기 문제를 해결하고 있어요. 🌎여러 유형의 공간이 모여 하나의 건물이 완성되는 만큼 공간과 건물에 대한 이해와 전문성은 "세상을 위한 적정 온도" 를 만드는 데 가장 중요합니다.그래서 씨드앤은 실시간 건물(공간) 데이터를 수집하고 분석하여 새로운 기술과 서비스를 만들어 세계 어디든 확장할 수 있는 \'건물에너지 운영 관리 플랫폼 The Building Energy Management Platform\' 이라는 비전을 실현해 나갑니다.[당신의 온도 관리를 쉽게, Leaf 🌱]씨드앤은 AIoT 기반 온도 관리 솔루션을 제공하고 있습니다. 사무실, 카페, 창고부터 무인 시설까지 냉난방 온도로 관리되는 모든 공간을 쾌적하고 건강하게 관리해 줍니다.[투자 유치 - 총 22억]- 2022년\xa0하나금융, 하나투자, SKT-인피니툼 펀드 등 프리시리즈 A 17억 추가 투자- 2021년\xa0카카오벤처스 프리시리즈A 투자유치[복지 및 혜택]- 지옥철이 뭔가요? 수습이 종료되면 8시부터 10시 사이에 유연 출근이 가능하다는 사실!- 점심시간 1시간 10분에 서울숲 맛집은 덤! 점심시간 10분 차이는 어마어마하답니다.- 마음껏 공부할 수 있도록, 도서비와 온라인 강의를 100% 무상 지원해 드립니다.- 씨드앤에서 성장의 끝이란 없습니다. 직무 관련 자격증 취득 시 시험 비용을 지원해 드립니다.- 씨드앤이 가장 먼저 생일을 축하드려요! 생일을 마음껏 즐길 수 있도록 생일 연차를 제공해 드립니다.- “반려동물과 일을 해야 능률이 오릅니다.” 반려동물과의 동반 출퇴근 환영!- 서울숲에 위치한 쾌적한 오피스!- 최신 PC 또는 노트북 지원으로 업무 효율까지 Up!- 직장인 3대 영양소 중 하나가 카페인이라던데, 맛까지 좋은 캡슐 커피를 무제한 제공해 드립니다.- 복장 is free! 사무실 안에서 신을 슬리퍼도 마음껏 가져 오세요.- 호칭은 모두 닉네임과 님으로![채용절차]① 서류전형 → ② 캐주얼 화상미팅 → ③ 1차 대면 면접 → ④ 2차 대면 면접 → ⑤ 최종합격 *캐주얼 화상미팅은 온라인에서만 알 수 있는 정보가 아닌 씨드앤의 목표, 미션, 정체성, 조직문화 등에 대해 상세히 설명드리는 시간입니다. 해당 전형은 면접 결과에 어떤 영향도 주지 않기 때문에 편한 마음으로 임해주세요 :) [지원서류]- 이력서 (자유양식이며 본인을 가장 잘 드러낼 수 있으면 좋아요!)    추가로 제출하고 싶은 서류가 있다면 recruit@seedn.co.kr로 보내주세요. ☺️',
#   'job_industry': 'IoT, 제조업/서비스, 사물인터넷, ESG, Energy/IOT/AI/bigdata/cloud, 에너지관리시스템, Environment, 건물에너지관리, DR시장, AutoDR, 중소형건물에너지관리, 에코시스템, HVAC, EHP',
#   'date_start': '2024-08-07',
#   'date_end': None},
#  {'company_id': '202165',
#   'company_name': '(주)해그로시',
#   'description': '인하우스 FIT 마케팅의 실현',
#   'job_id': '151509',
#   'job_title': '브랜드 컨텐츠 마케팅 팀장급 채용',
#   'job_career': ['경력'],
#   'timestamp': '2024-08-07_02:43:02',
#   'crawl_domain': 'www.rocketpunch.com',
#   'job_task': '해그로시(Hacking Growth See)는 소수 브랜드의 마케팅 액셀러레이팅을 진행하는 프로젝트 집단입니다. 우리는 클라이언트가 6개월에서 1년이면 마케팅 대행사가 필요 없어지기를 희망합니다. 인하우스 방식의 마케팅을 최적의 요소 별로 클라이언트에게 맞춤 제안하며 특정 단가 이상의 프로젝트만을 확실하게 성과로 메이드하고 있습니다.이 글을 직접 쓰는 대표 디렉터인 저는 인하우스에서 많은 대행사를 직접 선정하고 평가하는 포지션에 있었고, 동시에 개인적으로도 회사를 운영하면서 많은 브랜드의 성장을 돕는 프로젝트를 진행해 왔습니다. 단순히 대행 입장에서 특정 상품을 파는 것보다는 마케팅이라는 업에 맞게 브랜드의 질적인 성장을 통합 관점에서 만드는 본질적인 목표로 회사를 운영 중입니다.회사는 계속 성장 중이지만, 앞으로 도전해야 할 일들(새로운 BM 런칭, 프로젝트 퀄 개선)이 훨씬 많습니다. 유연하고 겸손하며 보상 구조(명확한 인센티브 챌린지)를 즐길 수 있는 분, 철저하게 노력하고 증명할 수 있는 수준 높은 동료를 찾습니다. (보통은 말만 하거나, drop되거나, 한계치에 부딪힙니다만 이겨낼 수 있는 분을 찾습니다.)실무의 팀장급(3개월 평가 후 결정)으로 오시거나 그 이상의 수익쉐어 형태 조건으로 챌린지로 합류하시거나 둘 중 하나의 선택권을 드립니다. 필요 시 평판 체크를 진행하며 클라이언트 유출 방지를 위한 법적 서류 또한 작성합니다. 스타트업 베이스의 올라운더 마케팅 깊이감을 갖춘 분, 대행사 베이스의 업무 감도를 경험해 보신 분, 창업의 여정을 경험하고 싶거나 다시 한번 해보고 싶으신 분이었으면 합니다. 물론 실무 멤버로서의 역할로만 join해도 무관합니다.',
#   'job_specialties': '디지털 마케팅, 바이럴 마케팅, 콘텐츠 마케팅, 그로스해킹, 브랜드 마케팅, 블로그, 제휴 마케팅',
#   'job_detail': '담당업무- 클라이언트 마케팅 PM (기존 멤버의 동료 혹은 실무 팀장 역할)- B2B 리드 제너레이션 (신규 클라이언트 수주를 위한 온라인 컨텐츠 채널링 / 유튜브, 블로그 등)- 브랜드/마케팅 후킹성 컨텐츠 기획 제작 (UX카피라이팅, 배너 및 영상 디자인/제작)- *관리 포지션 없습니다. 실무 직접하며, 일정 등 총괄에 가깝습니다.자격요건- 브랜드마케팅/디지털마케팅 4년차 이상- 디자인, 영상 기획제작 역량 (컨텐츠 포트폴리오를 브랜드 스토리 단계부터 만들어 보신 분, 사이드 플젝 무관)- 스타트업 마케팅(시리즈A~B 단계 올라운더 선호) 리딩 경험 2년 이상인 분- *논페이드/오가닉 마케팅 지표를 빌드업한 이력이 확실하신 분 (포트폴리오 필수)우대사항- 교육 컨텐츠/BM 기획제작 경험- 남성 2539 이해도가 높은 분- 디자이너 출신 컨텐츠 마케터 (극호)- 기존의 마케팅 방식에 갇히지 않고 유연한 사고, 기획, 시도를 즐길 수 있는 분복리후생- 클라이언트 업무 외 실행할 수 있는 독립적인 브랜드 빌드업 기회/경험- 함께 하는 빠른 성장, 스터디, 도전, 증명- 물질적 보상 (수익쉐어, 성과/상여금, 경조사비, 식대, 주차비 지원 등)- 납득할 수 있는 정량적 평가 기준표- 유연근무, 탄력근무, 재택근무',
#   'job_industry': '마케팅, IMC,광고,광고기획,광고제작,광고대행사,대행사,디지털,마케팅,매체개발,매체운영,모바일,미디어,솔루션개발,아이디어,온라인,종합광고대행사,캠페인, 브랜딩, 콘텐츠/마케팅/, 퍼포먼스마케팅, #영상#촬영#편집, 커뮤니케이션, 그로스해킹, 전략기획, 그로스마케팅, 상세페이지디자인',
#   'date_start': '2024-08-07',
#   'date_end': None},
#  {'company_id': '183498',
#   'company_name': '리버티랩스',
#   'description': 'Tech M&A 스타트업',
#   'job_id': '151328',
#   'job_title': 'Product Designer(4년 이상)',
#   'job_career': ['경력'],
#   'timestamp': '2024-08-07_02:43:02',
#   'crawl_domain': 'www.rocketpunch.com',
#   'job_task': '리버티랩스는 승계 문제에 처한 중소기업을 M&A 하는 기업입니다.저희는 승계 문제를 겪고 있는 중소기업을 인수한 후 20년에 걸쳐 임직원들에게 80% 지분을 나눠주어 기업이 소멸하지 않고 영속할 수 있도록 합니다. 또한 이들에게 소프트웨어 서비스를 공급하여 더 효율적으로 기업을 운영할 수 있도록 합니다.\xa0다수의 투자사들로부터 투자를 유치하였으며 고양이 NFT, 칭찬 슬랙봇과 같이 세상에 별로 중요하지 않은 문제를 풀고 있는 다른 스타트업과는 다르게 진짜로 세상에 의미 있고 중요한 일을 하고 있는 스타트업입니다.▼ 리버티랩스 채용 페이지https://libertylabs.careers.team/',
#   'job_specialties': 'UI/UX 디자인, 웹 디자인, 프로덕트디자인, UX 디자인, UI 디자인, Framer',
#   'job_detail': '▶ 담당업무-Tech Solution 팀에 소속되어 개발자들과 프로덕트 디자인 업무 담당-제품 디자인에 대한 오너십을 발휘하여 사용자 경험의 최소 수준 정의-PO와 함께 스토리보드, 유저 플로우, 와이어 프레임, 프로토 타입 등 제작-프로덕트 UI/UX 설계 및 디자인 기획 리드 및 지속적인 UX 개선-UI/UX 툴을 통해 완성도 높은 App/Web Responsive UI 설계▶ 자격요건-4년 이상의 UI/UX와 프로덕트 디자인 경력 혹은 그에 준하는 경험이 있으신 분-디자인 시스템에 대한 높은 이해도를 가지고 Figma 툴을 능숙하게 사용하시는 분-구조화된 UI, 일관된 UX 설계를 통해 사용자에게 통일된 UX를 전달할 수 있는 분-PM, PO, 개발자 등 협업 시 배려심을 바탕으로 논리적인 커뮤니케이션이 가능하신 분-기능주의적 스타트업 조직에서 빠른 속도로 비즈니스 목적에 맞는 UX 설계가 가능하신 분▶ 우대사항- Framer 사용 경험이 있으신 분- 주니어 디자이너 리드 경험이 있으신 분- 영어를 읽고 이해하는데 무리가 없는 분- B2B 환경의 UI/UX 디자인 경험이 있으신 분- 재무, 회계, 자산관리 관련 제품에 지식 또는 관심이 있으신 분▶ 우리의 문화1. Execution   책상에 앉아있는 것보다 직접 몸으로 뛰어 깨지고 배우는 것을 선호합니다.\xa02. 수평적 의사소통 / 수직적 의사결정\xa0   구성원 모두가 자신의 생각을 자유롭게 이야기하고, 결정이 내려지면 모두 한 방향으로 나아갑니다.\xa03. Growth   성장하지 못 하면 죽음뿐입니다. 조직의 성장과 함께 개인도 성장할 수 있어야 합니다.\xa04. Transparency   최대한 많은 정보를 서로에게 공유함으로써 투명한 문화를 만들어갑니다.\xa05. Meritocracty   다른 것은 보지 않고, 능력 있는 사람을 최고로 대우해줍니다.\xa06. Hard Working   워라벨, 복지보다 진짜 중요한 문제에 몰두하고 열심히 일하실 분을 찾습니다.\xa07. Flexibility\xa0   유연한 사고로 문제를 해결하는 분을 원합니다.▶ 함께하면 얻을 수 있는 것[함께 하는 것이 즐거운 각 분야 최고의 팀원]- CEO / 성담 패밀리오피스 Investor, Activant Capital, Cornell University Economics  Blackstone, KPS Capital Partners, MBK Partners 외 80여 개의 GP 출자한 경험과 다양한 PE 지인 네트워크 보유- CSO / EY Parthenon 시니어 컨설턴트, IoT 스타트업 창업, 고려대 경영, 소프트웨어 복수 전공  High-level 전략과 더불어 공정 효율화, HR, 구매, 조달 등 오퍼레이션 End-to-End 경험 보유- CIO / Simpson Thacher & Bartlett, Harvard Law School   미국 뉴욕주 변호사로 Blackstone, Carlyle, Microsoft 등의 M&A 프로젝트 경험- CTO / 라우드코퍼레이션 Software Engineer, Morph 대표, University of St.Andrews  한정판 신발 거래 플랫폼 ‘Morph’ 창업자이자 디자인, 앱/웹 프론트엔드, 백엔드 등 풀스택 개발 역량 보유- VP of Engineering / InterSystems Senior Engineer, 데이트립 Founding Engineer, Cornell University  연 매출 $976MN의 규모의 대기업에서 레거시 플랫폼 개선과 신기능 개발 참여[성과에 걸맞은 최고의 보상]- 무제한 휴가- 고성과자 스톡옵션 부여- 성과에 따른 성과급 및 상여금 지급- 이전 직장 대비 무조건 높은 연봉 보장- 팀원별 법인카드 지급을 통한 성장과 업무 무제한 지원▶ 기타 안내[복지 및 근무 환경]- 선릉역 10번 출구 1분 거리의 전망 좋은 16층 사무실- 업무를 위해 필요한 SW, 전자 기기 등 모든 것을 지원- 점심 식대뿐 아니라, 야근 시 저녁 식대 및 택시비 지원[주의 사항]- 모든 신규 입사자는 3개월 간의 수습 기간이 있으며, 수습 평가 결과에 따라 수습 기간이 연장되거나 채용이 취소될 수 있습니다.- 이력서 및 제출 서류에 허위 사실이 발견될 시 채용이 취소될 수 있습니다.',
#   'job_industry': '정보/통신',
#   'date_start': '2024-08-07',
#   'date_end': None},
#  {'company_id': '183498',
#   'company_name': '리버티랩스',
#   'description': 'Tech M&A 스타트업',
#   'job_id': '151508',
#   'job_title': 'UI/UX 디자이너(리드)',
#   'job_career': ['5,500 - 7,000만원', '경력'],
#   'timestamp': '2024-08-07_02:43:02',
#   'crawl_domain': 'www.rocketpunch.com',
#   'job_task': '',
#   'job_specialties': 'UI/UX 디자인, 웹 디자인, 프로덕트디자인, UX 디자인, UI 디자인, Framer',
#   'job_detail': '',
#   'job_industry': '정보/통신',
#   'date_start': '2024-08-07',
#   'date_end': None},
#  {'company_id': '196140',
#   'company_name': '아파트너',
#   'description': "'스마트 주거 생활 환경 플랫폼'으로, 아파트에 살고 있는 입주민들의 일상 속 불편함을 해소하고 따뜻한 기술을 통해 더 나은 세상을 만들어 나갑니다",
#   'job_id': '151369',
#   'job_title': '서비스기획',
#   'job_career': ['경력'],
#   'timestamp': '2024-08-07_02:43:02',
#   'crawl_domain': 'www.rocketpunch.com',
#   'job_task': "안녕하세요. 아파트너 채용 페이지를 찾아주셔서 감사합니다 : )아파트너는 '대한민국 No.1 아파트앱'입니다. 우리나라 인구 60%가 거주하는 '아파트'를 기반으로 DT(Digital Transformation)와 입주민의 풍요로운 라이프스타일을 지원하고 있습니다.앱 안에서 언제 어디서든 아파트 관리사무소와 입주민이 긴밀하게 소통할 수 있도록, 커뮤니티 시설 예약이나 방문 차량  예약과 같은 IoT 서비스를 지원하여 스마트한 생활이 가능하도록, 나아가 입주민들끼리의 소통 공간을 통해 따뜻한 정을 나눌 수 있도록 지원하여 아파트 생활을 혁신해나가는 데 앞장서고 있습니다.[ 아파트너 팀에 합류해서 담당하게 될 업무는요 ]- 고객의 목소리를 많이 듣고 이를 데이터 기반으로 분석해서, 더 나은 고객 경험을 제공할 수 있는 프로덕트를 구상해요- 가볍고 빠르게 실행할 수 있는 여러 가설을 만들고, 이 중 유저 임팩트를 줄 수 있는 것을 선별하여 실행하고 피드백해요- 서비스를 안정적으로 워킹하게 하는 것에서 더 나아가, 더 편리하고 완성도 있는 서비스 제공을 위한 고민을 해요",
#   'job_specialties': '서비스기획/운영',
#   'job_detail': "[ 지원 자격은 아래와 같아요 ]- 기획 경력 최소 3년 이상- 기획서 작성을 통한 서비스 개선 및 고도화를 담당해보신 분- 정책 및 기능 정의, 화면 설계를 수립할 수 있으신 분- 업무 프로세스를 개선하여 성과를 만들어낸 경험이 있으신 분- 포트폴리오 제출 필수 (*프로젝트 참여 역할, 범위, 출시된 서비스 URL 명시)[ 이런 경험이 있으면 좋아요 ]- 신사업 또는 서비스 초기 단계부터 참여하여 제품을 출시해본 경험이 있으신 분- 서비스기획/개발/운영 전체의 프로덕트 사이클을 경험해보신 분- 부동산 정보 업체 또는 프롭테크 관련 경력이 있으신 분[ 아파트너가 함께 일하고 싶은 사람은요 ]- 안되는 이유보다 이것을 '가능하게 만들 수 있는 방법을 찾는 사람'- 학습과 성장에 스스로 동기부여하며, '개인의 성장에서 멈추지 않고 팀과 조직의 성장에 긍정적인 영향력을 주는 사람'- 함께 일하는 것에 대한 가치를 알고, 상호 존중을 바탕으로 '배려하며 일할 수 있는 사람'- 공동의 목표를 달성하기 위해 '성과중심으로 사고하고 실행하는 사람'- 본인이 맡은 업무, 말과 행동에 '책임을 다하는 사람'[ 아파트너와 함께 하기까지의 여정 ]서류 전형 > 직무 인터뷰 > 컬쳐핏 인터뷰 > 처우 협의 > 최종 합격 및 입사",
#   'job_industry': '프롭테크, IT/솔루션, 앱/웹',
#   'date_start': '2024-08-07',
#   'date_end': None},
#  {'company_id': '196140',
#   'company_name': '아파트너',
#   'description': "'스마트 주거 생활 환경 플랫폼'으로, 아파트에 살고 있는 입주민들의 일상 속 불편함을 해소하고 따뜻한 기술을 통해 더 나은 세상을 만들어 나갑니다",
#   'job_id': '151370',
#   'job_title': 'CX운영(부산지점)',
#   'job_career': ['경력'],
#   'timestamp': '2024-08-07_02:43:02',
#   'crawl_domain': 'www.rocketpunch.com',
#   'job_task': "안녕하세요. 아파트너 채용 페이지를 찾아주셔서 감사합니다 : )아파트너는 '대한민국 No.1 아파트앱'입니다. 우리나라 인구 60%가 거주하는 '아파트'를 기반으로 DT(Digital Transformation)와 입주민의 풍요로운 라이프스타일을 지원하고 있습니다.앱 안에서 언제 어디서든 아파트 관리사무소와 입주민이 긴밀하게 소통할 수 있도록, 커뮤니티 시설 예약이나 방문 차량  예약과 같은 IoT 서비스를 지원하여 스마트한 생활이 가능하도록, 나아가 입주민들끼리의 소통 공간을 통해 따뜻한 정을 나눌 수 있도록 지원하여 아파트 생활을 혁신해나가는 데 앞장서고 있습니다.[ 아파트너 팀에 합류해서 담당하게 될 업무는요 ]- 고객 문의를 정확히 파악하고 이를 각 담당 부서에 전달하여 신속하게 처리해요- CS 상담을 통해 도출된 VOC를 기반으로, 불편사항을 파악하고 편의성을 도출해내는 역할을 해요- FAQ, 매뉴얼 등 고객이 서비스를 사용하는데에 어려움이 없도록 가이드를 지속적으로 업데이트하고 관리해요",
#   'job_specialties': 'CS, CX ',
#   'job_detail': "[ 지원 자격은 아래와 같아요 ]- 고객 상담 경력 5년 이상- 고객에게 신뢰를 줄 수 있는 친절함과 긍정적 태도를 가지신 분- 고객의 문제에 공감하고 이를 해결하기 위해 적극적으로 소통하실 수 있으신 분- 고객에게 아파트너와의 상담 경험을 긍정적으로 기억할 수 있도록 책임을 가지고 임할 수 있는 분[ 이런 경험이 있으면 좋아요 ]- IT 업계 CS/CX 경력이 있으신 분- VOC 데이터를 관리해본 경험이 있으신 분[ 근무 조건 ]- 근무형태 : 정규직 (수습기간 3개월 포함)- 근무일시 : 주 5일 (월-금) 9:00-18:00- *근무지역 : 부산 해운대구 센텀동로 41, 306호[ 아파트너가 함께 일하고 싶은 사람은요 ]- 안되는 이유보다 이것을 '가능하게 만들 수 있는 방법을 찾는 사람'- 학습과 성장에 스스로 동기부여하며, '개인의 성장에서 멈추지 않고 팀과 조직의 성장에 긍정적인 영향력을 주는 사람'- 함께 일하는 것에 대한 가치를 알고, 상호 존중을 바탕으로 '배려하며 일할 수 있는 사람'- 공동의 목표를 달성하기 위해 '성과중심으로 사고하고 실행하는 사람'- 본인이 맡은 업무, 말과 행동에 '책임을 다하는 사람'[ 아파트너와 함께 하기까지의 여정 ]서류 전형 > 직무 인터뷰 > 컬쳐핏 인터뷰 > 처우 협의 > 최종 합격 및 입사",
#   'job_industry': '프롭테크, IT/솔루션, 앱/웹',
#   'date_start': '2024-08-07',
#   'date_end': None},
#  {'company_id': '196140',
#   'company_name': '아파트너',
#   'description': "'스마트 주거 생활 환경 플랫폼'으로, 아파트에 살고 있는 입주민들의 일상 속 불편함을 해소하고 따뜻한 기술을 통해 더 나은 세상을 만들어 나갑니다",
#   'job_id': '151371',
#   'job_title': '영업지원(CS)',
#   'job_career': ['3,000 - 4,999만원', '경력'],
#   'timestamp': '2024-08-07_02:43:02',
#   'crawl_domain': 'www.rocketpunch.com',
#   'job_task': '',
#   'job_specialties': 'CS, 기술지원',
#   'job_detail': '',
#   'job_industry': '프롭테크, IT/솔루션, 앱/웹',
#   'date_start': '2024-08-07',
#   'date_end': None},
#  {'company_id': '196140',
#   'company_name': '아파트너',
#   'description': "'스마트 주거 생활 환경 플랫폼'으로, 아파트에 살고 있는 입주민들의 일상 속 불편함을 해소하고 따뜻한 기술을 통해 더 나은 세상을 만들어 나갑니다",
#   'job_id': '151368',
#   'job_title': 'UX/UI 디자이너',
#   'job_career': ['경력'],
#   'timestamp': '2024-08-07_02:43:02',
#   'crawl_domain': 'www.rocketpunch.com',
#   'job_task': "안녕하세요. 아파트너 채용 페이지를 찾아주셔서 감사합니다 : )아파트너는 '대한민국 No.1 아파트앱'입니다. 우리나라 인구 60%가 거주하는 '아파트'를 기반으로 DT(Digital Transformation)와 입주민의 풍요로운 라이프스타일을 지원하고 있습니다.앱 안에서 언제 어디서든 아파트 관리사무소와 입주민이 긴밀하게 소통할 수 있도록, 커뮤니티 시설 예약이나 방문 차량  예약과 같은 IoT 서비스를 지원하여 스마트한 생활이 가능하도록, 나아가 입주민들끼리의 소통 공간을 통해 따뜻한 정을 나눌 수 있도록 지원하여 아파트 생활을 혁신해나가는 데 앞장서고 있습니다.[ 아파트너 팀에 합류해서 담당하게 될 업무는요 ]- 아파트너의 고객들이 서비스를 이용하며 느낄 수 있는 경험을 설계하고, 이를 디자인이라는 방법을 통해 전달해요- 고객의 목소리를 많이 듣고 이를 데이터 기반으로 분석해서, 어떻게 더 쉽고 편리한 서비스를 제공할 수 있을지를 고민해요- 지속적으로 서비스 디자인을 평가하고 피드백하고 개선하여, 디자인 품질을 향상시키는 역할을 해요",
#   'job_specialties': 'UI/UX 디자인, 웹 디자인, 모바일 디자인, 포스/키오스크디자인',
#   'job_detail': "[ 지원 자격은 아래와 같아요 ]- 경력 5년 이상 또는 그에 준하는 실력을 가지신 분 (웹&앱 UX/UI 디자인 경력 3년 이상 포함)- Figma, Lottie, Adobe 등 디자인 툴을 원활하게 사용할 수 있으신 분- 다양한 고객 요구 사항에 긍정적이고 적극적으로 대응이 가능하신 분- 포트폴리오 제출 필수 (*프로젝트 참여 역할, 범위, 출시된 서비스 URL 명시)[ 이런 경험이 있으면 좋아요 ]- html/css에 대한 이해가 높으신 분- Android, IOS 가이드라인에 대한 이해가 높으신 분- 일관된 UX, 구조화된 UI를 설계해본 경험이 있으신 분- App&Web, 키오스크, 포스 등 다양한 분야의 디자인을 경험해보신 분- 기존 디자인 시스템과 프로세스의 문제점을 찾고 이를 개선해본 경험이 있으신 분[ 아파트너가 함께 일하고 싶은 사람은요 ]- 안되는 이유보다 이것을 '가능하게 만들 수 있는 방법을 찾는 사람'- 학습과 성장에 스스로 동기부여하며, '개인의 성장에서 멈추지 않고 팀과 조직의 성장에 긍정적인 영향력을 주는 사람'- 함께 일하는 것에 대한 가치를 알고, 상호 존중을 바탕으로 '배려하며 일할 수 있는 사람'- 공동의 목표를 달성하기 위해 '성과중심으로 사고하고 실행하는 사람'- 본인이 맡은 업무, 말과 행동에 '책임을 다하는 사람'[ 아파트너와 함께 하기까지의 여정 ]서류 전형 > 직무 인터뷰 > 컬쳐핏 인터뷰 > 처우 협의 > 최종 합격 및 입사",
#   'job_industry': '프롭테크, IT/솔루션, 앱/웹',
#   'date_start': '2024-08-07',
#   'date_end': None},
#  {'company_id': '6311',
#   'company_name': '다날',
#   'description': '데이터베이스 및 온라인정보 제공업체',
#   'job_id': '151507',
#   'job_title': '다날 결제 연계시스템 BE 개발 경력 채용',
#   'job_career': ['경력'],
#   'timestamp': '2024-08-07_02:43:02',
#   'crawl_domain': 'www.rocketpunch.com',
#   'job_task': '',
#   'job_specialties': 'Java, Java Spring Framework, Spring Boot, spring-batch, RESTful API, MySQL, mssql, PostgreSQL',
#   'job_detail': '',
#   'job_industry': '모바일게임, 메신저, 휴대폰결제, 통화연결음',
#   'date_start': '2024-08-07',
#   'date_end': None},
#  {'company_id': '6311',
#   'company_name': '다날',
#   'description': '데이터베이스 및 온라인정보 제공업체',
#   'job_id': '151190',
#   'job_title': '다날 결제시스템 서버 개발자 채용',
#   'job_career': ['경력'],
#   'timestamp': '2024-08-07_02:43:02',
#   'crawl_domain': 'www.rocketpunch.com',
#   'job_task': '',
#   'job_specialties': '백엔드 개발, Java, Sping framework, JPA, Gradle, ELK, MySQL, mssql, PostgreSQL, JUnit, Jenkins',
#   'job_detail': '[담당업무]- 안정적인 시스템 제공을 위해 레거시를 신규 프로젝트로 전환하는 등 여러가지 시스템을 고도화 진행합니다. - 결제시스템, 정산시스템 등 결제와 관련된 도메인을 전반적으로 담당하고 있습니다. [자격요건]- 7년 이상의 서버 개발 경험이 있으신 분 - Java, 객체지향, Spring framework를 잘 이해하고 활용 가능한 분 - Spring Boot/Batch 기반 개발 경험이 있으신 분 - RESTful API 설계 및 개발 경험이 있으신 분 - JPA를 활용한 도메인모델 방식의 개발 경험이 있으신 분 - 테스트 코드를 적극적으로 작성하시는 분 - Git flow 형상관리에 익숙하신 분 - 리눅스 환경에 익숙하신 분 [우대사항]- 온라인 결제 프로세스에 대한 이해와 경험이 있으신 분 - 정산 프로세스에 대한 이해와 경험이 있으신 분 - 대용량 트래픽에 대한 시스템 설계 및 운영 경험이 있으신 분 - docker, elk 활용 경험이 있으신 분 [개발환경] - 주요기술 : Java, Spring framework(Spring Boot, Spring Batch), JPA, Gradle- 저장소 : MySQL, MSSQL, PostgreSQL - 업무도구 : Git, GitLab, Jira, Confluence, IntelliJ - 코드리뷰, 코드품질 : upsource - 테스트, 빌드, 배포 : JUnit, Jenkins - 모니터링 : ELK[꼭 확인해주세요] ※ Notion, Google Docs 등 웹기반 문서는 확인하기 어려우니 참고할 만한 사항은 PDF로 첨부 바랍니다. - 사전과제는 개별적으로 안내드리며, 심사는 평균 일주일 정도 소요됩니다.  - 경력기술서는 자신의 기술력을 보여 줄 수 있는 프로젝트나 협력했던 활동사항 위주로 작성해주세요.   (진행 기간, 주요 업무내용, 본인이 기여한 부분, 결과/성과/성취 등)[채용사이트]- welcome.danal.co.kr',
#   'job_industry': '모바일게임, 메신저, 휴대폰결제, 통화연결음',
#   'date_start': '2024-08-07',
#   'date_end': None},
#  {'company_id': '6311',
#   'company_name': '다날',
#   'description': '데이터베이스 및 온라인정보 제공업체',
#   'job_id': '151200',
#   'job_title': '다날 정산시스템 개발 부문 경력 채용',
#   'job_career': ['경력'],
#   'timestamp': '2024-08-07_02:43:02',
#   'crawl_domain': 'www.rocketpunch.com',
#   'job_task': '',
#   'job_specialties': '웹 백엔드 개발(Java/Spring/Oracle/MySQL), mssql, SQL, spring-batch, RESTful API',
#   'job_detail': '',
#   'job_industry': '모바일게임, 메신저, 휴대폰결제, 통화연결음',
#   'date_start': '2024-08-07',
#   'date_end': None},
#  {'company_id': '6311',
#   'company_name': '다날',
#   'description': '데이터베이스 및 온라인정보 제공업체',
#   'job_id': '151201',
#   'job_title': '다날 테스트 자동화 개발 담당 경력 채용',
#   'job_career': ['경력'],
#   'timestamp': '2024-08-07_02:43:02',
#   'crawl_domain': 'www.rocketpunch.com',
#   'job_task': '',
#   'job_specialties': 'Python, Java, Jenkins, GitLab, Selenium, appium',
#   'job_detail': '',
#   'job_industry': '모바일게임, 메신저, 휴대폰결제, 통화연결음',
#   'date_start': '2024-08-07',
#   'date_end': None},
#  {'company_id': '6311',
#   'company_name': '다날',
#   'description': '데이터베이스 및 온라인정보 제공업체',
#   'job_id': '151505',
#   'job_title': '다날 결제페이지 FE 개발 경력 채용',
#   'job_career': ['경력'],
#   'timestamp': '2024-08-07_02:43:02',
#   'crawl_domain': 'www.rocketpunch.com',
#   'job_task': '',
#   'job_specialties': 'Java, PHP, Python, JavaScript, React, Vue.js, Spring, HTML, CSS',
#   'job_detail': '',
#   'job_industry': '모바일게임, 메신저, 휴대폰결제, 통화연결음',
#   'date_start': '2024-08-07',
#   'date_end': None},
#  {'company_id': '95952',
#   'company_name': '주식회사 알파브라더스',
#   'description': '스타트업 전문 엑셀러레이터입니다.',
#   'job_id': '150794',
#   'job_title': '[알파브라더스] Motion Grapher - 광고 및 홍보 영상 콘텐츠 제작 (경력)',
#   'job_career': ['경력'],
#   'timestamp': '2024-08-07_02:43:02',
#   'crawl_domain': 'www.rocketpunch.com',
#   'job_task': '',
#   'job_specialties': '광고기획, 광고 디자인, 영상 촬영, 영상제작, 영상편집, 영상 디자인, 모션그래픽, 영상 모션 디자인, 영상제작/편집',
#   'job_detail': "알파브라더스We Build Company - 알파브라더스는 컴퍼니 빌딩형 액셀러레이터입니다· 💰 투자실적 : 2020년부터 누적 21.7억원· 👩\u200d👧\u200d👦 사내벤처 실적 : 2020년부터 총 5개의 사내벤처 창업· 🏛️ 정부 연계 액셀러레이팅 : 2022년부터 매해 평균 3개 용역 실행알파브라더스는 초기기업을 대상으로 투자하는 액셀러레이터이며, 그 중에서도 단순 자금지원에서 그치지 않고 실무인력까지 지원하는 ACTIVE 액셀러레이터입니다 🚀독립레이블을 양성하는 창업지원 그룹 ABCDE 본부알파브라더스의 창업지원 그룹은 유망기업에게 자금투자와 실무지원을 제공하며, 실무분야 별로 ABCDE 5개 본부로 구성되어 있습니다.창업지원 그룹 ABCDE본부 지원을 통해 성공적으로 자립하는 기업은 독립레이블이라 불립니다.창업지원 그룹 ABCDE 본부는 어떤 업무를 지원하나요?· ADVISOR 본부 - [정부지원금부터 민간투자까지 자금조달 러닝메이트] : 알파브라더스 어드바이저 본부는 초기에 필요한 자금 확보 뿐만 아니라 기업 생애주기에 맞는 자금조달 컨설팅을 제공합니다.· BRAND 본부 - [제품과 서비스의 기본! 브랜드 설계와 작업까지] : 알파브라더스 브랜드 본부는 로고, 패키지, 상세페이지, UXUI, 사진/영상 촬영 등 토탈 브랜딩 서비스를 지원합니다.· CREATIVE 본부 - [숫자와 데이터로 매출을 일으키는 마케팅] : 알파브라더스 크리에이티브 본부는 고객 행동 데이터 분석을 통해 더 효과적으로 매출 증대를 이끌어내는 마케팅 전략 구축 및 실행을 지원합니다.· DATA & DEV  본부 - [비즈니스 모델 검증과 시장에 필요한 서비스 개발] : 알파브라더스 데이터&개발 본부는 MVP 테스트를 통해 초기 비즈니스 모델의 시장성, 사용성, 기술성 검증을 진행하고 잠재 고객 데이터를 기반으로 시장에 필요한 웹과 앱개발을 지원합니다.· EXPERT 본부 - [회사 경영관련 지원과 컨설팅 제공] : 알파브라더스 엑스퍼트 본부는 11명의 사내 노무사, 세무/회계사, 변호/변리사, 경영지도사 전문가의 지속적인 컨설팅과 실무를 지원합니다.우리에 대해 더 알고 싶은 것이 있으시다면?🔍홈페이지 접속!👉https://www.alphabrothers.co.kr/채용 배경✏️안녕하세요. 알파브라더스 브랜드 본부 비주얼아트팀 입니다. 금번 채용은 비주얼아트팀의 구독제 서비스와 광고 홍보 영상 제작 프로덕션 서비스에 참여할 Motion Grapher 채용의 건 입니다. 저희 브랜드 본부는 디자인 구독제를 시작으로 영상과 사진 등 다양한 서비스 영역에서 시장과 고객을 보다 더 효율적으로 연결하는 구독제 서비스를 지속적으로 런칭하고 있습니다.비주얼아트팀은 [1] 영상 및 사진 구독제 서비스를 시작으로 [2] 광고/홍보 영상을 전문으로 하는 프로덕션과 전문적인 연출 사진을 제작하는 스튜디오, [3] 다양한 주제의 YouTube 채널 등을 운영할 예정입니다. 전문성과 매체력을 갖춘 이후에는 [4] 이커머스 시장에 진출하여 의미있는 성장을 지속하고자 합니다.팀 소개 💁🏻\u200d♂️비주얼아트팀은1. 영상 구독제 서비스를 기획하고 운영하고자 해요.! (2024년 3월 런칭 예정)2. 광고/홍보 영상 제작 및 사진 촬영을 전문으로 하고 있는 인하우스 프로덕션 & 스튜디오 입니다. 🙂3. 마곡역 인근에 작고 소중한 스튜디오가 하나 있고4. 다양한 시도를 위해 여러가지 장비들을 도전적으로 활용해보고 있어요.5. 저희 팀은 높은 수준의 고객 만족을 목표로 하고 있습니다. ⭐️주요 업무 💫함께 하시게 된다면,1. 광고 / 홍보 영상 기획(안) 및 PPM(Conti) 작성 2. 그래픽 디자인 기획 및 제작3. 모션그래픽 기획 / OAP 제작, 편집(컷, 색, 음악, 음향 등)4. 촬영 현장 및 편집 지원5. 기타 프로덕션 제반 업무등의 업무를 함께 하시게 될 거예요!* 저희 팀은 1인 콘텐츠 제작자 로서의 성장과 발전이 목표인 Producer 들과 Photographer 들이 모여있어요! 💪* 팀 리더는 광고 제작 프로덕션(사진&영상) 운영 경험이 있는 10년차 PD/감독 입니다. ⭐️자격 요건 🔥우리는 아래 자격들을 갖춘 지원자를 원해요.[ 필수 ] 마인드셋· 다양한 의견에 귀 기울이고 수용하여 완성도를 높일 수 있는 분· 유연하고 적극적 커뮤니케이션으로 협업을 원활하게 진행할 수 있고, 책임감 강하신 분  ⭐️⭐️ [ 필수 ] 스킬셋· 포트폴리오 제출(필)· 기본적인 영상 콘텐츠 제작 과정에 대한 이해· 그래픽 디자인 및 모션, VFX 에 대한 이해와 기획력· 프리미어프로 / 애프터이펙트 / 포토샵 / 일러스트 등 어도비 계열 프로그램 활용 필수· LUT 및 플러그인의 제작, 활용 필수· 포토샵 / 일러스트 등 디자인 도구 활용 [ 중급 이상 ] [ 우대 ] 스킬셋· TVCF 등 광고 제작(편집) 경험이 있으신 분· 애니메이션 혹은 모션그래픽 기반의 광고 기획(안) 작성 경험이 있으신 분· D.I 경험이 있으신 분· Motion Creative 에 대한 이해가 있으신 분 [ Art work ]조직문화와 인재상을 위한 맞춤 복지 혜택 💝알파브라더스는 구성원들이 끊임없이 성장하고, 도전에서 배우고, 주도적으로 성과를 창출할 수 있는 조직문화를 만들기 위해 오늘도 고민합니다.1️⃣ 회사의 성장과 개인의 성장을 동반한다. 우리는 [성장 지향형 인재]입니다.📢 성장 지향적 인재를 위한 맞춤 복지제도를 소개합니다.· 신규입사자를 위한 일학습병행 프로그램· 주니어를 위한 스터디룸 운영· 시니어를 위한 외부 전문가 1:1 멘토링· 자격증 취득 비용 지원· 1,500권 이상의 사내 도서관 운영· 외부기관 연계 교육 프로그램 제공2️⃣ 실패는 없다, 레슨런만 있을 뿐. 우리는 [도전 지향형 인재]입니다.📢 도전 지향적 인재를 위한 맞춤 복지제도를 소개합니다.· 상시 랩업을 위한 주니어-시니어 면담· 월간 랩업을 위한 시니어 세미나· 분기/반기 랩업을 위한 팀별 워크숍· 사내벤처 프로그램 운영· 사이드 프로젝트 지원· 대표님과 1:1 커피챗3️⃣ OUTPUT = Performance x Time. 우리는 [성과 지향형 인재] 입니다.📢 성과 지향적 인재를 위한 맞춤 복지제도를 소개합니다.· 원하는 시간에 출근하자!· 원하는 시간대에 일하자!· 원하는 곳에서 근무하자!· 일과 휴가를 동시에, 워케이션 지원· 최신 장비 및 툴 지원· 집중을 위해 스마트 워크부스 지원채용 과정📌📥[ 첫번째, 입사 지원 ]· 아래 지원하기 버튼을 통해 지원서 작성 (소요시간 3분 미만)🗂[ 두번째, 서류 전형 ]· 상시채용으로 진행되며, 이력서를 검토하는 대로 합격, 불합격 상관 없이 모든 지원자 분께 서류전형 결과를 발표합니다.· 이력서, 자기소개서, 포트폴리오 제출 (필수)📢[ 세번째, 과제 및 면접 전형 ]  - (약 30분 ~ 1시간 이내)· (과제 제출이 필요할 경우) 면접 전형 전까지 메일로 회신해주시면 됩니다.· 지원자분과 적합도를 알아보기 위한 인터뷰 · 이력서, 자기소개서, 포트폴리오를 중심으로 이야기 하되, 본인의 핵심 스킬셋이 무엇인지 왜 그렇게 생각하는지에 대해 여러 경험을 함께 소통하는 자리입니다. 📄[네번째, 서류 검토]· 면접 전형 합격자에 한하여 개별로 구비서류를 메일로 요청드립니다.· 메일을 받으신 날로부터 3일 이내 회신해주셔야 합니다.· 제출한 구비서류 중 허위 사실이 발견될 경우 채용이 취소될 수 있습니다.🖋️[다섯번째, 처우 협의]· 제출한 서류에 이상이 없을 경우 입사제안서를 메일로 발송드립니다.· 메일을 받으신 날로부터 3일 이내 회신해주셔야 합니다.🎉[ 최종 합격 ]· 최종합격 시 개별 연락으로 안내합니다.❗️ 확인해주세요❗️· 경력 위주로 서류를 작성해주세요.· 서류 전형 합격자에 한해 개별 합격 안내 및 대면 면접을 진행하고 있어요.❗️꼭 읽어주세요❗️· 지원 시, '포트폴리오📑'를 필수로 제출해주세요.· 자료 제출 칸에 첨부 혹은 링크를 넣어주세요. (파일크기가 50MB를 넘는 경우 서류 접수 시 링크 첨부하여  제출)· 포지션에 따라 사전 과제가 있을 수 있습니다.· 계약직(3개월) 이후 정규직 전환을 진행합니다 ...
#   'job_industry': '컨설팅, 개발, 브랜딩, 디자인/컨설팅, 광고대행, 서비스/기획, #미디어#기획자#마케팅, 기획자, 사업기획',
#   'date_start': '2024-08-07',
#   'date_end': None},
#  {'company_id': '95952',
#   'company_name': '주식회사 알파브라더스',
#   'description': '스타트업 전문 엑셀러레이터입니다.',
#   'job_id': '150942',
#   'job_title': '크리에이티브 디렉터 - 브랜딩 및 디자인 총괄',
#   'job_career': ['경력'],
#   'timestamp': '2024-08-07_02:43:02',
#   'crawl_domain': 'www.rocketpunch.com',
#   'job_task': '■ 주요 업무ABBG가 기대하는 크리에이티브 디렉터의 업무를 알려드려요.알파브라더스의 독립레이블인 ABBG 소속으로 팀 내 업무일정 관리 및 결과물 관리감독 등의 업무를 담당하며, 동료 디자이너를 리드하여 브랜드경험 디자인 프로젝트 전반을 지휘하는 역할을 맡습니다.[업무 상세 내용] 브랜딩 및 디자인 실무 총괄 및 리딩· 프로젝트에 대한 이해를 바탕으로 업무 방향성 제시· BX/UX 영역의 디자인 및 크리에이티브 전반 총괄· 팀 내 업무 프로세스 확립 및 조직 관리· 팀원 매니지먼트 및 성장을 주도할 수 있는 리더 업무· 프로젝트 일정관리· 디자인 결과물 검수· 생산 및 인쇄감리· 용역 입찰 / 비딩 제안서 작성',
#   'job_specialties': 'UI/UX 디자인, 모바일 디자인, UI 디자인, Zeplin, 서비스 디자인',
#   'job_detail': "알파브라더스 브랜드그룹 [ABBG]상상을 현실로 만드는 디자인 - ALPHA BROTHERS BRAND GROUP알파브라더스 브랜드그룹 [ABBG]은 단순 자금지원에서 그치지 않고 실무인력까지 지원하는 ACTIVE 액셀러레이터인 알파브라더스의 독립레이블입니다 🚀We Build Company - 알파브라더스는 어떤 회사인가요?· 💰 투자실적 : 2020년부터 누적 21.7억원· 👩\u200d👧\u200d👦 사내벤처 실적 : 2020년부터 총 5개의 사내벤처 창업· 🏛️ 정부 연계 액셀러레이팅 : 2022년부터 매해 평균 3개 용역 실행독립레이블을 양성하는 창업지원 그룹 ABCDE 본부알파브라더스의 창업지원 그룹은 유망기업에게 자금투자와 실무지원을 제공하며, 실무분야 별로 ABCDE 5개 본부로 구성되어 있습니다.창업지원 그룹 ABCDE본부 지원을 통해 성공적으로 자립하는 기업은 독립레이블이라 불립니다.창업지원 그룹 ABCDE 본부는 어떤 업무를 지원하나요?· ADVISOR 본부 - [정부지원금부터 민간투자까지 자금조달 러닝메이트] : 알파브라더스 어드바이저 본부는 초기에 필요한 자금 확보 뿐만 아니라 기업 생애주기에 맞는 자금조달 컨설팅을 제공합니다.· BRAND 본부 - [제품과 서비스의 기본! 브랜드 설계와 작업까지] : 알파브라더스 브랜드 본부는 로고, 패키지, 상세페이지, UXUI, 사진/영상 촬영 등 토탈 브랜딩 서비스를 지원합니다.· CREATIVE 본부 - [숫자와 데이터로 매출을 일으키는 마케팅] : 알파브라더스 크리에이티브 본부는 고객 행동 데이터 분석을 통해 더 효과적으로 매출 증대를 이끌어내는 마케팅 전략 구축 및 실행을 지원합니다.· DATA & DEV  본부 - [비즈니스 모델 검증과 시장에 필요한 서비스 개발] : 알파브라더스 데이터&개발 본부는 MVP 테스트를 통해 초기 비즈니스 모델의 시장성, 사용성, 기술성 검증을 진행하고 잠재 고객 데이터를 기반으로 시장에 필요한 웹과 앱개발을 지원합니다.· EXPERT 본부 - [회사 경영관련 지원과 컨설팅 제공] : 알파브라더스 엑스퍼트 본부는 11명의 사내 노무사, 세무/회계사, 변호/변리사, 경영지도사 전문가의 지속적인 컨설팅과 실무를 지원합니다.우리에 대해 더 알고 싶은 것이 있으시다면?🔍ABBG 홈페이지 접속! 👉https://www.abbg.co.kr알파브라더스 홈페이지 접속!👉https://www.alphabrothers.co.kr/채용 배경✏️독립레이블로의 도약을 시작하는 ABBG!알파브라더스 BRAND 본부로써 쌓아온 6년간의 디자인 필드 노하우를 기반으로 ABBG는 2024년 토탈브랜딩 에이전시 론칭을 준비하며 독립레이블로의 도약을 시작하고 있습니다. 열정 넘치는 ABBG의 디자이너들을 이끌어 새로운 에이전시 업무를 총괄하는 디렉터 인력을 찾고 있습니다.팀 소개 💁🏻\u200d♂️에이전시팀은 ABBG 소속으로 민간 비딩 프로젝트를 비롯한 정부 용역 등의 업무 수주를 통해 프로젝트 단위의 브랜딩, 디자인 서비스를 제공하고자 합니다.주요 업무 💫ABBG가 기대하는 크리에이티브 디렉터의 업무를 알려드려요.알파브라더스의 독립레이블인 ABBG 소속으로 팀 내 업무일정 관리 및 결과물 관리감독 등의 업무를 담당하며, 동료 디자이너를 리드하여 브랜드경험 디자인 프로젝트 전반을 지휘하는 역할을 맡습니다.[업무 상세 내용] 브랜딩 및 디자인 실무 총괄 및 리딩· 프로젝트에 대한 이해를 바탕으로 업무 방향성 제시· BX/UX 영역의 디자인 및 크리에이티브 전반 총괄· 팀 내 업무 프로세스 확립 및 조직 관리· 팀원 매니지먼트 및 성장을 주도할 수 있는 리더 업무· 프로젝트 일정관리· 디자인 결과물 검수· 생산 및 인쇄감리· 용역 입찰 / 비딩 제안서 작성자격 요건 🔥우리는 아래 자격들을 갖춘 지원자를 원해요.[ 필수 ] 마인드셋· 자신의 의견을 명확하게 표현할 수 있는 분 · 다양한 의견을 경청하면서도 명확한 근거를 갖춘 디렉션을 지향하는 분· 일의 목표를 기준으로 다양한 분야의 전문가, 관계자들과 커뮤니케이션이 가능하신 분[ 필수 ] 스킬셋· 유관경력 7년 이상에 준하는 브랜딩 및 디자인 실무 경력이 있으신 분· 대졸 이상의 학력을 가지신 분· 브랜드 가이드 구축 및 운영 경험을 가지신 분· 인쇄 및 생산감리 경험을 가지신 분· 디자인 소프트웨어(Adobe, Figma) 사용능력을 갖추신 분[ 우대 ] 스킬셋· [에이전시] 브랜딩 및 디자인 에이전시 경력이 있으신 분· [디자인 어워드] Red dot, IF를 비롯한 디자인 어워드 입상 경험이 있으신 분· [비딩] 민간/정부 디자인 분야 비딩을 통한 프로젝트 수주, 진행 경험이 있으신 분조직문화와 인재상을 위한 맞춤 복지 혜택 💝ABBG는 구성원들이 끊임없이 성장하고, 도전에서 배우고, 주도적으로 성과를 창출할 수 있는 조직문화를 만들기 위해 오늘도 고민하는 알파브라더스와 똑같은 복지 혜택을 제공합니다!1️⃣ 회사의 성장과 개인의 성장을 동반한다. 우리는 [성장 지향형 인재]입니다.📢 성장 지향적 인재를 위한 맞춤 복지제도를 소개합니다.· 신규입사자를 위한 일학습병행 프로그램· 주니어를 위한 스터디룸 운영· 시니어를 위한 외부 전문가 1:1 멘토링· 자격증 취득 비용 지원· 1,500권 이상의 사내 도서관 운영· 외부기관 연계 교육 프로그램 제공2️⃣ 실패는 없다, 레슨런만 있을 뿐. 우리는 [도전 지향형 인재]입니다.📢 도전 지향적 인재를 위한 맞춤 복지제도를 소개합니다.· 상시 랩업을 위한 주니어-시니어 면담· 월간 랩업을 위한 시니어 세미나· 분기/반기 랩업을 위한 팀별 워크숍· 사내벤처 프로그램 운영· 사이드 프로젝트 지원· 대표님과 1:1 커피챗3️⃣ OUTPUT = Performance x Time. 우리는 [성과 지향형 인재] 입니다.📢 성과 지향적 인재를 위한 맞춤 복지제도를 소개합니다.· 원하는 시간에 출근하자!· 원하는 시간대에 일하자!· 원하는 곳에서 근무하자!· 일과 휴가를 동시에, 워케이션 지원· 최신 장비 및 툴 지원· 집중을 위해 스마트 워크부스 지원채용 과정📌📥[ 첫번째, 입사지원 ]· 아래 지원하기 버튼을 통해 지원서 작성 (소요시간 3분 미만)🗂[ 두번째, 서류전형 ]· 상시채용으로 진행되며, 이력서를 검토하는 대로 합격, 불합격 상관 없이 모든 지원자 분께 서류전형 결과를 발표합니다.· 이력서, 자기소개서, 포트폴리오 제출 (필수)📢[ 세번째, 과제 및 면접 전형 ]  - (약 30분 ~ 1시간 이내)· (과제 제출이 필요할 경우) 면접 전형 전까지 메일로 회신해주시면 됩니다.· 지원자분과 적합도를 알아보기 위한 인터뷰 · 이력서, 자기소개서, 포트폴리오를 중심으로 이야기 하되, 본인의 핵심 스킬셋이 무엇인지 왜 그렇게 생각하는지에 대해 여러 경험을 함께 소통하는 자리입니다. 📄[네번째, 서류 검토]· 면접 전형 합격자에 한하여 개별로 구비서류를 메일로 요청드립니다.· 메일을 받으신 날로부터 3일 이내 회신해주셔야 합니다.· 제출한 구비서류 중 허위 사실이 발견될 경우 채용이 취소될 수 있습니다.🖋️[다섯번째, 처우 협의]· 제출한 서류에 이상이 없을 경우 입사제안서를 메일로 발송드립니다.· 메일을 받으신 날로부터 3일 이내 회신해주셔야 합니다.🎉[ 최종합격 ]· 최종합격 시 개별 연락으로 안내합니다.❗️ 확인해주세요❗️· 본 공고는 주식회사 알파브라더스가 아닌, 독립레이블 주식회사 에이비비지(ABBG)의 채용공고입니다.· 경력 위주로 서류를 작성해주세요.· 서류 전형 합격자에 한해 개별 합격 안내 및 대면 면접을 진행하고 있어요.❗️꼭 읽어주세요❗️· 지원 시 이력서(경력기술)와 함께, '포트폴리오📑'를 필수로 제출해주세요.· 자료 제출 칸에 첨부 혹은 링크를 넣어주세요. (파일크기가 50MB를 넘는 경우 서류 접수 시 링크 첨부하 제출)· 계약직(3개월) 이후 정규직 전환을 진행합니다. (단, 수습기간 및 계약기간 내 임금은 100% 지급됩니다.)",
#   'job_industry': '컨설팅, 개발, 브랜딩, 디자인/컨설팅, 광고대행, 서비스/기획, #미디어#기획자#마케팅, 기획자, 사업기획',
#   'date_start': '2024-08-07',
#   'date_end': None},
#  {'company_id': '95952',
#   'company_name': '주식회사 알파브라더스',
#   'description': '스타트업 전문 엑셀러레이터입니다.',
#   'job_id': '151228',
#   'job_title': '[알파브라더스] 퍼포먼스 마케터 (팀리드)',
#   'job_career': ['경력'],
#   'timestamp': '2024-08-07_02:43:02',
#   'crawl_domain': 'www.rocketpunch.com',
#   'job_task': '',
#   'job_specialties': 'meta, google ads, 퍼포먼스 마케팅, 퍼포먼스마케터',
#   'job_detail': "알파브라더스We Build Company - 알파브라더스는 컴퍼니 빌딩형 액셀러레이터입니다ㆍ💰 투자실적 : 2020년부터 누적 21.7억원ㆍ👩\u200d👧\u200d👦 사내벤처 실적 : 2020년부터 총 5개의 사내벤처 창업ㆍ🏛️ 정부 연계 액셀러레이팅 : 2022년부터 매해 평균 3개 용역 실행알파브라더스는 초기기업을 대상으로 투자하는 액셀러레이터이며, 그 중에서도 단순 자금지원에서 그치지 않고 실무인력까지 지원하는 ACTIVE 액셀러레이터입니다 🚀독립레이블을 양성하는 창업지원 그룹 ABCDE 본부알파브라더스의 창업지원 그룹은 유망기업에게 자금투자와 실무지원을 제공하며, 실무분야 별로 ABCDE 5개 본부로 구성되어 있습니다.창업지원 그룹 ABCDE본부 지원을 통해 성공적으로 자립하는 기업은 독립레이블이라 불립니다.창업지원 그룹 ABCDE 본부는 어떤 업무를 지원하나요?ㆍ ADVISOR 본부 - [정부지원금부터 민간투자까지 자금조달 러닝메이트] : 알파브라더스 어드바이저 본부는 초기에 필요한 자금 확보 뿐만 아니라 기업 생애주기에 맞는 자금조달 컨설팅을 제공합니다.ㆍ BRAND 본부 - [제품과 서비스의 기본! 브랜드 설계와 작업까지] : 알파브라더스 브랜드 본부는 로고, 패키지, 상세페이지, UXUI, 사진/영상 촬영 등 토탈 브랜딩 서비스를 지원합니다.ㆍ CREATIVE 본부 - [숫자와 데이터로 매출을 일으키는 마케팅] : 알파브라더스 크리에이티브 본부는 고객 행동 데이터 분석을 통해 더 효과적으로 매출 증대를 이끌어내는 마케팅 전략 구축 및 실행을 지원합니다.ㆍ DATA & DEV  본부 - [비즈니스 모델 검증과 시장에 필요한 서비스 개발] : 알파브라더스 데이터&개발 본부는 MVP 테스트를 통해 초기 비즈니스 모델의 시장성, 사용성, 기술성 검증을 진행하고 잠재 고객 데이터를 기반으로 시장에 필요한 웹과 앱개발을 지원합니다.ㆍ EXPERT 본부 - [회사 경영관련 지원과 컨설팅 제공] : 알파브라더스 엑스퍼트 본부는 11명의 사내 노무사, 세무/회계사, 변호/변리사, 경영지도사 전문가의 지속적인 컨설팅과 실무를 지원합니다.우리에 대해 더 알고 싶은 것이 있으시다면?🔍홈페이지 접속!👉https://www.alphabrothers.co.kr/채용 배경✏️알파브라더스는 총 80명의 사내 전문가들이 A/B/C/D/E 5개의 그룹으로 나뉘어 사업기획, 디자인, 마케팅, 개발, 인사/재무/법률 등 다양한 분야의 실무를 지원하고 있습니다. 퍼포먼스 마케팅 분야에서 더욱 강력한 경쟁력을 구축하고, 새로운 아이디어와 역량을 통해 마케팅 성과를 높이기 위해 이번 채용을 진행하게 되었습니다.알파브라더스는 데이터 기반의 전략적 실행 능력을 통해 고객을 유입시키고, 콘텐츠와 목표 지표를 개선하여 고객을 획득하고, 매출 증대를 위한 아이디어와 열정을 가진 퍼포먼스 마케팅 리드를 찾고 있습니다.팀 소개 💁🏻\u200d♂️우리 팀은 데이터를 활용하여 광고 성과를 개선하고, 브랜드의 성장을 함께 이루어가는 팀입니다.현재 우리는 액셀러레이터 회사로서 투자하고 있는 기업의 브랜드를 인하우스형태로 맡아 다양한 마케팅 업무를 진행하고 있습니다.ㆍ 패션 브랜드: 자사몰에서 월간 약 1.5억 원의 매출이 발생하며, 광고비는 약 3천만원으로 운영하고 있습니다.ㆍ F&B 브랜드: 온라인몰에서 월간 약 7억 원의 매출이 발생하며, 광고비는 약 3천만원으로 운영하고 있습니다.ㆍ 사내 벤처 브랜드: 3개의 브랜드를 관리하며, 월간 광고비는 약 1천5백만 원으로 운영하고 있습니다.현재 팀 구성은 퍼포먼스 마케터(주니어) 1명과 CRM 마케터(주니어) 1명, 콘텐츠 마케터(주니어) 1명, 디자이너(대리급) 1명으로 이루어져 있으며, 이번 채용을 통해 팀의 리딩 역량을 강화하고자 합니다.우리는 퍼포먼스 마케팅의 중요성을 이해하고 목표 달성을 위해 협력하며, 서로의 아이디어를 존중하고 원활한 커뮤니케이션을 추구하는 환경을 만들고 있습니다.주요 업무 💫퍼포먼스 마케터 팀리드로서 다음과 같은 업무를 담당하게 됩니다. : )ㆍ 다양한 채널을 활용한 효과적인 미디어 믹스 전략 수립ㆍ 팀의 퍼포먼스 마케팅 실무를 리드하고 운영ㆍ 데이터를 기반으로 성과를 분석하고 매출을 상승시키는 전략 수립 및 실행ㆍ 각 브랜드의 목표에 맞춘 전략 및 예산 수립 자격 요건 🔥우리는 아래 자격들을 갖춘 지원자를 원해요.[마인드셋]ㆍ 데이터에 근거하여 의사결정을 내리고 성과를 향상시키기 위해 지속적으로 데이터를 분석하고 개선점을 찾으시는 분ㆍ 새로운 아이디어를 실험하며 실패를 두려워하지 않는 실험적 사고를 가지신 분ㆍ 비즈니스 목표와 전략을 이해하고 성장을 위한 전략적 사고를 가지신 분ㆍ 빠르게 변화하는 마케팅 트렌드와 업계의 변화에 대응하고 적극적인 사고를 가지신 분[스킬셋]ㆍ 퍼포먼스 마케팅 경력 4~5년 이상 또는 이에 준하는 역량을 보유하신 분ㆍ Meta, Google Ads, Naver 검색광고 등 주요 광고 플랫폼 운영 경험이 있으신 분ㆍ GA, Tableau, Looker Studio 등 데이터 시각화 및 분석 도구 사용이 가능하신 분ㆍ 유관부서 및 이해관계자와 효과적 커뮤니케이션이 가능하신 분[우대사항]ㆍ 이커머스 브랜드에서 근무 경험이 있으신 분ㆍ 성공적인 프로젝트 리드 경험이 있으신 분ㆍ AARRR 퍼널별 CTR 및 CVR 개선 경험이 있으신 분ㆍ 마케팅 실험과 빠른 실행, 집요한 개선을 통해 목표를 달성한 경험이 있으신 분ㆍ 팀 리드 경험 및 원활한 의사소통 능력을 가지신 분조직문화와 인재상을 위한 맞춤 복지 혜택 💝알파브라더스는 구성원들이 끊임없이 성장하고, 도전에서 배우고, 주도적으로 성과를 창출할 수 있는 조직문화를 만들기 위해 오늘도 고민합니다.1️⃣ 회사의 성장과 개인의 성장을 동반한다. 우리는 [성장 지향형 인재]입니다.📢 성장 지향적 인재를 위한 맞춤 복지제도를 소개합니다.ㆍ 신규입사자를 위한 일학습병행 프로그램ㆍ 주니어를 위한 스터디룸 운영ㆍ 시니어를 위한 외부 전문가 1:1 멘토링ㆍ 자격증 취득 비용 지원ㆍ 1,500권 이상의 사내 도서관 운영ㆍ 외부기관 연계 교육 프로그램 제공2️⃣ 실패는 없다, 레슨런만 있을 뿐. 우리는 [도전 지향형 인재]입니다.📢 도전 지향적 인재를 위한 맞춤 복지제도를 소개합니다.ㆍ 상시 랩업을 위한 주니어-시니어 면담ㆍ 월간 랩업을 위한 시니어 세미나ㆍ 분기/반기 랩업을 위한 팀별 워크숍ㆍ 사내벤처 프로그램 운영ㆍ 사이드 프로젝트 지원ㆍ 대표님과 1:1 커피챗3️⃣ OUTPUT = Performance x Time. 우리는 [성과 지향형 인재] 입니다.📢 성과 지향적 인재를 위한 맞춤 복지제도를 소개합니다.ㆍ 원하는 시간에 출근하자!ㆍ 원하는 시간대에 일하자!ㆍ 원하는 곳에서 근무하자!ㆍ 일과 휴가를 동시에, 워케이션 지원ㆍ 최신 장비 및 툴 지원ㆍ 집중을 위해 스마트 워크부스 지원채용 과정📌📑[ 첫번째, 서류 전형 ]ㆍ 상시채용으로 진행되며, 이력서를 검토하는 대로 합격, 불합격 상관 없이 모든 지원자 분께 서류전형 결과를 발표합니다.ㆍ 이력서, 자기소개서, 포트폴리오 제출(필수)📢[ 두번째, 과제 및 면접 전형 ]  - (약 30분 ~ 1시간 이내)ㆍ (과제 제출이 필요할 경우) 면접 전형 전까지 메일로 회신해주시면 됩니다.ㆍ 지원자분과 적합도를 알아보기 위한 인터뷰 ㆍ 이력서, 자기소개서, 포트폴리오를 중심으로 이야기 하되, 본인의 핵심 스킬셋이 무엇인지 왜 그렇게 생각하는지에 대해 여러 경험을 함께 소통하는 자리입니다. 📄[세번째, 서류 검토]ㆍ 면접 전형 합격자에 한하여 개별로 구비서류를 메일로 요청드립니다.ㆍ 메일을 받으신 날로부터 3일 이내 회신해주셔야 합니다.ㆍ 제출한 구비서류 중 허위 사실이 발견될 경우 채용이 취소될 수 있습니다.🖋️[네번째, 처우 협의]ㆍ 제출한 서류에 이상이 없을 경우 입사제안서를 메일로 발송드립니다.ㆍ 메일을 받으신 날로부터 3일 이내 회신해주셔야 합니다.🎉[ 최종 합격 ]ㆍ 최종합격 시 개별 연락으로 안내합니다.❗️ 확인해주세요❗️ㆍ 경력 위주로 서류를 작성해주세요.ㆍ 서류 전형 합격자에 한해 개별 합격 안내 및 대면 면접을 진행하고 있어요.❗️꼭 읽어주세요❗️ㆍ ...
#   'job_industry': '컨설팅, 개발, 브랜딩, 디자인/컨설팅, 광고대행, 서비스/기획, #미디어#기획자#마케팅, 기획자, 사업기획',
#   'date_start': '2024-08-07',
#   'date_end': None},
#  {'company_id': '95952',
#   'company_name': '주식회사 알파브라더스',
#   'description': '스타트업 전문 엑셀러레이터입니다.',
#   'job_id': '151229',
#   'job_title': '[알파브라더스] 콘텐츠 디자이너 (경력)',
#   'job_career': ['경력'],
#   'timestamp': '2024-08-07_02:43:02',
#   'crawl_domain': 'www.rocketpunch.com',
#   'job_task': '',
#   'job_specialties': 'Adobe Photoshop, Adobe Illustrator, 그래픽 디자인, 콘텐츠 기획, 콘텐츠 제작, 디지털광고',
#   'job_detail': "알파브라더스We Build Company - 알파브라더스는 컴퍼니 빌딩형 액셀러레이터입니다ㆍ 💰 투자실적 : 2020년부터 누적 21.7억원ㆍ 👩\u200d👧\u200d👦 사내벤처 실적 : 2020년부터 총 5개의 사내벤처 창업ㆍ 🏛️ 정부 연계 액셀러레이팅 : 2022년부터 매해 평균 3개 용역 실행알파브라더스는 초기기업을 대상으로 투자하는 액셀러레이터이며, 그 중에서도 단순 자금지원에서 그치지 않고 실무인력까지 지원하는 ACTIVE 액셀러레이터입니다 🚀독립레이블을 양성하는 창업지원 그룹 ABCDE 본부알파브라더스의 창업지원 그룹은 유망기업에게 자금투자와 실무지원을 제공하며, 실무분야 별로 ABCDE 5개 본부로 구성되어 있습니다.창업지원 그룹 ABCDE본부 지원을 통해 성공적으로 자립하는 기업은 독립레이블이라 불립니다.창업지원 그룹 ABCDE 본부는 어떤 업무를 지원하나요?ㆍ ADVISOR 본부 - [정부지원금부터 민간투자까지 자금조달 러닝메이트] : 알파브라더스 어드바이저 본부는 초기에 필요한 자금 확보 뿐만 아니라 기업 생애주기에 맞는 자금조달 컨설팅을 제공합니다.ㆍ BRAND 본부 - [제품과 서비스의 기본! 브랜드 설계와 작업까지] : 알파브라더스 브랜드 본부는 로고, 패키지, 상세페이지, UXUI, 사진/영상 촬영 등 토탈 브랜딩 서비스를 지원합니다.ㆍ CREATIVE 본부 - [숫자와 데이터로 매출을 일으키는 마케팅] : 알파브라더스 크리에이티브 본부는 고객 행동 데이터 분석을 통해 더 효과적으로 매출 증대를 이끌어내는 마케팅 전략 구축 및 실행을 지원합니다.ㆍ DATA & DEV  본부 - [비즈니스 모델 검증과 시장에 필요한 서비스 개발] : 알파브라더스 데이터&개발 본부는 MVP 테스트를 통해 초기 비즈니스 모델의 시장성, 사용성, 기술성 검증을 진행하고 잠재 고객 데이터를 기반으로 시장에 필요한 웹과 앱개발을 지원합니다.ㆍ EXPERT 본부 - [회사 경영관련 지원과 컨설팅 제공] : 알파브라더스 엑스퍼트 본부는 11명의 사내 노무사, 세무/회계사, 변호/변리사, 경영지도사 전문가의 지속적인 컨설팅과 실무를 지원합니다.우리에 대해 더 알고 싶은 것이 있으시다면?🔍홈페이지 접속!👉https://www.alphabrothers.co.kr/채용 배경✏️알파브라더스는 총 80명의 사내 전문가들이 A/B/C/D/E 5개의 그룹으로 나뉘어 사업기획, 디자인, 마케팅, 개발, 인사/재무/법률 등의 전분야 실무를 지원하고 있습니다.이에 퍼포먼스 마케팅 분야에서 더욱 강력한 경쟁력을 구축하고 새로운 아이디어와 역량을 통해 마케팅 성과를 높이려고 합니다.\xa0팀 소개 💁🏻\u200d♂️우리 팀은 데이터를 근거로 한 전략을 통해 커머스를 성장시키는 팀입니다!커머스에 디자인이 중요한 이유를 이해하고 원하는 목표를 달성하기 위해 노력합니다!\xa0서로의 아이디어를 존중하고 커뮤니케이션이 원활할 수 있는 환경을 추구합니다!현재 우리는 액셀러레이터 회사로 투자하고 있는 기업의 브랜드를 인하우스 형태로 맡아 업무를 진행하고 있습니다.\xa0패션 브랜드, F&B 브랜드, 그리고 내부에서 창업한 3개의 브랜드를 관리하며, 각 브랜드마다 다양한 마케팅 전략을 실행하고 있습니다.팀 구성은 퍼포먼스 팀리드 1명과 퍼포먼스 마케터(주니어) 1명, CRM 마케터(주니어) 1명, 콘텐츠 마케터(주니어) 1명으로 이루어져 있으며,이번 채용을 통해 팀의 디자인 역량을 강화하고자 합니다.주요 업무 💫우리 팀의 디자이너로서 다음과 같은 업무를 담당하게 됩니다.ㆍ 패션 및 F&B 브랜드의 SNS 채널에 적합한 시각적 콘텐츠 제작ㆍ 제품 설명 및 구매 전환을 위한 상세페이지 디자인ㆍ 디지털 광고를 위한 이미지 및 그래픽 디자인ㆍ 디자인 기획 과정에서 주도적으로 리딩자격 요건\xa0🔥우리는 아래 자격을 갖춘 지원자를 원합니다![마인드셋]ㆍ 창의적 사고를 바탕으로 혁신적인 디자인을 제안할 수 있는 분ㆍ 팀과의 협업을 중요하게 생각하고 원활한 커뮤니케이션이 가능한 분ㆍ 마케팅 목표와 브랜드 전략을 이해하고 디자인에 반영할 수 있는 전략적 사고를 가지신 분[스킬셋]ㆍ 그래픽 디자인 관련 3~4년 이상의 경력을 보유하신 분ㆍ Adobe Creative Suite (Photoshop, Illustrator 등) 사용에 능숙하신 분ㆍ 다양한 디지털 플랫폼의 디자인 요구사항에 대한 이해가 있으신 분ㆍ 포트폴리오 제출 필수[우대사항]ㆍ 패션 및 F&B 브랜드 디자인 경험이 있으신 분ㆍ 콘텐츠 기획 및 주도적 참여 경험이 있으신 분ㆍ 트렌드에 민감하고 빠르게 적응할 수 있는 분조직문화와 인재상을 위한 맞춤 복지 혜택 💝알파브라더스는 구성원들이 끊임없이 성장하고, 도전에서 배우고, 주도적으로 성과를 창출할 수 있는 조직문화를 만들기 위해 오늘도 고민합니다.1️⃣ 회사의 성장과 개인의 성장을 동반한다. 우리는 [성장 지향형 인재]입니다.📢 성장 지향적 인재를 위한 맞춤 복지제도를 소개합니다.ㆍ 신규입사자를 위한 일학습병행 프로그램ㆍ 주니어를 위한 스터디룸 운영ㆍ 시니어를 위한 외부 전문가 1:1 멘토링ㆍ 자격증 취득 비용 지원ㆍ 1,500권 이상의 사내 도서관 운영ㆍ 외부기관 연계 교육 프로그램 제공2️⃣ 실패는 없다, 레슨런만 있을 뿐. 우리는 [도전 지향형 인재]입니다.📢\xa0도전 지향적 인재를 위한 맞춤 복지제도를 소개합니다.ㆍ 상시 랩업을 위한 주니어-시니어 면담ㆍ 월간 랩업을 위한 시니어 세미나ㆍ 분기/반기 랩업을 위한 팀별 워크숍ㆍ 사내벤처 프로그램 운영ㆍ 사이드 프로젝트 지원ㆍ 대표님과 1:1 커피챗3️⃣ OUTPUT = Performance x Time. 우리는 [성과 지향형 인재] 입니다.📢 성과 지향적 인재를 위한 맞춤 복지제도를 소개합니다.ㆍ 원하는 시간에 출근하자!ㆍ 원하는 시간대에 일하자!ㆍ 원하는 곳에서 근무하자!ㆍ 일과 휴가를 동시에, 워케이션 지원ㆍ 최신 장비 및 툴 지원ㆍ 집중을 위해 스마트 워크부스 지원채용 과정📌🗂[ 첫번째, 서류 전형 ]ㆍ 상시채용으로 진행되며, 이력서를 검토하는 대로 합격, 불합격 상관 없이 모든 지원자 분께 서류전형 결과를 발표합니다.ㆍ 이력서, 자기소개서, 포트폴리오 제출 (필수)📢[두번째, 과제 및 면접 전형 ]\xa0 - (약 30분 ~ 1시간 이내)ㆍ (과제 제출이 필요할 경우) 면접 전형 전까지 메일로 회신해주시면 됩니다.ㆍ 지원자분과 적합도를 알아보기 위한 인터뷰\xa0ㆍ 이력서, 자기소개서, 포트폴리오를 중심으로 이야기 하되, 본인의 핵심 스킬셋이 무엇인지 왜 그렇게 생각하는지에 대해 여러 경험을 함께 소통하는 자리입니다.\xa0📄[세번째, 서류 검토]ㆍ 면접 전형 합격자에 한하여 개별로 구비서류를 메일로 요청드립니다.ㆍ 메일을 받으신 날로 부터 3일 이내 회신해주셔야 합니다.ㆍ 제출한 구비서류 중 허위 사실이 발견될 경우 채용이 취소될 수 있습니다.🖋️[네번째, 처우 협의]ㆍ 제출한 서류에 이상이 없을 경우 입사제안서를 메일로 발송드립니다.ㆍ 메일을 받으신 날로부터 3일 이내 회신해주셔야 합니다.🎉[ 최종 합격 ]ㆍ 최종합격 시 개별 연락으로 안내합니다.❗️ 확인해주세요❗️ㆍ 경력 위주로 서류를 작성해주세요.ㆍ 서류 전형 합격자에 한해 개별 합격 안내 및 대면 면접을 진행하고 있어요.❗️꼭 읽어주세요❗️ㆍ 지원 시, '포트폴리오📑'를 필수로 제출해주세요.ㆍ 자료 제출 칸에 첨부 혹은 링크를 넣어주세요. (파일크기가 50MB를 넘는 경우 서류 접수 시 링크 첨부하 제출)ㆍ 포지션에 따라 사전 과제가 있을 수 있습니다.ㆍ 계약직(3개월) 이후 정규직 전환을 진행합니다.",
#   'job_industry': '컨설팅, 개발, 브랜딩, 디자인/컨설팅, 광고대행, 서비스/기획, #미디어#기획자#마케팅, 기획자, 사업기획',
#   'date_start': '2024-08-07',
#   'date_end': None},
#  {'company_id': '95952',
#   'company_name': '주식회사 알파브라더스',
#   'description': '스타트업 전문 엑셀러레이터입니다.',
#   'job_id': '151230',
#   'job_title': '[알파브라더스] 콘텐츠 마케터(신입)',
#   'job_career': ['신입, 경력'],
#   'timestamp': '2024-08-07_02:43:02',
#   'crawl_domain': 'www.rocketpunch.com',
#   'job_task': '',
#   'job_specialties': 'Adobe Photoshop, Adobe Illustrator, 영상편집, 콘텐츠기획, SNS 마케팅',
#   'job_detail': "알파브라더스We Build Company - 알파브라더스는 컴퍼니 빌딩형 액셀러레이터입니다ㆍ 💰 투자실적 : 2020년부터 누적 21.7억원ㆍ 👩\u200d👧\u200d👦 사내벤처 실적 : 2020년부터 총 5개의 사내벤처 창업ㆍ 🏛️ 정부 연계 액셀러레이팅 : 2022년부터 매해 평균 3개 용역 실행알파브라더스는 초기기업을 대상으로 투자하는 액셀러레이터이며, 그 중에서도 단순 자금지원에서 그치지 않고 실무인력까지 지원하는 ACTIVE 액셀러레이터입니다 🚀독립레이블을 양성하는 창업지원 그룹 ABCDE 본부알파브라더스의 창업지원 그룹은 유망기업에게 자금투자와 실무지원을 제공하며, 실무분야 별로 ABCDE 5개 본부로 구성되어 있습니다.창업지원 그룹 ABCDE본부 지원을 통해 성공적으로 자립하는 기업은 독립레이블이라 불립니다.창업지원 그룹 ABCDE 본부는 어떤 업무를 지원하나요?ㆍ ADVISOR 본부 - [정부지원금부터 민간투자까지 자금조달 러닝메이트] : 알파브라더스 어드바이저 본부는 초기에 필요한 자금 확보 뿐만 아니라 기업 생애주기에 맞는 자금조달 컨설팅을 제공합니다.ㆍ BRAND 본부 - [제품과 서비스의 기본! 브랜드 설계와 작업까지] : 알파브라더스 브랜드 본부는 로고, 패키지, 상세페이지, UXUI, 사진/영상 촬영 등 토탈 브랜딩 서비스를 지원합니다.ㆍ CREATIVE 본부 - [숫자와 데이터로 매출을 일으키는 마케팅] : 알파브라더스 크리에이티브 본부는 고객 행동 데이터 분석을 통해 더 효과적으로 매출 증대를 이끌어내는 마케팅 전략 구축 및 실행을 지원합니다.ㆍ DATA & DEV  본부 - [비즈니스 모델 검증과 시장에 필요한 서비스 개발] : 알파브라더스 데이터&개발 본부는 MVP 테스트를 통해 초기 비즈니스 모델의 시장성, 사용성, 기술성 검증을 진행하고 잠재 고객 데이터를 기반으로 시장에 필요한 웹과 앱개발을 지원합니다.ㆍ EXPERT 본부 - [회사 경영관련 지원과 컨설팅 제공] : 알파브라더스 엑스퍼트 본부는 11명의 사내 노무사, 세무/회계사, 변호/변리사, 경영지도사 전문가의 지속적인 컨설팅과 실무를 지원합니다.우리에 대해 더 알고 싶은 것이 있으시다면?🔍홈페이지 접속!👉https://www.alphabrothers.co.kr/채용 배경✏️알파브라더스는 총 80명의 사내 전문가들이 A/B/C/D/E 5개의 그룹으로 나뉘어 사업기획, 디자인, 마케팅, 개발, 인사/재무/법률 등의 전분야 실무를 지원하고 있습니다. 이에 콘텐츠 마케팅 분야에서 더욱 강력한 경쟁력을 구축하고 새로운 아이디어와 역량을 통해 마케팅 성과를 높이려고 합니다\xa0팀 소개 💁🏻\u200d♂️우리 팀은 데이터를 근거로 한 전략을 통해 커머스를 성장시키는 팀입니다!콘텐츠 마케팅이 중요한 이유를 이해하고 원하는 목표를 달성하기 위해 노력합니다! 서로의 아이디어를 존중하고 커뮤니케이션이 원활할 수 있는 환경을 추구합니다!현재 우리는 액셀러레이터 회사로 투자하고 있는 기업의 브랜드를 인하우스 형태로 맡아 업무를 진행하고 있습니다.\xa0패션 브랜드, F&B 브랜드, 그리고 내부에서 창업한 3개의 브랜드를 관리하며, 각 브랜드마다 다양한 마케팅 전략을 실행하고 있습니다.팀 구성은 퍼포먼스 팀리드 1명과 퍼포먼스 마케터(주니어) 1명, CRM 마케터(주니어) 1명, 디자이너(대리급) 1명으로 이루어져 있으며, 이번 채용을 통해 팀의 콘텐츠 역량을 강화하고자 합니다.주요 업무 💫콘텐츠 마케터로서 다음과 같은 업무를 담당하게 됩니다.ㆍ 브랜드의 메시지와 전략을 반영한 콘텐츠(상세페이지, 광고콘텐츠, SNS 등) 기획ㆍ SNS 및 온라인 채널에 적합한 콘텐츠 기획 및 운영ㆍ 기본적인 포토샵 작업 및 간단한 영상 편집 업무ㆍ 다양한 마케팅 툴을 활용한 콘텐츠 기획 및 제작자격 요건\xa0🔥우리는 아래 자격을 갖춘 지원자를 원합니다![마인드셋]ㆍ 창의적이고 혁신적인 아이디어를 제안할 수 있는 분ㆍ 마케팅 트렌드와 업계 변화를 적극적으로 수용하고 대응할 수 있는 분ㆍ 협업과 커뮤니케이션 능력이 뛰어난 분[스킬셋]ㆍ 포토샵, 일러스트레이터, 영상 편집 툴 사용 경험이 있는 분ㆍ 콘텐츠 기획 및 디자인 경험이 있는 분 (인턴, 프로젝트 등 포함)ㆍ 포트폴리오 제출 필수[우대사항]ㆍ 다양한 콘텐츠 제작 경험이 있으신 분ㆍ SNS 및 디지털 마케팅에 대한 이해가 있는 분ㆍ 빠르게 변화하는 환경에 적응할 수 있는 분조직문화와 인재상을 위한 맞춤 복지 혜택 💝알파브라더스는 구성원들이 끊임없이 성장하고, 도전에서 배우고, 주도적으로 성과를 창출할 수 있는 조직문화를 만들기 위해 오늘도 고민합니다.1️⃣ 회사의 성장과 개인의 성장을 동반한다. 우리는 [성장 지향형 인재]입니다.📢 성장 지향적 인재를 위한 맞춤 복지제도를 소개합니다.ㆍ 신규입사자를 위한 일학습병행 프로그램ㆍ 주니어를 위한 스터디룸 운영ㆍ 시니어를 위한 외부 전문가 1:1 멘토링ㆍ 자격증 취득 비용 지원ㆍ 1,500권 이상의 사내 도서관 운영ㆍ 외부기관 연계 교육 프로그램 제공2️⃣ 실패는 없다, 레슨런만 있을 뿐. 우리는 [도전 지향형 인재]입니다.📢\xa0도전 지향적 인재를 위한 맞춤 복지제도를 소개합니다.ㆍ 상시 랩업을 위한 주니어-시니어 면담ㆍ 월간 랩업을 위한 시니어 세미나ㆍ 분기/반기 랩업을 위한 팀별 워크숍ㆍ 사내벤처 프로그램 운영ㆍ 사이드 프로젝트 지원ㆍ 대표님과 1:1 커피챗3️⃣ OUTPUT = Performance x Time. 우리는 [성과 지향형 인재] 입니다.📢 성과 지향적 인재를 위한 맞춤 복지제도를 소개합니다.ㆍ 원하는 시간에 출근하자!ㆍ 원하는 시간대에 일하자!ㆍ 원하는 곳에서 근무하자!ㆍ 일과 휴가를 동시에, 워케이션 지원ㆍ 최신 장비 및 툴 지원ㆍ 집중을 위해 스마트 워크부스 지원채용 과정📌🗂[ 첫번째, 서류 전형 ]ㆍ 상시채용으로 진행되며, 이력서를 검토하는 대로 합격, 불합격 상관 없이 모든 지원자 분께 서류전형 결과를 발표합니다.ㆍ 이력서, 자기소개서, 포트폴리오 제출 (필수)📢[두번째, 과제 및 면접 전형 ]\xa0 - (약 30분 ~ 1시간 이내)ㆍ (과제 제출이 필요할 경우) 면접 전형 전까지 메일로 회신해주시면 됩니다.ㆍ 지원자분과 적합도를 알아보기 위한 인터뷰\xa0ㆍ 이력서, 자기소개서, 포트폴리오를 중심으로 이야기 하되, 본인의 핵심 스킬셋이 무엇인지 왜 그렇게 생각하는지에 대해 여러 경험을 함께 소통하는 자리입니다.\xa0📄[세번째, 서류 검토]ㆍ 면접 전형 합격자에 한하여 개별로 구비서류를 메일로 요청드립니다.ㆍ 메일을 받으신 날로 부터 3일 이내 회신해주셔야 합니다.ㆍ 제출한 구비서류 중 허위 사실이 발견될 경우 채용이 취소될 수 있습니다.🖋️[네번째, 처우 협의]ㆍ 제출한 서류에 이상이 없을 경우 입사제안서를 메일로 발송드립니다.ㆍ 메일을 받으신 날로부터 3일 이내 회신해주셔야 합니다.🎉[ 최종 합격 ]ㆍ 최종합격 시 개별 연락으로 안내합니다.❗️ 확인해주세요❗️ㆍ 경력 위주로 서류를 작성해주세요.ㆍ 서류 전형 합격자에 한해 개별 합격 안내 및 대면 면접을 진행하고 있어요.❗️꼭 읽어주세요❗️ㆍ 지원 시, '포트폴리오📑'를 필수로 제출해주세요.ㆍ 자료 제출 칸에 첨부 혹은 링크를 넣어주세요. (파일크기가 50MB를 넘는 경우 서류 접수 시 링크 첨부하 제출)ㆍ 포지션에 따라 사전 과제가 있을 수 있습니다.ㆍ 계약직(3개월) 이후 정규직 전환을 진행합니다.",
#   'job_industry': '컨설팅, 개발, 브랜딩, 디자인/컨설팅, 광고대행, 서비스/기획, #미디어#기획자#마케팅, 기획자, 사업기획',
#   'date_start': '2024-08-07',
#   'date_end': None},
#  {'company_id': '95952',
#   'company_name': '주식회사 알파브라더스',
#   'description': '스타트업 전문 엑셀러레이터입니다.',
#   'job_id': '151503',
#   'job_title': '[알파브라더스] UX컨설턴트 (경력)',
#   'job_career': ['경력'],
#   'timestamp': '2024-08-07_02:43:02',
#   'crawl_domain': 'www.rocketpunch.com',
#   'job_task': "데이터기획팀의 업무는 다음과 같아요. : )· 담당 기업의 비즈니스와 제품을 이해하고, 적절한 테스트를 제안해요.· 담당 기업에 대한 이해를 바탕으로 필요한 리서치를 설계하고 운영해요.· '시장성 테스트'를 위한 설문조사를 설계하고, 조사결과 데이터 분석을 통해 전략을 제안해요.· 'FGI/IDI'를 위한 인터뷰 질문지를 기획하고, 인터뷰 결과 데이터 분석을 통해 전략을 제안해요.· 테스트를 통해 얻은 인사이트를 바탕으로 테스트 방법론을 고도화해요.· 디자이너, PM(Project Manager)과 협업을 통해 완성도 높은 결과물을 만들어요.",
#   'job_specialties': 'ms-office, Figma, UI/UX 디자인',
#   'job_detail': "알파브라더스We Build Company - 알파브라더스는 컴퍼니 빌딩형 액셀러레이터입니다· 💰 투자실적 : 2020년부터 누적 21.7억원· 👩\u200d👧\u200d👦 사내벤처 실적 : 2020년부터 총 5개의 사내벤처 창업· 🏛️ 정부 연계 액셀러레이팅 : 2022년부터 매해 평균 3개 용역 실행알파브라더스는 초기기업을 대상으로 투자하는 액셀러레이터이며, 그 중에서도 단순 자금지원에서 그치지 않고 실무인력까지 지원하는 ACTIVE 액셀러레이터입니다 🚀● 독립레이블을 양성하는 창업지원 그룹 ABCDE 본부알파브라더스의 창업지원 그룹은 유망기업에게 자금투자와 실무지원을 제공하며, 실무분야 별로 ABCDE 5개 본부로 구성되어 있습니다.창업지원 그룹 ABCDE본부 지원을 통해 성공적으로 자립하는 기업은 독립레이블이라 불립니다.● 창업지원 그룹 ABCDE 본부는 어떤 업무를 지원하나요?· ADVISOR 본부 - [정부지원금부터 민간투자까지 자금조달 러닝메이트] : 알파브라더스 어드바이저 본부는 초기에 필요한 자금 확보 뿐만 아니라 기업 생애주기에 맞는 자금조달 컨설팅을 제공합니다.· BRAND 본부 - [제품과 서비스의 기본! 브랜드 설계와 작업까지] : 알파브라더스 브랜드 본부는 로고, 패키지, 상세페이지, UXUI, 사진/영상 촬영 등 토탈 브랜딩 서비스를 지원합니다.· CREATIVE 본부 - [숫자와 데이터로 매출을 일으키는 마케팅] : 알파브라더스 크리에이티브 본부는 고객 행동 데이터 분석을 통해 더 효과적으로 매출 증대를 이끌어내는 마케팅 전략 구축 및 실행을 지원합니다.· DATA & DEV  본부 - [비즈니스 모델 검증과 시장에 필요한 서비스 개발] : 알파브라더스 데이터&개발 본부는 MVP 테스트를 통해 초기 비즈니스 모델의 시장성, 사용성, 기술성 검증을 진행하고 잠재 고객 데이터를 기반으로 시장에 필요한 웹과 앱개발을 지원합니다.· EXPERT 본부 - [회사 경영관련 지원과 컨설팅 제공] : 알파브라더스 엑스퍼트 본부는 11명의 사내 노무사, 세무/회계사, 변호/변리사, 경영지도사 전문가의 지속적인 컨설팅과 실무를 지원합니다.● 우리에 대해 더 알고 싶은 것이 있으시다면?홈페이지 접속!👉https://www.alphabrothers.co.kr/● 채용 배경알파브라더스는 분야별 전문성을 보유한 90명의 사내 인력을 보유한 액셀러레이터 그룹입니다.A/B/C/D/E 5개의 그룹은 사업기획,디자인,마케팅,시장성 검증,개발, 인사/재무/법률의 분야로 초기 창업이 필요한 모든 분야를 다 갖춰 진정한 All-in-one 서비스를 제공하고 있습니다.스타트업이 실패하는 이유, 압도적 1위는 ‘시장 수요가 없음(No Market Needs)’ 시장성 검증을 전문으로 하는 데이터팀은 사업 아이템의 가설을 검증하고, 데이터 기반의 insight를 같이 도출할 수 있는 컨설턴트를 찾고 있습니다.● 팀 소개\u200b데이터전략팀은 데이터를 기반으로 더 좋은 의사결정을 내릴 수 있는 환경을 만듭니다.우리와 함께 성장할 좋은 동료를 찾습니다. 제품 기획과 문제 해결에 관심이 많은 분이 저희와 함께 동반 성장할 수 있기를 희망합니다.● 알파브라더스 'UX컨설턴트'란?알파브라더스의 'UX컨설턴트'는 시장검증, UX리서치가 필요한 스타트업을 위한 테스트를 설계하고, 데이터 기반 전략을 제안하는 일을 해요.● 알파브라더스의 시장(고객) 검증· 시장성 테스트 : 비즈니스의 시장성을 알아보고, 이를 고도화 하기 위한 정량/정성 데이터를 수집 및 분석합니다.· 사용성 테스트 : SW제품의 사용성을 개선하고, 비즈니스를 개선하기 위한 정량 데이터를 수집 및 분석합니다.· FGI / IDI : 주요 핵심 고객을 대상으로 PainPoint, 개선 의견, 아이디어 등 정성 데이터를 수집 및 분석합니다.● 주요 업무데이터기획팀의 업무는 다음과 같아요. : )· 담당 기업의 비즈니스와 제품을 이해하고, 적절한 테스트를 제안해요.· 담당 기업에 대한 이해를 바탕으로 필요한 리서치를 설계하고 운영해요.· '시장성 테스트'를 위한 설무조사를 설계하고, 조사결과 데이터 분석을 통해 전략을 제안해요.· 'FGI/IDI'를 위한 인터뷰 질문지를 기획하고, 인터뷰 결과 데이터 분석을 통해 전략을 제안해요.· 테스트를 통해 얻은 인사이트를 바탕으로 테스트 방법론을 고도화해요.· 디자이너, PM(Project Manager)과 협업을 통해 완성도 높은 결과물을 만들어요.● 자격 요건우리는 아래 자격들을 갖춘 지원자를 원해요.[필수] 마인드셋· 고객지향: 업무의 0순위는 클라이언트의 만족도입니다.· 마감기한: 마감기한을 기준으로 일간, 주간, 월간 태스크를 주도적으로 관리합니다.· 책임감: 본인의 업무는 본인 스스로 해결하고자 합니다.[필수] 스킬셋· 테스트를 통해 인사이트를 도출하고, 전략을 수립할 수 있어야해요.· 설문조사 플랫폼(구글폼, Walla, 오픈서베이 등)을 직접 활용해 본 경험이 필요해요.· 테스트 운영을 위해 PM, 디자이너와 원활하게 협업할 수 있어야해요.· MS오피스(PPT,Excel), 한글의 기본적인 기능을 활용할 수 있어야해요.[우대] 스킬셋· 리서치 프로젝트의 모든 프로세스를 주도적으로 수행해보신 분이면 좋아요.· 프로덕트 매니저 경험, 플랫폼 운영 경험이 있으면 좋아요.· 정량, 정성 데이터를 분석해본 경험이 있으면 좋아요.· UT, FGI, IDI를 주도적으로 수행해보신 분이면 좋아요.· 비즈니스 이론, 사업개발에 대한 이해가 높으신 분이면 좋아요.· UX/UI 디자인 경험이 있으신 분이면 좋아요.· Figma를 능숙하게 활용할 수 있는 분이면 좋아요.● 조직문화와 인재상을 위한 맞춤 복지 혜택알파브라더스는 구성원들이 끊임없이 성장하고, 도전에서 배우고, 주도적으로 성과를 창출할 수 있는 조직문화를 만들기 위해 오늘도 고민합니다.1️⃣ 회사의 성장과 개인의 성장을 동반한다. 우리는 [성장 지향형 인재]입니다.📢 성장 지향적 인재를 위한 맞춤 복지제도를 소개합니다.· 신규입사자를 위한 일학습병행 프로그램· 주니어를 위한 스터디룸 운영· 시니어를 위한 외부 전문가 1:1 멘토링· 자격증 취득 비용 지원· 1,500권 이상의 사내 도서관 운영· 외부기관 연계 교육 프로그램 제공2️⃣ 실패는 없다, 레슨런만 있을 뿐. 우리는 [도전 지향형 인재]입니다.📢 도전 지향적 인재를 위한 맞춤 복지제도를 소개합니다.· 상시 랩업을 위한 주니어-시니어 면담· 월간 랩업을 위한 시니어 세미나· 분기/반기 랩업을 위한 팀별 워크숍· 사내벤처 프로그램 운영· 사이드 프로젝트 지원· 대표님과 1:1 커피챗3️⃣ OUTPUT = Performance x Time. 우리는 [성과 지향형 인재] 입니다.📢 성과 지향적 인재를 위한 맞춤 복지제도를 소개합니다.· 원하는 시간에 출근하자!· 원하는 시간대에 일하자!· 원하는 곳에서 근무하자!· 일과 휴가를 동시에, 워케이션 지원· 최신 장비 및 툴 지원· 집중을 위해 스마트 워크부스 지원● 채용 과정📥[ 첫번째, 입사 지원 ]· 아래 지원하기 버튼을 통해 지원서 작성 (소요시간 3분 미만)📑[ 두번째, 서류 전형 ]· 상시채용으로 진행되며, 이력서를 검토하는 대로 합격, 불합격 상관 없이 모든 지원자 분께 서류전형 결과를 발표합니다.· 이력서(필수), 자기소개서, 포트폴리오(선택) 제출· 자기소개서 또는 포트폴리오 작성 시, 포지션에 지원하신 계기, 본인 삶에 있어 문제를 발견하게 된 계기와 이를 해결한 과정을 함께 작성해주시면 지원자님을 이해하는데 더욱 도움이 됩니다.💻[ 세번째, 과제 및 면접 전형 ]  - (약 30분 ~ 1시간 이내)· (과제 제출이 필요할 경우) 면접 전형 전까지 메일로 회신해주시면 됩니다.· 지원자분과 적합도를 알아보기 위한 인터뷰 · 이력서, 자기소개서, 포트폴리오를 중심으로 이야기 하되, 본인의 핵심 스킬셋이 무엇인지 왜 그렇게 생각하는지에 대해 여러 경험을 함께 소통하는 자리입니다. 📄[네번째, 서류 검토]· 면접 전형 합격자에 한하여 개별로 구비서류를 메일로 요청드립니다.· 메일을 받으신 날로부터 3일 이내 회신해주셔야 합니다.· 제출한 구비서류 중 허위 사실 ...
#   'job_industry': '컨설팅, 개발, 브랜딩, 디자인/컨설팅, 광고대행, 서비스/기획, #미디어#기획자#마케팅, 기획자, 사업기획',
#   'date_start': '2024-08-07',
#   'date_end': None},
#  {'company_id': '95952',
#   'company_name': '주식회사 알파브라더스',
#   'description': '스타트업 전문 엑셀러레이터입니다.',
#   'job_id': '150848',
#   'job_title': '[알파브라더스] 스타트업 컨설턴트 (신입)',
#   'job_career': ['신입, 경력'],
#   'timestamp': '2024-08-07_02:43:02',
#   'crawl_domain': 'www.rocketpunch.com',
#   'job_task': "데이터전략팀의 업무는 다음과 같아요. : )📋 시장 검증① 기업의 제품 및 서비스 개발 단계, 사업 분야와 규모 등에 따라 적합한 테스트를 제안하고 설계 및 기획해요.· '시장성 테스트'를 위한 가설수립 및 MVP를 기획하고, 정량적 데이터 분석을 통해 시장성을 검증하고 전략을 제안해요.② '사용성 테스트'를 위한 설문조사를 설계하고, 조사결과 데이터 분석과 개선 의견을 통해 개선 전략을 제안해요.③ 'FGI/IDI'를 위한 인터뷰 질문지를 기획하고, 인터뷰 데이터 분석 결과와 정성적 의견을 결합해 개발 및 개선 전략을 제시해요.· 디자이너, PM(ProjectManager)과 협업을 통해 완성도 높은 결과물을 고객에게 제공해요.· 테스트를 통해 얻은 인사이트를 바탕으로 테스트 방법론을 고도화해요.📊 기업 컨설팅 및 투자유치① 담당 기업의 비즈니스와 제품(혹은 서비스)을 이해하고, 사업계획서 및 비즈니스 모델 등을 통해 기업을 진단해요.② 투자유치와 정부지원사업 선정을 위해 기업에게 맞는 사업계획서와 IR Deck을 제작하고 컨설팅해요.· 정부지원사업 선정을 위해 P-S-S-T 형식의 사업계획서를 제작하고 컨설팅해요.· 투자유치를 위해 투자사 심사 기준에 맞추어 IR Deck을 제작하고 IR Pitching을 멘토링해요.③ 투자가 이루어질 수 있도록 투자자들을 초청한 IR 및 데모데이를 기획, 운영하고 기업과의 네트워킹을 관리해요.🪄 스타트업 프로그램 운영① 스타트업을 지원하고 컨설팅하는 프로그램 용역 사업을 수주하고 수행해요.· 용역 수주를 위한 제안서를 작성하고 추진을 위한 업무 정의와 일정을 계획해요.· 다수의 기업에 대해 원활한 소통과 효율적인 운영을 통해 담당 고객들을 관리해요.",
#   'job_specialties': '데이터, 데이터 시각화, 데이터 분석',
# ...
#   'job_industry': 'AI, IT/인공지능, 인공지능, 머신러닝, 딥러닝, SW/AI, 솔루션,인공지능,데이터마이닝, 모바일서비스,웹서비스,소프트웨어,데이터,모바일,빅데이터,인공지능,데이터분석,데이터마이닝,서버,, Python, 인공지능솔루션, 소프트웨어(이미지처리,동영상처리,딥러닝,AI),',
#   'date_start': '2024-08-07',
#   'date_end': None},
#  {'company_id': '107422',
#   'company_name': '(주)에이펙스 이에스씨',
#   'description': 'Zecure  보안관제 시스템 / 수사지원 시스템 등을 개발 및 제공하고 있습니다.',
#   'job_id': '150591',
#   'job_title': 'S/W(소프트웨어) 개발',
#   'job_career': ['경력'],
#   'timestamp': '2024-08-07_02:43:32',
#   'crawl_domain': 'www.rocketpunch.com',
#   'job_task': '1. 직무 설명- 멀티플랫폼 어플리케이션 및 홈페이지 개발- 복잡한 워크플로우 및 마이크로서비스 아키텍처 개발- 생성형 AI 활용 가능한 소프트웨어 엔지니어2. 주요 업무- 웹 어플리케이션 및 서버 개발 (Javascript/Typescript, Next.js, Node.js)- 멀티플랫폼 환경 개발 (Javascript/Typescript, React Native)- 마이크로서비스 아키텍처 개발 (Golang, Python)- 시스템 스크립트 및 AI 파이프라인 개발 (Golang, Python)- AWS/Docker 기반 개발 환경에서의 작업- 생성형 AI 사용 및 프롬프트 엔지니어링에 대한 이해3. 자격 요건- 경력 : 4년 ~ 8년 이하- Javascript/Python 개발 언어 사용- RDB/NoSQL/VectorDB에 대한 이해- 네트워크 통신에 대한 이해- 아키텍처 설계 경험- 멀티플랫폼 개발 경험',
#   'job_specialties': 'JavaScript, Node.js, 프론트엔드 개발, 백엔드 개발, 풀스택 개발, Go, PostgreSQL, GCP, Firebase, React, TypeScript, React Native, Python, AWS, Docker',
#   'job_detail': '1. 우대사항- 컴퓨터 공학 전공 또는 유사 학과 졸업- T자형 인재로서의 기술적 깊이와 폭 넓은 경험- 프롬프트 엔지니어링에 대한 이해와 관심- AI 개발에 대한 관심과 경험2. 필요 역량- 문제 해결 능력 및 엔지니어링 마인드- 코드 설계 및 개발에 대한 철학적 접근- 긍정적 마인드 및 효과적인 커뮤니케이션 능력- 새로운 언어 및 기술에 대한 수용- 자신의 코드에 대한 자부심 및 책임감3. 업무 환경- Docker를 기반으로 하는 개발 환경- Slack과 GitHub를 통한 협업- 스프린트 방식의 개발 프로세스- 사무실에 음악 재생등 자유로운 근무 환경- 독립적 또는 소규모 팀에서의 작업4. 복리후생- 점심 식대 및 카페 음료 전액 지원!- 업무 관련 원하는 교육 있을 시 교육(온라인/오프라인) 및 도서 구매 지원!    (직원이 성장하면 회사도 성장한다!)- 맥북 프로 또는 필요한 개발장비 최신형 지원! - 눈치 보지 말고 자유로운 연차와 연말 휴가- 업무 Tool을 이용한 유연한 근무! (Slack, Notion)- 휴식은 자유롭게 (수면, 보드게임 등)',
#   'job_industry': '소프트웨어개발/서비스, 제조업/서비스, 정보통신공사',
#   'date_start': '2024-08-07',
#   'date_end': None},
#  {'company_id': '130011',
#   'company_name': '캥스터즈',
#   'description': '사랑하는 사람을 위한 에이블테크 기업',
#   'job_id': '150575',
#   'job_title': '사업기획/개발',
#   'job_career': ['경력'],
#   'timestamp': '2024-08-07_02:43:32',
#   'crawl_domain': 'www.rocketpunch.com',
#   'job_task': '[회사 소개]캥스터즈는 사랑하는 사람들을 위한 기술로, 신체적 약자들이 겪는 불편함을 해결하는 에이블 테크(able-tech) 기업입니다. 우리는 초기 장애인구성원 가족을 가진 청년들이 모여 만들어진 팀으로, 휠체어 사용자들을 위한 종합 피트니스 솔루션 \'휠리엑스\'를 개발하였고 2022년 1월에 출시했습니다. 이는 전세계의 장애인시설, 복지시설, 특수학교, 병원, 피트니스 시설 등에서 보급되고 있습니다.2022년 하반기부터는 전 세계 1억명의 휠체어 사용 인구에게 우리의 기술과 서비스를 제공하기 위하여 미국과 유럽 시장으로 진출을 시작하였으며, 미국에 현지 법인을 설립하여 글로벌 기업으로 성장하기 위한 준비를 마쳤습니다.최근 미국의 권위있는 시상식인 "에디슨 어워즈2023"에서 "인간중심적 디자인 금상"과  2024 CES 혁신상 등을 수상하며 혁신적인 기술과 디자인이 세계적으로 인정받고 있음을 확인할 수 있었습니다.2023년 하반기에는 자체개발한 휠체어 전용센서가 개발되었고, 이를통하여 휠체어 레이싱게임과 다양한 게임 등을 출시할 예정이며 앞으로 장애인 e-sports 분야로 사업 영역을 확장하고자 합니다.캥스터즈는 현재까지 15억원 이상의 누적 투자를 유치하였고, 추가 20억을 모집중입니다. 국내외 에이블테크 업계에서 주목받으며 성장하고 있는 스타트업 중 하나입니다. 우리의 비전과 컬쳐핏에 공감하고, 목표를 이루고자 하는 열정을 가진 인재들과 함께 성장하고 싶습니다.저희는 앞으로도 다양한 배경과 경험을 가진 인재들을 모셔서 서로 배울 수 있는 환경을 조성하려 합니다. 함께 더 큰 성과를 이루고, 밝은 미래를 같이 만들어 나가는 데 함께 하고싶으신 분들의 지원을 기다립니다.감사합니다.- 사업 전략 기획, 차별적 경쟁 우위 요소 발굴 및 사업화 실행# Business Developer  (사업개발 담당)▣ 이런일을 합니다 ▣- 사업현황을 분석하고 이에 따른 프로덕트 로드맵과 전략을 고민합니다.- 프로덕트(보조기기) 정부지원품목 등록 절차를 알아보고 등록하는 PM 역할을 합니다.- 다양한 기업 및 잠재적 사업 파트너에게 제휴 및 파트너쉽을 제안합니다.- 사업의 전반적인 문제점과 해결책을 지속적으로 도출해내고 방향성을 팀간 논의하고 소통합니다.',
#   'job_specialties': '사업 기획, 전략 기획, 비즈니스분석, 신사업 기회 및 신사업 개발, 사업기획수립, 사업전략기획, 사업개발',
#   'job_detail': '▶ 자격요건- 사업 개발/사업기획/전략기획 업무 경력 3년 이상▶ 이런분을 찾습니다- 자기주도적으로 새로움을 탐구하고 거침없이 도전을 하실 수 있는 분- 논리적 사고를 기반으로 문제해결이 가능한 분- 고객지향적인 마인드와 긍정적이고 유연한 태도를 보유한 분- 정직하고 성실하신 분▶ 이런 분이면 더 좋아요- 사회복지/피트니스/의료 산업에 대한 경험- 장애인 관련 경험 및 배경- 스타트업 근무 경험♥ 혜택 및 복지 ♥- 신규입사자 멘토제도- 중식비 지원- 자유로운 분위기- 자유로운 연차사용- 명절 선물지급- 연말 1주일 안식주 제도♥ 캥스터즈는 이렇게 믿어요 ♥도전 정신은 성장을 불러오고, 성장은 결국 성과를 가져옵니다. 무엇이든 혼자는 어렵지만 함께 라면 가능합니다. 캥스터즈는 함께 도전하며 상생하고, 성장하시길 희망하시는 분께 열려있습니다.     개인의 성장과 회사의 성장은 동일하게 중요하다고 믿습니다.   한 팀으로 일하며 서로가 빛날 수 있게 멋진 문화를 같이 만들어 나가실 분들을 초대합니다.  ★ 참고해주세요 ★1. 채용절차 : 서류전형→화상인터뷰 →대면 면접 → 처우 협의 → 최종 합격 및 입사. 캥스터즈는 최대한 빠른 의사결정을 위해 통상적으로 서류전형에서 부터 최대 2주일 이내로 결과발표를 합니다.2. 추가서류 : 추가적인 포트폴리오 및 관련 서류는 자유 형식으로 제출해 주세요.',
#   'job_industry': '헬스케어, 피트니스, 제조업/ICT, 장애인, 휠체어, 에이블테크',
#   'date_start': '2024-08-07',
#   'date_end': None},
#  {'company_id': '198485',
#   'company_name': '게놈파이',
#   'description': 'AI기반 Web3 Genome DID 플랫폼',
#   'job_id': '150428',
#   'job_title': 'UI/UX 디자이너(리드)',
#   'job_career': ['경력'],
#   'timestamp': '2024-08-07_02:43:32',
#   'crawl_domain': 'www.rocketpunch.com',
#   'job_task': 'GenomeFi는 AI 기반 Web3 Genome DID 플랫폼을 통해 게놈, 유전체학, 바이오, 의료, 과학 등의 콘텐츠를 대중화하고 혁신적으로 성장하는 것을 목표로 합니다.우리는 글로벌 메디컬 센터 및 바이오 전문 기업과 함께 세계 최고 수준의 게놈 분석 기술력을 보유하고 있습니다. 개인의 신체적 특성이나 질병을 예측하여 게놈 의료 솔루션 서비스를 제공하며, 액체생검 및 멀티오믹스 기술을 통해 암 및 다른 질병의 조기 진단과 맞춤 치료 서비스를 제공합니다.두바이를 기반으로 실증 비즈니스를 활성화하고 있으며, 웹2 기업과의 협력을 통해 웹2와 웹3 시대의 사업 확장을 추진하고 있습니다. 우리는 실증 비즈니스를 하는 웹2 기업들과의 협력을 중심으로 웹2와 웹3까지의 사업 확장을 통해 지속적인 성장을 이끌어 나가고자 합니다.',
#   'job_specialties': 'UI/UX 디자인, Zeplin, Figma',
#   'job_detail': '[담당업무]• 제품의 UI 디자인에 대한 최고 책임과 권한을 가지고, 주도적으로 서비스의 UI를 디자인합니다.• 서비스 브랜딩, UX 설계 등 고객에게 가치를 전달하는 모든 설계 과정에 참여합니다.[자격요건]• 3년차 이상의 UI/UX 디자인 경험• Sketch, Figma, Zepline 등 디자인 도구에 능숙한 분• 사용성과 심미성에 대한 높은 기준을 가지고 있으며, 이를 실제 디자인으로 구현할 수 있는 분• 서비스에 적합한 디자인 철학 및 원칙을 수립하고 이를 바탕으로 구조화된 UI, 일관된 UX를 설계할 수 있는 분• 디자인 의사결정에 대해 논리적으로 당위성을 설명할 수 있는 분[우대사항]• 디자인 파트 리더로서 팀원들의 역량을 이끌어내고 성장시킨 경험이 있는 분• 디자인 철학, 원칙 등을 기반으로 디자인 시스템을 구축한 경험이 있는 분• HTML/CSS, JavaScript 등의 웹 기술에 대한 높은 이해도를 갖춘 분• 블록체인 및 AI 등 새로운 기술혁신에 대한 관심과 호기심• 암호화폐 투자경험 및 시장에 대한 이해[혜택 및 복지]ㆍ 팀원들의 기여에 대해서는 확실하게 보상합니다   - 우수사원을 선정하여 반기마다 성과급 지급ㆍ 팀원들이 최고의 퍼포먼스를 낼 수 있는 환경을 조성합니다.   - 필요한 장비 지원   - 분기별 팀 회식비 지원   - 자율복장   - 수면실 제공   - 유연한 출퇴근 제도 (9시 ~ 12시 출근)   - 점심 식대 제공 & 여유로운 점심시간ㆍ 여러분의 성장이 회사의 성장이라 생각합니다   - 도서구입비 지원   - 근무시간 중 외부행사 및 교육 참여 지원ㆍ 그 외 당연하고 기본적인 것들   - 4대 보험   - 경조사 및 명절 선물 지원   - 생일자 선물 지원ㆍ우리만 제공할 수 있는  - 유전자 검사 1회 제공(수습 종료 시)',
#   'job_industry': 'SW',
#   'date_start': '2024-08-07',
#   'date_end': None},
#  {'company_id': '198485',
#   'company_name': '게놈파이',
#   'description': 'AI기반 Web3 Genome DID 플랫폼',
#   'job_id': '150512',
#   'job_title': 'App/Web 서비스 기획자',
#   'job_career': ['경력'],
#   'timestamp': '2024-08-07_02:43:32',
#   'crawl_domain': 'www.rocketpunch.com',
#   'job_task': '',
#   'job_specialties': 'powerpoint, Figma, Exel, MS Word',
#   'job_detail': '',
#   'job_industry': 'SW',
#   'date_start': '2024-08-07',
#   'date_end': None},
#  {'company_id': '93877',
#   'company_name': '쉐어밸류',
#   'description': '기술평가 벤처기업 &  중소벤처기업부 초기관광벤처 & 2022 한국관광공사 여행업디지털전환 공급기업, 2022 관광기업 혁신바우처 사업 제공기업',
#   'job_id': '149473',
#   'job_title': '웹서비스 풀스택 경력 개발자',
#   'job_career': ['4,500 - 7,000만원', '0.5% - 1.0%', '경력'],
#   'timestamp': '2024-08-07_02:43:32',
#   'crawl_domain': 'www.rocketpunch.com',
#   'job_task': '여행산업 내 전문 SaaS 형 부킹엔진을 제공하고 있습니다.판매 단계가 가장 복잡한 항공 서비스의 자동화 모듈을 개발하여  다양한 고객과 제휴사에 제공하고 있으며여행상품을 통합 검색 및 예약하여 다이나믹한 실시간 예약, 결제 서비스를 R&D 하고 있습니다.  항공 예약 시스템 Back-End여행상품 예약 시스템 Back-End',
#   'job_specialties': 'JavaScript, TypeScript, Node.js, Vue.js, MySQL, GitHub, Amazon Web Services',
#   'job_detail': '자사는 업계 최초의 다국어 SaaS형 항공 부킹엔진 솔루션을 개발, 운영하고 있습니다.그동안 GDS연동, 저비용항공사 API 연동, 호텔 API 연동, 투어 서비스 API 연동 등  다양한 여행 서비스를 제공하고 있으며 해외 로컬 페이 PG를 연동하여 국 내외 고객 서비스에 제공하고 있습니다. 담당업무- 항공 멀티 GDS 예약 서비스 & 백오피스- 여행상품 예약 서비스 & 백오피스- 호텔 예약 서비스 & 백오피스- DIY ( DO IT YOURSELF ) 예약 서비스 & 백오피스자격요건- JavaScript, TypeScript 중 1개 이상 언어 숙련자- Vue.js 를 사용해 보신 분- Node.js 를 사용해 보신 분- GitHub 을 사용해 보신 분우대사항- AWS 나 클라우드 서비스로 서비스 구축 경험 있으신 분',
#   'job_industry': '소프트웨어개발/서비스, 여행, 관광산업, 관광벤처기업, 한국관광공사여행업디지털전환사업공급기업, 한국관광공사관광기업혁신바우처사업공급기업',
#   'date_start': '2024-08-07',
#   'date_end': None},
#  {'company_id': '161830',
#   'company_name': '피노키오랩',
#   'description': '피노키오랩의 AI는 진실을 볼 수 있는 세상을 만들기 위하여 노력합니다.',
#   'job_id': '146878',
#   'job_title': 'Vision AI 연구/개발 분야 (팀장/팀원)',
#   'job_career': ['4,500 - 10,000만원', '0.1% - 1.5%', '신입, 경력'],
#   'timestamp': '2024-08-07_02:43:32',
#   'crawl_domain': 'www.rocketpunch.com',
#   'job_task': '',
#   'job_specialties': 'Python, PyTorch, Deep learning, 인공지능, computer-vision, ML/AI, Computer Vision (컴퓨터비전)',
#   'job_detail': '자격요건• 전공: 공학계열 (컴퓨터공학 또는 수학 전공 등)• 학력: 대학원 석사 이상(팀장) / 대학교 학부 이상(팀원)• 경력: VISION AI 연구/개발 경력이 있는 분• Python 언어에 능숙하고, CNN, Visual Transformer(ViT) 구조의 모델을 만드는데 익숙한 분• 영어 논문 및 기술자료를 읽고 최신 기술 Trend를 follow-up 할 수 있는 분우대사항• 컴퓨터 비전 관련 학회에 제1저자 혹은 교신저자로 논문 게재 •  문제를 찾고 해결하는 과정에서 성취감을 느끼시는 분 • 다양한 영상 또는 이미지에 대하여 딥러닝을 활용한 연구 경력 • unsupervised 또는 self / semi / weakly supervised 딥러닝 모델 개발을 할 수 있는 분',
#   'job_industry': 'IT/서비스',
#   'date_start': '2024-08-07',
#   'date_end': None},
#  {'company_id': '200711',
#   'company_name': '휘게아',
#   'description': '신규 코스메틱 브랜드',
#   'job_id': '150454',
#   'job_title': '신규 코스메틱 브랜드 온라인 세일즈 MD 채용',
#   'job_career': ['인턴, 신입, 경력'],
#   'timestamp': '2024-08-07_02:43:32',
#   'crawl_domain': 'www.rocketpunch.com',
#   'job_task': '',
#   'job_specialties': '온라인커머스, MD, 온라인 MD, , 세일즈, 브랜드 세일즈, 온라인쇼핑몰MD, 상품관리, 온라인md, 커머스MD, 상품MD, 상품소싱, MD, 이커머스MD, 이커머스운영, eCommerce, 커머스 브랜드 MD, 이커머스, 구매/유통',
#   'job_detail': '담당업무-\t자사몰 및 외부몰 운영 및 CS관리-\t해외 크로스보더 온라인몰 개척-\t브랜드 운영 상품 관리 (상품등록, 출고 발주, 품절, 재고 등)-\t채널별 매출관리 프로모션 계획 수립 및 운영-\t온라인몰 컨텐츠 관리자격요건-\t이커머스 관련 경력 2년 이상 / 온라인MD 경력 보유 -\tCafe24 운영 관리 경험자-\t외부 제휴 채널 입점 및 판매 운영 경력 보유-\t재고 관리 및 포캐스팅 진행 가능자-\t커뮤니케이션 역량 우수한 분-\tExcel 사용 우수자우대사항-\t영어 외 외국어 가능자-\t뷰티 컨텐츠 기획 경험-\t브랜드에 대한 열정과 창의적인 아이디어를 소유한 사람-\tPhotoshop 가능한 자＜필수 제출 서류＞1. 포트폴리오 (경력 위주 기재)2. 이력서＜전형절차＞서류전형 ＞ 면접 ＞ 최종합격',
#   'job_industry': '화장품/유통, #화장품, 코스메틱',
#   'date_start': '2024-08-07',
#   'date_end': None},
#  {'company_id': '200711',
#   'company_name': '휘게아',
#   'description': '신규 코스메틱 브랜드',
#   'job_id': '150455',
#   'job_title': '신규 코스메틱 브랜드 웹디자이너 경력 채용',
#   'job_career': ['경력'],
#   'timestamp': '2024-08-07_02:43:32',
#   'crawl_domain': 'www.rocketpunch.com',
#   'job_task': '',
#   'job_specialties': '웹 디자인, Adobe Illustrator, Adobe Photoshop, 브랜드 디자인, 콘텐츠 디자인, 그래픽 디자인, 서비스 디자인, 모바일 디자인, 마케팅 디자인, 크리에이티브 디자인',
#   'job_detail': '',
#   'job_industry': '화장품/유통, #화장품, 코스메틱',
#   'date_start': '2024-08-07',
#   'date_end': None},
#  {'company_id': '200711',
#   'company_name': '휘게아',
#   'description': '신규 코스메틱 브랜드',
#   'job_id': '150456',
#   'job_title': '신규 코스매틱 브랜드 SNS&인플루언서 마케터 모집합니다.',
#   'job_career': ['인턴, 신입, 경력'],
#   'timestamp': '2024-08-07_02:43:32',
#   'crawl_domain': 'www.rocketpunch.com',
#   'job_task': '',
#   'job_specialties': '바이럴 마케팅, 콘텐츠 마케팅, 페이스북, 인스타그램, 디지털 마케팅, 온라인 마케팅, instagram, YouTube, Facebook, 모바일 광고, SNS, SNS 마케팅, 블로그, 온라인광고, 브랜드 마케팅, 소셜 마케팅, Online Marketing, Social Marketing , 광고',
#   'job_detail': '[주요업무]- SNS 피드 기획 및 운영- SNS 소재 제작- SNS 인사이트 분석 및 개선 방안 도출- 마이크로 인플루언서 리스트업 및 시딩- 인플루언서 PPL 제안 및 집행[자격요건]- 코스메틱 브랜드 경험자- SNS에 이해도 높으신 분- SNS 운영 경험자- Photoshop 사용 가능한 자- 인플루언서 마케팅 경험자[우대사항]- 영상 제작 가능한 자- 브랜드에 대한 열정과 창의적인 아이디어를 소유한 사람- 외국어 가능한 자(영어 or 중국어 or 일본어)- 개인 SNS 계정 운영자** 경력이 없으신 신입 분들도 모집합니다.단, 이 쪽 분야에 어느 정도 이해도가 있어야 하며 업무 진행하면서도 스터디를 하실 정도로 열정이 있으셔야 합니다.＜필수 제출 서류＞1. 포트폴리오 (경력 위주 기재)2. 이력서＜전형절차＞서류전형 ＞ 면접 ＞ 최종합격',
#   'job_industry': '화장품/유통, #화장품, 코스메틱',
#   'date_start': '2024-08-07',
#   'date_end': None},
#  {'company_id': '200304',
#   'company_name': '주식회사 두아즈',
#   'description': '산업플랫폼을 AI로 혁신합니다.',
#   'job_id': '150376',
#   'job_title': 'NLP, LLM 엔지니어 채용 공고',
#   'job_career': ['경력'],
#   'timestamp': '2024-08-07_02:43:32',
#   'crawl_domain': 'www.rocketpunch.com',
#   'job_task': '',
#   'job_specialties': 'LLM, NLP, 오픈소스, Python, Java, AWS, Azure, 엘라스틱서치',
#   'job_detail': '',
#   'job_industry': 'IT/개발',
#   'date_start': '2024-08-07',
#   'date_end': None},
#  {'company_id': '200304',
#   'company_name': '주식회사 두아즈',
#   'description': '산업플랫폼을 AI로 혁신합니다.',
#   'job_id': '150375',
#   'job_title': 'Fullstack 개발자 채용 공고',
#   'job_career': ['경력'],
#   'timestamp': '2024-08-07_02:43:32',
#   'crawl_domain': 'www.rocketpunch.com',
#   'job_task': '',
#   'job_specialties': '풀스택 개발, MERN stack, full-stack development, 챗봇, LLM, full stack, 대화형인공지능',
#   'job_detail': '',
#   'job_industry': 'IT/개발',
#   'date_start': '2024-08-07',
#   'date_end': None},
#  {'company_id': '181487',
#   'company_name': '바인드',
#   'description': '40대 남성 NO.1 패션 플랫폼',
#   'job_id': '139188',
#   'job_title': 'BO (Brand Owner)',
#   'job_career': ['경력'],
#   'timestamp': '2024-08-07_02:43:34',
#   'crawl_domain': 'www.rocketpunch.com',
#   'job_task': '[ 1. 애슬러 ]팀 BIND는 4050 남성을 위한 커머스 플랫폼 "애슬러(athler)"를 시작으로 지금껏 소외되어 왔던 4050 남성의 라이프스타일을 바꿉니다.온라인 세상의 4050 남성들은 그동안 많은 기업들이 도전했지만 설득에 실패한 시장입니다.그렇지만 우리는 이 시장에서 기회를 보았고, 이를 증명하고 있습니다.[ 2. 왜 4050 남성인가요? ]최근 “50대는 모바일 서비스를 잘 안 쓸 거야”라는 편견을 뒤엎는 서비스들이 등장했고, 빠르게 성장하고 있습니다. 그러나 대부분의 서비스가 여성만을 타겟하고 있어, 50대 남성들을 위한 모바일 서비스 영역은 비어있는 상황입니다.한 가정의 가장으로 책임을 다했던 한국의 50대 남성은, 은퇴를 기점으로 경제적 여유와 시간적 여유를 모두 가진 유일무이한 소비인구로 변모합니다. 서구권에서는 일과 여가를 균형 있게 즐기는 편이지만, 상대적으로 한국에서는 그렇게 살아온 사람들의 수가 현저히 적습니다. 자녀와 가정을 위한 소비에서 나를 위한 소비로 전환되는 시점이 45세라는 것이죠. 물론, 4050 남성이 가장 시간과 돈을 많이 쓰는 곳은 단연 패션 영역입니다.온라인 세상에서의 중년 남성 시장은 많은 기업들이 도전했지만, 포기한 영역입니다. 비즈니스가 동작하려면 시장의 시기와 팀의 실력이 맞물려야 하는데, 이제 4050 남성들도 온라인으로 전환되는 시기가 왔고, BIND는 이 시장의 가능성을 스스로 증명하고 있습니다.[3. 팀 BIND에서는 속도가 가장 중요합니다.]불확실한 상황에서도 빠르게 의사결정하는 것이 빠르고 많은 실험을 할 수 있는 공식이라고 믿습니다. 이런 상황에서 더 좋은 결정을 끌어내기 위해서는 건설적인 의견 대립이 필요합니다. 이때 사실에 근거한 의견을 가지고, 격렬하게 자신의 견해를 밝혀야 합니다. 그렇지만, 일단 결정이 내려지면 그 결정에 반대했더라도 전적으로 헌신할 수 있어야 합니다.2달 동안 세계 1,000여 개의 유니콘 기업들이 풀고 있는 문제들은 어떤 것들인지 모두 뜯어봤습니다. Top-down 관점으로 시장의 기회를 찾았고, 3주 만에 서비스 런칭, 이후 MoM 평균 50% 이상 속도로 거래액이 성장하는 놀라운 퍼포먼스를 내고 있습니다.성장하는 스타트업의 경험을 가진 사람은 극명한 소수입니다. 때문에 그 경험은 어떤 것보다 값지다고 생각합니다. 이 소중한 경험을 함께하실 분을 만나고 싶습니다. 지금의 애슬러, 오늘의 애슬러는 그 어떤 때보다 작은 어제 일 것 입니다. 언제 함께하느냐가 얻을 수 있는 경험의 범주를 의미합니다. 삶의 여러 가지 것들이 있지만 미래를 앞당기는 가치 있는 일을 위해 sweat을 쏟고 싶은 분을 찾습니다. 가슴 뛰는 생각을 시작한 오늘을 회상할 때 살아가는 방식을 바꾼 순간으로 기억될 것 입니다.내가 가진 것으로 의미있는 임팩트를 만드는 여정이 매력적으로 느껴지신다면,영리한 동료들과 챌린지십한 목표에 도전하는 일에 가슴이 뛰신다면,지금 애슬러로 합류하세요!',
#   'job_specialties': 'B2B/B2C영업, 온라인커머스, MD, 온라인 MD, ',
#   'job_detail': '[ 4. 합류하시면 이런 일을 함께 합니다 ]4-50대 남성에게 매력적으로 보일 신규 브랜드들을 입점시키고 관리하는 전략을 수립하고 엑션합니다.서비스의 거래액과 매출을 극대화 시키기 위한 세부 전략을 도출합니다.[영업]브랜드를 애슬러에 입점하도록 소싱하고 제휴 전략을 세웁니다.Seller Retention에 대해 고민하고 셀러의 성공을 위한 전략을 수립하고 실행합니다.상품 수급과 기획 상품에 대해 논의하여 브랜드와 애슬러가 함께 성장할 수 있도록 합니다.[운영]전사 프로모션을 담당하며 주도적으로 유관 부서와 커뮤니케이션 합니다.월/분기 별 프로모션 계획을 수립하고 운영 관련 세부사항을 관리합니다.거래액/객단가 상승을 위한 다양한 이벤트와 프로모션을 기획하고 운영합니다.[ 5. 이런 분을 모시고 싶어요 ]커머스 비즈니스의 성공 방정식에서 MD의 역할은 매우 중요한 요소라고 생각합니다. 특히나, 온라인 서비스에 익숙하지 않은 이용자들에게 친화적으로 다가가기 위해서는 더더욱 섬세하게 고객을 파악하고, 그에 맞는 제품을 소싱해야 합니다. 4050 남성의 고객 특성을 알아가고, 그들이 좋아하는 상품이 무엇일지 고민하는 것에 진심인 분을 모시고 싶습니다.그 외에 아래의 성향/경험/역량을 갖춘 분이면 더 좋을 것 같습니다.- 이커머스/ 버티컬 플랫폼/ 패션 산업에 관심이 있는 분- 플랫폼사의 MD 커리어에 열정이 있는 분- 유관 경력이 1년 이상이신 분[ 6. 이런 점이 있다면 더 좋아요 ]우리의 비즈니스는 속도가 중요합니다. 불확실한 상황에서 불완전하더라도 빠르게 의사 결정해야만 합니다. 더 좋은 결정을 끌어내기 위해 건설적인 의견 대립이 필요합니다. 이때 사실에 근거한 의견을 가지고, 격렬하게 자신의 견해를 밝혀야 합니다. 일단 결정이 내려지면 그 결정에 반대했더라도 전적으로 헌신할 수 있는 분이면 좋겠습니다.그 외에 아래의 성향/경험/역량을 갖춘 분이면 더 좋을 것 같습니다.- 온, 오프라인을 넘나드는 다이나믹한 환경에서 재미를 찾을 수 있으신 분- 커뮤니케이션 스킬 및\xa0시장 분석, 서비스 개선 인사이트가 있으신 분- 서비스 성장곡선을 본인의 성장곡선과 align하는 것에 짜릿함을 느끼시는 분[ 7. 근무 환경 및 복지 ]- 정식 크루 합류 시 경쟁력 있는 성과급 제도를 제공합니다. 이후로도 계속해서 보상 체계 유지를 위하여 6개월 단위 연봉 협상을 진행합니다. (팀의 성장에 크게 기여해주시는 크루에게 경제적 이익을 극대화 할 방안을 적극적으로 고민 할 것입니다)- 업무에 필요한 최신형 노트북, 모니터, 전산장비 등을 제공합니다.[ 8. 지원 및 절차 ]- luke@bindcorporation.com 메일로 간단한 이력서 및 소개를 보내주시면, 확인 후 문자로 인터뷰 안내를 드리게 됩니다. (참고하면 좋을 포폴, 블로그, 노션 등이 있으시면 자유롭게 첨부해주세요!)- 지원에 대한 확신이 서지 않고 더 자세한 이야기를 직접 들어봐야 결정을 할 수 있겠다 싶으신 분도 마찬가지로 luke@bindcorporation.com 로 연락주시면, 대표와 1:1 커피챗 자리를 마련하도록 하겠습니다.- 결과에 관계 없이 모든 지원자 분들께 1주 내외로 개별 연락드립니다.- 인터뷰는 커피챗 형태로 진행되게 되며, 최대 2차까지 진행될 수 있습니다.- 오피스 위치 : 서울특별시 마포구 마포대로 122, 프론트원',
#   'job_industry': '패션, 전자상거래, e-커머스, 이커머스/패션뷰티, 패션&라이프스타일, 패션플랫폼, 패션/인터넷쇼핑몰',
#   'date_start': '2024-08-07',
#   'date_end': None}]

# %%
test = '상시채용'
pattern = re.compile('[ㄱ-ㅎ가-힣]+')
if pattern.search(test):
    print('true')
# Out:
# true

# %%
rocketpunch_list = rocketpunch_crawler()

# %%
rocketpunch_list.__len__()
# Out:
# 148

# %%
import pandas as pd

# %%
df=pd.DataFrame(rocketpunch_list)

# %%
df.head(3)
# Out:
#   company_id company_name                 description  \
# 0       6532       마카롱팩토리  대한민국 1등 운전자 차량관리 필수앱 - 마이클
# 1       6311           다날         데이터베이스 및 온라인정보 제공업체
# 2     160928       에이치디메디             쉽고 편한 의료 서비스 i약
#
#                                             job_list  job_id  \
# 0  [{'company_id': '6532', 'company_name': '마카롱팩토...  151375
# 1  [{'company_id': '6311', 'company_name': '다날', ...  151201
# 2  [{'company_id': '160928', 'company_name': '에이치...  151453
#
#                           job_title                            job_info  \
# 0                  프론트엔드 개발 (5년 이상)                                [경력]
# 1            다날 테스트 자동화 개발 담당 경력 채용                                [경력]
# 2  i약 SaaS 서버 엔지니어(Java/SpringBoot)  [5,000 - 8,000만원, 0.5% - 3.0%, 경력]
#
#    job_date
# 0  09/30 마감
# 1  09/29 마감
# 2  08/29 마감

# %%
# 유료광고와 겹치는지 확인용 -> 유료공고와 겹침으로 유료쪽 광고 크롤링x
df.loc[df['company_name'].isin(['제이제이앤컴퍼니스'])]
# Out:
#    company_id company_name                    description  \
# 64     203363    제이제이앤컴퍼니스  인공지능과 공정제어 기반의 해양 엔지니어링 전문 기업
#
#                                              job_list  job_id  \
# 64  [{'company_id': '203363', 'company_name': '제이제...  151418
#
#              job_title job_info  job_date
# 64  백엔드 엔지니어 정규직 채용 공고     [경력]  08/23 마감

# %%
# 공고 크롤링
def parse_job_page():
    job_url = 'https://www.rocketpunch.com/jobs/151267'
    session = requests.Session()
    #print(data['job_id'])
    #res = session.get(job_url.format(data['job_id']), headers=headers)
    res = session.get(job_url, headers=headers)
    soup = BS(res.text, 'html.parser')
    
    div = soup.find('div', class_='duty break')
    #print(div)
    if div:
      span_hidden = div.find('span', class_='hide full-text')
      span_short = div.find('span', class_='short-text') if not span_hidden else None
      span = span_hidden.text if span_hidden else span_short
    print(span)
    
    job_date = soup.find('div', class_='job-dates')
    date_span = job_date.find_all('span')
    for i, date in enumerate(date_span):
      text = date.get_text(strip=True)
      date_only = text.split()[0]
      
      year = datetime.datetime.now().year
      mon = date_only.split('/')[0]
      day = date_only.split('/')[1]
      
      if i == 0 :
        date_start = datetime.datetime.strptime(f'{year}-{mon}-{day}', '%Y-%m-%d').date()
        print(date_start)
      else:
        date_end = datetime.datetime.strptime(f'{year}-{mon}-{day}', '%Y-%m-%d').date()
        print(date_end)

# %%
parse_job_page()
# Out:
# 슬로그업의 개발 문화를 먼저 소개할게요.슬로거들은 ‘불확실한 가설과 위험은 마지막보다 초기에 대응한다’는 마음으로PM, 디자이너, 개발자 등 모든 구성원이 팀 단위로 프로덕트를 정의하고 설계해나가요.이중 백엔드 프로덕트 엔지니어는 다음과 같은 업무를 담당해요.- 프로젝트 목표와 기능별 목적에 관해 이해- 아이디어 단계부터 참여해 효율성 높고 창의적인 방향성 도출- 최소의 개발로 최대한 효과를 낼 수 있는 구조 고민- PM, PD와 협업해 단순 기능구현이 아닌 ‘문제 해결’을 목적으로 개발- 가설검증 단계에서 매우 빠른 속도로 프로토타입 구축- 기초검증된 목표를 효율적이고 확장성 있는 설계로 개발- 지속적 뉴테크 학습과 비지니스적 요소 고려로 유연하게 제품에 적용- 정기적 회고를 통해 부족한 점을 찾고 꾸준히 개선하며 지속 성장
# 2024-08-31
# 2024-07-31

# %%
# Out:
# '2024-08-07'
